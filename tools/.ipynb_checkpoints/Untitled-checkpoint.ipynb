# %%
import sys, os
sys.path.append('../..')
import json
import requests
from ebest import Ebest

# %%
# %load_ext autoreload
# %aimport ebest
# %autoreload 2

# %%
ebest = Ebest()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ebest = Ebest()
#
# File ~\Documents\projects\webapp\webapp\trading\tools\ebest.py:17, in Ebest.__init__(self)
#      16 def __init__(self):
# ---> 17     self.baseurl = get_secret("BASEURL")
#      18     self.appkey = get_secret('APPKEY')
#      19     self.appsecretkey = get_secret('APPSECRETKEY')
#
# File ~\Documents\projects\webapp\webapp\trading\tools\ebest.py:9, in get_secret(setting)
#       6 def get_secret(setting):
#       7     """Get secret setting or fail with ImproperlyConfigured"""
# ----> 9     with open(os.path.join(BASE_DIR, 'secrets.json')) as secrets_file:
#      10         secrets = json.load(secrets_file)
#      12     return secrets["EBEST"][setting]
#
# ...

# %%
ebest.login()

# %%
ebest.transactions(start='20230601', end='20230701')
# Out:
# [{'OrdDt': '20230601',
#   'OvrsFutsOrdNo': '0000021849',
#   'OvrsFutsOrgOrdNo': '0000000000',
#   'FcmOrdNo': '54646338318067',
#   'ExecDt': '20230601',
#   'OvrsFutsExecNo': '0000011088',
#   'FcmAcntNo': '21647',
#   'IsuCodeVal': '3EX1M23_4130',
#   'IsuNm': 'W1 Micro E-mini S&P 500 P4130 (2306)',
#   'AbrdFutsXrcPrc': '0.00000000000',
#   'BnsTpCode': '2',
#   'BnsTpNm': '매수',
#   'FutsOrdStatCode': '4',
#   'TpCodeNm': '신규',
#   'FutsOrdTpCode': '1',
#   'TrdTpNm': '체결',
#   'AbrdFutsOrdPtnCode': '2',
#   'OrdPtnNm': '지정가',
#   'OrdPtnTermTpCode': '01',
#   'CmnCodeNm': '일반',
#   'AppSrtDt': '',
#   'AppEndDt': '',
#   'OrdQty': 1,
#   'OvrsDrvtOrdPrc': '1.85000000000',
#   'OvrsDrvtExecIsuCode': '3EX1M23_4130',
#   'ExecIsuNm': 'W1 Micro E-mini S&P 500 P4130 (2306)',
#   'ExecBnsTpCode': '2',
#   'ExecBnsTpNm': '매수',
#   'ExecQty': 1,
#   'AbrdFutsExecPrc': '1.85000000000',
#   'OrdCndiPrc': '0.00000000000',
#   'OvrsDrvtNowPrc': '3.35000000000',
#   'UnercQty': 0,
# ...
