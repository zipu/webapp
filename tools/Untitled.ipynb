# %%
import sys, os
sys.path.append('../..')
import json
import requests, time
from ebest import Stock
from datetime import datetime

# %%
# %load_ext autoreload
# %aimport ebest
# %autoreload 2

# %%
a = time.time()

# %%
time.time() - a
# Out:
# 4.654552936553955

# %%
api = Stock()

# %%
res = api.login()
# Out:
# *로그인성공*

# %%
res = api.chart("395160")

# %%
len(res.json()['t8410OutBlock1'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 len(res.json()['t8410OutBlock1'])
#
# KeyError: 't8410OutBlock1'

# %%
def test():
    print('hi')

# %%
test('')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 test('')
#
# TypeError: test() takes 0 positional arguments but 1 was given

# %%
codes = [ i['shcode'] for i in stocks.json()['t9945OutBlock'] if i['etfchk']=='1' and 'KODEX' in i['hname']]

# %%
codes = codes[:10]

# %%
''.join(codes)
# Out:
# '069500091160091170091180099140101280102780102960102970114260'

# %%
data = api.favorites()

# %%
data.json()
# Out:
# {'t8407OutBlock1': [{'shcode': '305720',
#    'hname': 'KODEX 2차전지산업',
#    'price': 34630,
#    'sign': '2',
#    'change': 2180,
#    'diff': '6.72',
#    'volume': 6464705,
#    'offerho': 34630,
#    'bidho': 34610,
#    'cvolume': 15,
#    'chdegree': '101.11',
#    'open': 32775,
#    'high': 34900,
#    'low': 32775,
#    'value': 218905,
#    'offerrem': 2910,
#    'bidrem': 1,
#    'totofferrem': 20368,
#    'totbidrem': 2075,
#    'jnilclose': 32450,
#    'uplmtprice': 42185,
#    'dnlmtprice': 22715},
#   {'shcode': '229200',
#    'hname': 'KODEX 코스닥150',
#    'price': 15150,
#    'sign': '2',
#    'change': 165,
#    'diff': '1.10',
#    'volume': 5920558,
#    'offerho': 15150,
#    'bidho': 15145,
#    'cvolume': 500,
#    'chdegree': '168.53',
#    'open': 14985,
#    'high': 15190,
#    'low': 14885,
#    'value': 89105,
#    'offerrem': 4537,
#    'bidrem': 939,
#    'totofferrem': 138679,
#    'totbidrem': 106508,
#    'jnilclose': 14985,
#    'uplmtprice': 19480,
# ...

# %%
[i for i in arr if i['etfchk']=='1']
# Out:
# []

# %%
for i in res:
    print(i['IsuCodeVal']==i['OvrsDrvtExecIsuCode'])
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...

# %%
d = '20230601231248760'

# %%
red = ebest.login()
# Out:
# *로그인성공*
# *접속서버: 해외선물 실서버
# *접속주소: https://openapi.ebestsec.co.kr:8080

# %%
red.json)()
# Out:
#   Cell In[13], line 1
#     red.json)()
#             ^
# SyntaxError: unmatched ')'

# %%
red.json()
# Out:
# {'access_token': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..moBo5OeR0FxdubvWtcGyPAdfVoikRdwXKEm1CDRfSVSo1nFqN7Gs-IPgwh1fCDTjBKaE80Y_069XVtofaF4qeA',
#  'scope': 'oob',
#  'token_type': 'Bearer',
#  'expires_in': 58034}

# %%
res[0]
# Out:
# {'OrdDt': '20230608',
#  'OvrsFutsOrdNo': '0000008232',
#  'OvrsFutsOrgOrdNo': '0000000000',
#  'FcmOrdNo': '708561622276',
#  'ExecDt': '20230608',
#  'OvrsFutsExecNo': '0000003677',
#  'FcmAcntNo': '21647',
#  'IsuCodeVal': 'ZWN23',
#  'IsuNm': 'Wheat(2023.07)',
#  'AbrdFutsXrcPrc': '0.00000000000',
#  'BnsTpCode': '2',
#  'BnsTpNm': '매수',
#  'FutsOrdStatCode': '4',
#  'TpCodeNm': '신규',
#  'FutsOrdTpCode': '1',
#  'TrdTpNm': '체결',
#  'AbrdFutsOrdPtnCode': '2',
#  'OrdPtnNm': '지정가',
#  'OrdPtnTermTpCode': '01',
#  'CmnCodeNm': '일반',
#  'AppSrtDt': '',
#  'AppEndDt': '',
#  'OrdQty': 1,
#  'OvrsDrvtOrdPrc': '620.25000000000',
#  'OvrsDrvtExecIsuCode': 'ZWN23',
#  'ExecIsuNm': 'Wheat(2023.07)',
#  'ExecBnsTpCode': '2',
#  'ExecBnsTpNm': '매수',
#  'ExecQty': 1,
#  'AbrdFutsExecPrc': '620.25000000000',
#  'OrdCndiPrc': '0.00000000000',
#  'OvrsDrvtNowPrc': '620.25000000000',
#  'UnercQty': 0,
#  'TrxStatCode': '1',
#  'TrxStatCodeNm': '체결',
#  'CsgnCmsn': '2.99',
#  'FcmCmsn': '0.0000',
# ...

# %%
res[0]['ExecDttm'][:-3]
# Out:
# '20230104104052'

# %%
res[0]['CsgnCmsn']
# Out:
# '2.99'

# %%
datetime.strptime('20230717123808', "%Y%m%d%H%M%S" )
# Out:
# datetime.datetime(2023, 7, 17, 12, 38, 8)
