# %%
import sys, os
sys.path.append('../..')
import json
import requests, time
from stock import Stock
from futures import Futures
from datetime import datetime

# %%
# %load_ext autoreload
# %aimport stock
# %aimport futures
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
a = Stock()

# %%
a.get_access_token()
# Out:
# True

# %%
res=a.COT('005930')

# %%
res.json()
# Out:
# {'t1716OutBlock': [{'date': '20230728',
#    'close': 70600,
#    'sign': '5',
#    'change': -1100,
#    'diff': '-1.53',
#    'volume': 19073611,
#    'krx_0008': -140107016,
#    'krx_0018': -44879623,
#    'krx_0009': 190804310,
#    'pgmvol': 38215458047,
#    'fsc_listing': 3165220867,
#    'fsc_sjrate': '53.02',
#    'fsc_0009': 191435610,
#    'gm_volume': 938711690,
#    'gm_value': 7086402},
#   {'date': '20230727',
#    'close': 71700,
#    'sign': '2',
#    'change': 1900,
#    'diff': '2.72',
#    'volume': 24205818,
#    'krx_0008': -141933686,
#    'krx_0018': -43359607,
#    'krx_0009': 191259694,
#    'pgmvol': 38216451142,
#    'fsc_listing': 3165427951,
#    'fsc_sjrate': '53.02',
#    'fsc_0009': 191642694,
#    'gm_volume': 938172698,
#    'gm_value': 7048254},
#   {'date': '20230726',
#    'close': 69800,
#    'sign': '5',
#    'change': -200,
#    'diff': '-0.29',
#    'volume': 29848958,
#    'krx_0008': -137841021,
#    'krx_0018': -46473560,
#    'krx_0009': 190171106,
#    'pgmvol': 38215466917,
#    'fsc_listing': 3163909245,
#    'fsc_sjrate': '53.00',
#    'fsc_0009': 190123988,
#    'gm_volume': 937481259,
#    'gm_value': 7000277},
#   {'date': '20230725',
#    'close': 70000,
#    'sign': '5',
#    'change': -400,
#    'diff': '-0.57',
#    'volume': 13500986,
#    'krx_0008': -138463231,
#    'krx_0018': -47558404,
#    'krx_0009': 191393190,
#    'pgmvol': 38217003776,
#    'fsc_listing': 3165243552,
#    'fsc_sjrate': '53.02',
#    'fsc_0009': 191458295,
#    'gm_volume': 937231790,
#    'gm_value': 6982806},
#   {'date': '20230724',
#    'close': 70400,
#    'sign': '2',
#    'change': 100,
#    'diff': '0.14',
#    'volume': 13360061,
#    'krx_0008': -138512424,
#    'krx_0018': -46595087,
#    'krx_0009': 190488534,
#    'pgmvol': 38217943813,
#    'fsc_listing': 3164288196,
#    'fsc_sjrate': '53.01',
#    'fsc_0009': 190502939,
#    'gm_volume': 937043918,
#    'gm_value': 6969569},
#   {'date': '20230721',
#    'close': 70300,
#    'sign': '5',
#    'change': -700,
#    'diff': '-0.99',
#    'volume': 16528926,
#    'krx_0008': -136262977,
#    'krx_0018': -46031293,
#    'krx_0009': 187490106,
#    'pgmvol': 38215521976,
#    'fsc_listing': 3161284337,
#    'fsc_sjrate': '52.95',
#    'fsc_0009': 187499080,
#    'gm_volume': 936353541,
#    'gm_value': 6921370},
#   {'date': '20230720',
#    'close': 71000,
#    'sign': '5',
#    'change': -700,
#    'diff': '-0.98',
#    'volume': 9732730,
#    'krx_0008': -139918074,
#    'krx_0018': -46343109,
#    'krx_0009': 191545634,
#    'pgmvol': 38216345411,
#    'fsc_listing': 3164847957,
#    'fsc_sjrate': '53.01',
#    'fsc_0009': 191062700,
#    'gm_volume': 936141515,
#    'gm_value': 6906266},
#   {'date': '20230719',
#    'close': 71700,
#    'sign': '5',
#    'change': -300,
#    'diff': '-0.42',
#    'volume': 10851948,
#    'krx_0008': -140898784,
#    'krx_0018': -45462417,
#    'krx_0009': 191651575,
#    'pgmvol': 38216154970,
#    'fsc_listing': 3163456948,
#    'fsc_sjrate': '52.99',
#    'fsc_0009': 189671691,
#    'gm_volume': 935816154,
#    'gm_value': 6882917},
#   {'date': '20230718',
#    'close': 72000,
#    'sign': '5',
#    'change': -1300,
#    'diff': '-1.77',
#    'volume': 11282654,
#    'krx_0008': -141611064,
#    'krx_0018': -44261698,
#    'krx_0009': 191179591,
#    'pgmvol': 38215054454,
#    'fsc_listing': 3163380264,
#    'fsc_sjrate': '52.99',
#    'fsc_0009': 189595007,
#    'gm_volume': 935442693,
#    'gm_value': 6855721},
#   {'date': '20230717',
#    'close': 73300,
#    'sign': '5',
#    'change': -100,
#    'diff': '-0.14',
#    'volume': 10060049,
#    'krx_0008': -142969074,
#    'krx_0018': -43609368,
#    'krx_0009': 191970638,
#    'pgmvol': 38215690333,
#    'fsc_listing': 3164885311,
#    'fsc_sjrate': '53.02',
#    'fsc_0009': 191100054,
#    'gm_volume': 935028083,
#    'gm_value': 6825368},
#   {'date': '20230714',
#    'close': 73400,
#    'sign': '2',
#    'change': 1500,
#    'diff': '2.09',
#    'volume': 15772356,
#    'krx_0008': -141350965,
#    'krx_0018': -43705943,
#    'krx_0009': 190427963,
#    'pgmvol': 38214336280,
#    'fsc_listing': 3163509952,
#    'fsc_sjrate': '52.99',
#    'fsc_0009': 189724695,
#    'gm_volume': 934542576,
#    'gm_value': 6789951},
#   {'date': '20230713',
#    'close': 71900,
#    'sign': '3',
#    'change': 0,
#    'diff': '0.00',
#    'volume': 14417279,
#    'krx_0008': -132843437,
#    'krx_0018': -47543118,
#    'krx_0009': 185603891,
#    'pgmvol': 38212120237,
#    'fsc_listing': 3158405403,
#    'fsc_sjrate': '52.91',
#    'fsc_0009': 184620146,
#    'gm_volume': 934147846,
#    'gm_value': 6761420},
#   {'date': '20230712',
#    'close': 71900,
#    'sign': '2',
#    'change': 400,
#    'diff': '0.56',
#    'volume': 10226140,
#    'krx_0008': -130028150,
#    'krx_0018': -49880083,
#    'krx_0009': 185166970,
#    'pgmvol': 38213548633,
#    'fsc_listing': 3157846123,
#    'fsc_sjrate': '52.90',
#    'fsc_0009': 184060866,
#    'gm_volume': 933702953,
#    'gm_value': 6729615},
#   {'date': '20230711',
#    'close': 71500,
#    'sign': '2',
#    'change': 2000,
#    'diff': '2.88',
#    'volume': 12152893,
#    'krx_0008': -128949754,
#    'krx_0018': -49231378,
#    'krx_0009': 183449011,
#    'pgmvol': 38212950605,
#    'fsc_listing': 3155927850,
#    'fsc_sjrate': '52.87',
#    'fsc_0009': 182142593,
#    'gm_volume': 933152927,
#    'gm_value': 6690634},
#   {'date': '20230710',
#    'close': 69500,
#    'sign': '5',
#    'change': -400,
#    'diff': '-0.57',
#    'volume': 11565490,
#    'krx_0008': -127348150,
#    'krx_0018': -49995307,
#    'krx_0009': 182572031,
#    'pgmvol': 38212785701,
#    'fsc_listing': 3153681962,
#    'fsc_sjrate': '52.83',
#    'fsc_0009': 179896705,
#    'gm_volume': 932655336,
#    'gm_value': 6655983},
#   {'date': '20230707',
#    'close': 69900,
#    'sign': '5',
#    'change': -1700,
#    'diff': '-2.37',
#    'volume': 17280440,
#    'krx_0008': -128051727,
#    'krx_0018': -49227335,
#    'krx_0009': 182543559,
#    'pgmvol': 38212814089,
#    'fsc_listing': 3153813013,
#    'fsc_sjrate': '52.83',
#    'fsc_0009': 180027756,
#    'gm_volume': 931880996,
#    'gm_value': 6601652},
#   {'date': '20230706',
#    'close': 71600,
#    'sign': '5',
#    'change': -400,
#    'diff': '-0.56',
#    'volume': 14588829,
#    'krx_0008': -132345045,
#    'krx_0018': -46058677,
#    'krx_0009': 183765183,
#    'pgmvol': 38214780433,
#    'fsc_listing': 3154801683,
#    'fsc_sjrate': '52.85',
#    'fsc_0009': 181016426,
#    'gm_volume': 931504877,
#    'gm_value': 6574751},
#   {'date': '20230705',
#    'close': 72000,
#    'sign': '5',
#    'change': -1000,
#    'diff': '-1.37',
#    'volume': 11662458,
#    'krx_0008': -132706162,
#    'krx_0018': -44633277,
#    'krx_0009': 182707905,
#    'pgmvol': 38214702344,
#    'fsc_listing': 3153589805,
#    'fsc_sjrate': '52.83',
#    'fsc_0009': 179804548,
#    'gm_volume': 931100082,
#    'gm_value': 6545460},
#   {'date': '20230704',
#    'close': 73000,
#    'sign': '3',
#    'change': 0,
#    'diff': '0.00',
#    'volume': 10212350,
#    'krx_0008': -134419278,
#    'krx_0018': -41899980,
#    'krx_0009': 181731240,
#    'pgmvol': 38213637864,
#    'fsc_listing': 3152485502,
#    'fsc_sjrate': '52.81',
#    'fsc_0009': 178700245,
#    'gm_volume': 930844087,
#    'gm_value': 6526705},
#   {'date': '20230703',
#    'close': 73000,
#    'sign': '2',
#    'change': 800,
#    'diff': '1.11',
#    'volume': 10722181,
#    'krx_0008': -133461595,
#    'krx_0018': -40684226,
#    'krx_0009': 179475752,
#    'pgmvol': 38212231364,
#    'fsc_listing': 3150524014,
#    'fsc_sjrate': '52.77',
#    'fsc_0009': 176738757,
#    'gm_volume': 930592010,
#    'gm_value': 6508317},
#   {'date': '20230630',
#    'close': 72200,
#    'sign': '5',
#    'change': -200,
#    'diff': '-0.28',
#    'volume': 11334353,
#    'krx_0008': -130917634,
#    'krx_0018': -43254588,
#    'krx_0009': 179464835,
#    'pgmvol': 38212817593,
#    'fsc_listing': 3151237002,
#    'fsc_sjrate': '52.79',
#    'fsc_0009': 177451745,
#    'gm_volume': 930074878,
#    'gm_value': 6470982},
#   {'date': '20230629',
#    'close': 72400,
#    'sign': '5',
#    'change': -300,
#    'diff': '-0.41',
#    'volume': 12216370,
#    'krx_0008': -130584065,
#    'krx_0018': -43000293,
#    'krx_0009': 178890837,
#    'pgmvol': 38212277705,
#    'fsc_listing': 3151307696,
#    'fsc_sjrate': '52.79',
#    'fsc_0009': 177522439,
#    'gm_volume': 929725044,
#    'gm_value': 6445476},
#   {'date': '20230628',
#    'close': 72700,
#    'sign': '2',
#    'change': 100,
#    'diff': '0.14',
#    'volume': 8716664,
#    'krx_0008': -129356479,
#    'krx_0018': -42180967,
#    'krx_0009': 176734203,
#    'pgmvol': 38211637965,
#    'fsc_listing': 3149128846,
#    'fsc_sjrate': '52.75',
#    'fsc_0009': 175343589,
#    'gm_volume': 929405693,
#    'gm_value': 6422324},
#   {'date': '20230627',
#    'close': 72600,
#    'sign': '2',
#    'change': 200,
#    'diff': '0.28',
#    'volume': 9222104,
#    'krx_0008': -128402167,
#    'krx_0018': -42241218,
#    'krx_0009': 175888202,
#    'pgmvol': 38210902875,
#    'fsc_listing': 3150393963,
#    'fsc_sjrate': '52.77',
#    'fsc_0009': 176608706,
#    'gm_volume': 928786865,
#    'gm_value': 6377530},
#   {'date': '20230626',
#    'close': 72400,
#    'sign': '2',
#    'change': 800,
#    'diff': '1.12',
#    'volume': 10410317,
#    'krx_0008': -126492743,
#    'krx_0018': -41823390,
#    'krx_0009': 173616689,
#    'pgmvol': 38209979938,
#    'fsc_listing': 3147924486,
#    'fsc_sjrate': '52.73',
#    'fsc_0009': 174139229,
#    'gm_volume': 928231859,
#    'gm_value': 6337659},
#   {'date': '20230623',
#    'close': 71600,
#    'sign': '2',
#    'change': 300,
#    'diff': '0.42',
#    'volume': 12252821,
#    'krx_0008': -122282930,
#    'krx_0018': -42722457,
#    'krx_0009': 170172620,
#    'pgmvol': 38207917527,
#    'fsc_listing': 3144334417,
#    'fsc_sjrate': '52.67',
#    'fsc_0009': 170549160,
#    'gm_volume': 927926362,
#    'gm_value': 6315705},
#   {'date': '20230622',
#    'close': 71300,
#    'sign': '2',
#    'change': 800,
#    'diff': '1.13',
#    'volume': 11316385,
#    'krx_0008': -119518992,
#    'krx_0018': -41149470,
#    'krx_0009': 165792674,
#    'pgmvol': 38206658751,
#    'fsc_listing': 3139538222,
#    'fsc_sjrate': '52.59',
#    'fsc_0009': 165752965,
#    'gm_volume': 927582543,
#    'gm_value': 6291271},
#   {'date': '20230621',
#    'close': 70500,
#    'sign': '5',
#    'change': -900,
#    'diff': '-1.26',
#    'volume': 10528867,
#    'krx_0008': -117231947,
#    'krx_0018': -41472509,
#    'krx_0009': 163788985,
#    'pgmvol': 38205389714,
#    'fsc_listing': 3138521456,
#    'fsc_sjrate': '52.57',
#    'fsc_0009': 164736199,
#    'gm_volume': 927399932,
#    'gm_value': 6278360},
#   {'date': '20230620',
#    'close': 71400,
#    'sign': '2',
#    'change': 200,
#    'diff': '0.28',
#    'volume': 11535955,
#    'krx_0008': -118150183,
#    'krx_0018': -41102228,
#    'krx_0009': 164319245,
#    'pgmvol': 38205418743,
#    'fsc_listing': 3139273940,
#    'fsc_sjrate': '52.59',
#    'fsc_0009': 165488683,
#    'gm_volume': 927286919,
#    'gm_value': 6270359},
#   {'date': '20230619',
#    'close': 71200,
#    'sign': '5',
#    'change': -600,
#    'diff': '-0.84',
#    'volume': 11009959,
#    'krx_0008': -117613902,
#    'krx_0018': -40676441,
#    'krx_0009': 163377182,
#    'pgmvol': 38204015902,
#    'fsc_listing': 3138114632,
#    'fsc_sjrate': '52.57',
#    'fsc_0009': 164329375,
#    'gm_volume': 927099582,
#    'gm_value': 6257032},
#   {'date': '20230616',
#    'close': 71800,
#    'sign': '2',
#    'change': 300,
#    'diff': '0.42',
#    'volume': 14302425,
#    'krx_0008': -117790449,
#    'krx_0018': -40123267,
#    'krx_0009': 162994280,
#    'pgmvol': 38204390254,
#    'fsc_listing': 3137906162,
#    'fsc_sjrate': '52.56',
#    'fsc_0009': 164120905,
#    'gm_volume': 926214611,
#    'gm_value': 6193755},
#   {'date': '20230615',
#    'close': 71500,
#    'sign': '5',
#    'change': -400,
#    'diff': '-0.56',
#    'volume': 13157666,
#    'krx_0008': -117939967,
#    'krx_0018': -38459681,
#    'krx_0009': 161482952,
#    'pgmvol': 38203740887,
#    'fsc_listing': 3136133435,
#    'fsc_sjrate': '52.53',
#    'fsc_0009': 162348178,
#    'gm_volume': 926069388,
#    'gm_value': 6183317},
#   {'date': '20230614',
#    'close': 71900,
#    'sign': '5',
#    'change': -100,
#    'diff': '-0.14',
#    'volume': 12501046,
#    'krx_0008': -117582029,
#    'krx_0018': -38118707,
#    'krx_0009': 160789806,
#    'pgmvol': 38204105507,
#    'fsc_listing': 3136959357,
#    'fsc_sjrate': '52.55',
#    'fsc_0009': 163174100,
#    'gm_volume': 925918598,
#    'gm_value': 6172515},
#   {'date': '20230613',
#    'close': 72000,
#    'sign': '2',
#    'change': 1000,
#    'diff': '1.41',
#    'volume': 12917385,
#    'krx_0008': -117328388,
#    'krx_0018': -37671518,
#    'krx_0009': 160076148,
#    'pgmvol': 38204432563,
#    'fsc_listing': 3136646047,
#    'fsc_sjrate': '52.54',
#    'fsc_0009': 162860790,
#    'gm_volume': 925848052,
#    'gm_value': 6167443},
#   {'date': '20230612',
#    'close': 71000,
#    'sign': '5',
#    'change': -1000,
#    'diff': '-1.39',
#    'volume': 12042817,
#    'krx_0008': -114580688,
#    'krx_0018': -38646251,
#    'krx_0009': 158231372,
#    'pgmvol': 38203117510,
#    'fsc_listing': 3135405516,
#    'fsc_sjrate': '52.52',
#    'fsc_0009': 161620259,
#    'gm_volume': 923879412,
#    'gm_value': 6026830},
#   {'date': '20230609',
#    'close': 72000,
#    'sign': '2',
#    'change': 1100,
#    'diff': '1.55',
#    'volume': 14992310,
#    'krx_0008': -115857965,
#    'krx_0018': -39127671,
#    'krx_0009': 159984338,
#    'pgmvol': 38203363621,
#    'fsc_listing': 3138211482,
#    'fsc_sjrate': '52.57',
#    'fsc_0009': 164426225,
#    'gm_volume': 923365205,
#    'gm_value': 5990157},
#   {'date': '20230608',
#    'close': 70900,
#    'sign': '5',
#    'change': -100,
#    'diff': '-0.14',
#    'volume': 19165568,
#    'krx_0008': -112067644,
#    'krx_0018': -40554571,
#    'krx_0009': 157511915,
#    'pgmvol': 38202454773,
#    'fsc_listing': 3135396459,
#    'fsc_sjrate': '52.52',
#    'fsc_0009': 161611202,
#    'gm_volume': 922991870,
#    'gm_value': 5963736},
#   {'date': '20230607',
#    'close': 71000,
#    'sign': '5',
#    'change': -700,
#    'diff': '-0.98',
#    'volume': 14755937,
#    'krx_0008': -111471708,
#    'krx_0018': -41013956,
#    'krx_0009': 157283582,
#    'pgmvol': 38202441613,
#    'fsc_listing': 3135548226,
#    'fsc_sjrate': '52.52',
#    'fsc_0009': 161762969,
#    'gm_volume': 922898236,
#    'gm_value': 5957072},
#   {'date': '20230605',
#    'close': 71700,
#    'sign': '5',
#    'change': -500,
#    'diff': '-0.69',
#    'volume': 12651559,
#    'krx_0008': -111220281,
#    'krx_0018': -42558730,
#    'krx_0009': 158546888,
#    'pgmvol': 38202400280,
#    'fsc_listing': 3136445332,
#    'fsc_sjrate': '52.54',
#    'fsc_0009': 162660075,
#    'gm_volume': 922409854,
#    'gm_value': 5921886},
#   {'date': '20230602',
#    'close': 72200,
#    'sign': '2',
#    'change': 1300,
#    'diff': '1.83',
#    'volume': 11769798,
#    'krx_0008': -111629039,
#    'krx_0018': -43546488,
#    'krx_0009': 159971943,
#    'pgmvol': 38204585853,
#    'fsc_listing': 3136730023,
#    'fsc_sjrate': '52.54',
#    'fsc_0009': 162944766,
#    'gm_volume': 921793690,
#    'gm_value': 5877577},
#   {'date': '20230601',
#    'close': 70900,
#    'sign': '5',
#    'change': -500,
#    'diff': '-0.70',
#    'volume': 14566407,
#    'krx_0008': -109119329,
#    'krx_0018': -43578078,
#    'krx_0009': 157523798,
#    'pgmvol': 38202705220,
#    'fsc_listing': 3133808250,
#    'fsc_sjrate': '52.49',
#    'fsc_0009': 160022993,
#    'gm_volume': 921478497,
#    'gm_value': 5855149},
#   {'date': '20230531',
#    'close': 71400,
#    'sign': '5',
#    'change': -900,
#    'diff': '-1.24',
#    'volume': 24153085,
#    'krx_0008': -109370242,
#    'krx_0018': -42103354,
#    'krx_0009': 156278320,
#    'pgmvol': 38201351099,
#    'fsc_listing': 3132707672,
#    'fsc_sjrate': '52.48',
#    'fsc_0009': 158922415,
#    'gm_volume': 920622442,
#    'gm_value': 5793543},
#   {'date': '20230530',
#    'close': 72300,
#    'sign': '2',
#    'change': 2000,
#    'diff': '2.84',
#    'volume': 25371700,
#    'krx_0008': -108223627,
#    'krx_0018': -41391316,
#    'krx_0009': 154283431,
#    'pgmvol': 38202010158,
#    'fsc_listing': 3130869289,
#    'fsc_sjrate': '52.45',
#    'fsc_0009': 157084032,
#    'gm_volume': 919537338,
#    'gm_value': 5715702},
#   {'date': '20230526',
#    'close': 70300,
#    'sign': '2',
#    'change': 1500,
#    'diff': '2.18',
#    'volume': 19522023,
#    'krx_0008': -103248085,
#    'krx_0018': -40495364,
#    'krx_0009': 148064914,
#    'pgmvol': 38200784773,
#    'fsc_listing': 3124516695,
#    'fsc_sjrate': '52.34',
#    'fsc_0009': 150731438,
#    'gm_volume': 918278729,
#    'gm_value': 5627596},
#   {'date': '20230525',
#    'close': 68800,
#    'sign': '2',
#    'change': 300,
#    'diff': '0.44',
#    'volume': 14231160,
#    'krx_0008': -96786272,
#    'krx_0018': -39366748,
#    'krx_0009': 140372074,
#    'pgmvol': 38197199665,
#    'fsc_listing': 3116542289,
#    'fsc_sjrate': '52.21',
#    'fsc_0009': 142757032,
#    'gm_volume': 917338968,
#    'gm_value': 5562512},
#   {'date': '20230524',
#    'close': 68500,
#    'sign': '2',
#    'change': 100,
#    'diff': '0.15',
#    'volume': 8081634,
#    'krx_0008': -96453976,
#    'krx_0018': -38641736,
#    'krx_0009': 139256849,
#    'pgmvol': 38196787258,
#    'fsc_listing': 3116148965,
#    'fsc_sjrate': '52.20',
#    'fsc_0009': 142363708,
#    'gm_volume': 916960243,
#    'gm_value': 5536600},
#   {'date': '20230523',
#    'close': 68400,
#    'sign': '5',
#    'change': -100,
#    'diff': '-0.15',
#    'volume': 8528989,
#    'krx_0008': -95688672,
#    'krx_0018': -38020901,
#    'krx_0009': 137878094,
#    'pgmvol': 38195428934,
#    'fsc_listing': 3114885610,
#    'fsc_sjrate': '52.18',
#    'fsc_0009': 141100353,
#    'gm_volume': 916390058,
#    'gm_value': 5497574},
#   {'date': '20230522',
#    'close': 68500,
#    'sign': '2',
#    'change': 100,
#    'diff': '0.15',
#    'volume': 14425375,
#    'krx_0008': -95202122,
#    'krx_0018': -39103791,
#    'krx_0009': 138416708,
#    'pgmvol': 38196310745,
#    'fsc_listing': 3115646940,
#    'fsc_sjrate': '52.19',
#    'fsc_0009': 141861683,
#    'gm_volume': 915755716,
#    'gm_value': 5454141},
#   {'date': '20230519',
#    'close': 68400,
#    'sign': '2',
#    'change': 2200,
#    'diff': '3.32',
#    'volume': 20334873,
#    'krx_0008': -92782096,
#    'krx_0018': -41532650,
#    'krx_0009': 138349267,
#    'pgmvol': 38197462963,
#    'fsc_listing': 3115896617,
#    'fsc_sjrate': '52.19',
#    'fsc_0009': 142111360,
#    'gm_volume': 915167718,
#    'gm_value': 5414217},
#   {'date': '20230518',
#    'close': 66200,
#    'sign': '2',
#    'change': 1200,
#    'diff': '1.85',
#    'volume': 14411704,
#    'krx_0008': -82542288,
#    'krx_0018': -44375845,
#    'krx_0009': 130567404,
#    'pgmvol': 38192886151,
#    'fsc_listing': 3109160000,
#    'fsc_sjrate': '52.08',
#    'fsc_0009': 135374743,
#    'gm_volume': 914548147,
#    'gm_value': 5373355},
#   {'date': '20230517',
#    'close': 65000,
#    'sign': '5',
#    'change': -400,
#    'diff': '-0.61',
#    'volume': 10217085,
#    'krx_0008': -78218743,
#    'krx_0018': -43402289,
#    'krx_0009': 125069379,
#    'pgmvol': 38189913447,
#    'fsc_listing': 3103603817,
#    'fsc_sjrate': '51.99',
#    'fsc_0009': 129818560,
#    'gm_volume': 912973304,
#    'gm_value': 5270461},
#   {'date': '20230516',
#    'close': 65400,
#    'sign': '2',
#    'change': 900,
#    'diff': '1.40',
#    'volume': 12200178,
#    'krx_0008': -78701848,
#    'krx_0018': -43368595,
#    'krx_0009': 125544686,
#    'pgmvol': 38190801582,
#    'fsc_listing': 3103605816,
#    'fsc_sjrate': '51.99',
#    'fsc_0009': 129820559,
#    'gm_volume': 912274458,
#    'gm_value': 5224604},
#   {'date': '20230515',
#    'close': 64500,
#    'sign': '2',
#    'change': 400,
#    'diff': '0.62',
#    'volume': 8157143,
#    'krx_0008': -76430553,
#    'krx_0018': -43424692,
#    'krx_0009': 122314114,
#    'pgmvol': 38187961322,
#    'fsc_listing': 3100906224,
#    'fsc_sjrate': '51.94',
#    'fsc_0009': 127120967,
#    'gm_volume': 911703204,
#    'gm_value': 5187956},
#   {'date': '20230512',
#    'close': 64100,
#    'sign': '5',
#    'change': -100,
#    'diff': '-0.16',
#    'volume': 7546680,
#    'krx_0008': -75961789,
#    'krx_0018': -43616161,
#    'krx_0009': 122026364,
#    'pgmvol': 38187986429,
#    'fsc_listing': 3100618474,
#    'fsc_sjrate': '51.94',
#    'fsc_0009': 126833217,
#    'gm_volume': 911335258,
#    'gm_value': 5164330},
#   {'date': '20230511',
#    'close': 64200,
#    'sign': '5',
#    'change': -400,
#    'diff': '-0.62',
#    'volume': 11648905,
#    'krx_0008': -76056145,
#    'krx_0018': -43318020,
#    'krx_0009': 121780235,
#    'pgmvol': 38187308042,
#    'fsc_listing': 3100236345,
#    'fsc_sjrate': '51.93',
#    'fsc_0009': 126451088,
#    'gm_volume': 910764763,
#    'gm_value': 5127421},
#   {'date': '20230510',
#    'close': 64600,
#    'sign': '5',
#    'change': -700,
#    'diff': '-1.07',
#    'volume': 13042129,
#    'krx_0008': -76654226,
#    'krx_0018': -43516680,
#    'krx_0009': 122559646,
#    'pgmvol': 38189117326,
#    'fsc_listing': 3100932940,
#    'fsc_sjrate': '51.94',
#    'fsc_0009': 127147683,
#    'gm_volume': 910411874,
#    'gm_value': 5104606},
#   {'date': '20230509',
#    'close': 65300,
#    'sign': '5',
#    'change': -600,
#    'diff': '-0.91',
#    'volume': 9293835,
#    'krx_0008': -78049363,
#    'krx_0018': -42659030,
#    'krx_0009': 123216554,
#    'pgmvol': 38191663314,
#    'fsc_listing': 3101759848,
#    'fsc_sjrate': '51.96',
#    'fsc_0009': 127974591,
#    'gm_volume': 909376669,
#    'gm_value': 5036915},
#   {'date': '20230508',
#    'close': 65900,
#    'sign': '2',
#    'change': 800,
#    'diff': '1.23',
#    'volume': 9268657,
#    'krx_0008': -78260036,
#    'krx_0018': -42868523,
#    'krx_0009': 123665092,
#    'pgmvol': 38192330634,
#    'fsc_listing': 3102256191,
#    'fsc_sjrate': '51.97',
#    'fsc_0009': 128470934,
#    'gm_volume': 908944304,
#    'gm_value': 5008375},
#   {'date': '20230504',
#    'close': 65100,
#    'sign': '5',
#    'change': -300,
#    'diff': '-0.46',
#    'volume': 9776982,
#    'krx_0008': -75600545,
#    'krx_0018': -44427941,
#    'krx_0009': 122524931,
#    'pgmvol': 38192089664,
#    'fsc_listing': 3101371293,
#    'fsc_sjrate': '51.95',
#    'fsc_0009': 127586036,
#    'gm_volume': 908470096,
#    'gm_value': 4977478},
#   {'date': '20230503',
#    'close': 65400,
#    'sign': '5',
#    'change': -300,
#    'diff': '-0.46',
#    'volume': 8795072,
#    'krx_0008': -75721256,
#    'krx_0018': -42950294,
#    'krx_0009': 121186713,
#    'pgmvol': 38191700655,
#    'fsc_listing': 3100361780,
#    'fsc_sjrate': '51.93',
#    'fsc_0009': 126576523,
#    'gm_volume': 907674380,
#    'gm_value': 4925522},
#   {'date': '20230502',
#    'close': 65700,
#    'sign': '2',
#    'change': 200,
#    'diff': '0.31',
#    'volume': 14099788,
#    'krx_0008': -75755064,
#    'krx_0018': -41895197,
#    'krx_0009': 120131054,
#    'pgmvol': 38190574798,
#    'fsc_listing': 3097854660,
#    'fsc_sjrate': '51.89',
#    'fsc_0009': 124069403,
#    'gm_volume': 906539010,
#    'gm_value': 4850764},
#   {'date': '20230428',
#    'close': 65500,
#    'sign': '2',
#    'change': 900,
#    'diff': '1.39',
#    'volume': 18158364,
#    'krx_0008': -74137469,
#    'krx_0018': -42420589,
#    'krx_0009': 118948271,
#    'pgmvol': 38191470818,
#    'fsc_listing': 3096749107,
#    'fsc_sjrate': '51.87',
#    'fsc_0009': 122963850,
#    'gm_volume': 905734016,
#    'gm_value': 4798108},
#   {'date': '20230427',
#    'close': 64600,
#    'sign': '2',
#    'change': 500,
#    'diff': '0.78',
#    'volume': 14727926,
#    'krx_0008': -71482301,
#    'krx_0018': -41213040,
#    'krx_0009': 115002607,
#    'pgmvol': 38189086261,
#    'fsc_listing': 3092645815,
#    'fsc_sjrate': '51.80',
#    'fsc_0009': 118860558,
#    'gm_volume': 905511217,
#    'gm_value': 4783846},
#   {'date': '20230426',
#    'close': 64100,
#    'sign': '2',
#    'change': 500,
#    'diff': '0.79',
#    'volume': 12583068,
#    'krx_0008': -70086581,
#    'krx_0018': -38751165,
#    'krx_0009': 111098744,
#    'pgmvol': 38187700477,
#    'fsc_listing': 3088205952,
#    'fsc_sjrate': '51.73',
#    'fsc_0009': 114420695,
#    'gm_volume': 905094879,
#    'gm_value': 4757278},
#   {'date': '20230425',
#    'close': 63600,
#    'sign': '5',
#    'change': -1600,
#    'diff': '-2.45',
#    'volume': 16088779,
#    'krx_0008': -69741688,
#    'krx_0018': -37774766,
#    'krx_0009': 109649276,
#    'pgmvol': 38186407487,
#    'fsc_listing': 3085388514,
#    'fsc_sjrate': '51.68',
#    'fsc_0009': 111603257,
#    'gm_volume': 904749014,
#    'gm_value': 4734991},
#   {'date': '20230424',
#    'close': 65200,
#    'sign': '5',
#    'change': -500,
#    'diff': '-0.76',
#    'volume': 12916594,
#    'krx_0008': -71004090,
#    'krx_0018': -37231980,
#    'krx_0009': 110363543,
#    'pgmvol': 38186635396,
#    'fsc_listing': 3086117183,
#    'fsc_sjrate': '51.70',
#    'fsc_0009': 112331926,
#    'gm_volume': 904082339,
#    'gm_value': 4691525},
#   {'date': '20230421',
#    'close': 65700,
#    'sign': '2',
#    'change': 400,
#    'diff': '0.61',
#    'volume': 10302056,
#    'krx_0008': -69373238,
#    'krx_0018': -37573243,
#    'krx_0009': 109005342,
#    'pgmvol': 38186271653,
#    'fsc_listing': 3083353159,
#    'fsc_sjrate': '51.65',
#    'fsc_0009': 109567902,
#    'gm_volume': 903392846,
#    'gm_value': 4646262},
#   {'date': '20230420',
#    'close': 65300,
#    'sign': '5',
#    'change': -200,
#    'diff': '-0.31',
#    'volume': 9501169,
#    'krx_0008': -67369316,
#    'krx_0018': -36903357,
#    'krx_0009': 106320145,
#    'pgmvol': 38187676140,
#    'fsc_listing': 3080713573,
#    'fsc_sjrate': '51.61',
#    'fsc_0009': 106928316,
#    'gm_volume': 903131058,
#    'gm_value': 4629239},
#   {'date': '20230419',
#    'close': 65500,
#    'sign': '5',
#    'change': -100,
#    'diff': '-0.15',
#    'volume': 10254291,
#    'krx_0008': -66540799,
#    'krx_0018': -36499472,
#    'krx_0009': 105061895,
#    'pgmvol': 38186965015,
#    'fsc_listing': 3079372323,
#    'fsc_sjrate': '51.58',
#    'fsc_0009': 105587066,
#    'gm_volume': 902826837,
#    'gm_value': 4609314},
#   {'date': '20230418',
#    'close': 65600,
#    'sign': '2',
#    'change': 300,
#    'diff': '0.46',
#    'volume': 14786758,
#    'krx_0008': -65569567,
#    'krx_0018': -36430276,
#    'krx_0009': 104006091,
#    'pgmvol': 38186760787,
#    'fsc_listing': 3080154519,
#    'fsc_sjrate': '51.60',
#    'fsc_0009': 106369262,
#    'gm_volume': 902317591,
#    'gm_value': 4576027},
#   {'date': '20230417',
#    'close': 65300,
#    'sign': '2',
#    'change': 200,
#    'diff': '0.31',
#    'volume': 13486618,
#    'krx_0008': -64911613,
#    'krx_0018': -33357139,
#    'krx_0009': 100262913,
#    'pgmvol': 38184690052,
#    'fsc_listing': 3075861341,
#    'fsc_sjrate': '51.52',
#    'fsc_0009': 102076084,
#    'gm_volume': 902072649,
#    'gm_value': 4560063},
#   {'date': '20230414',
#    'close': 65100,
#    'sign': '5',
#    'change': -1000,
#    'diff': '-1.51',
#    'volume': 15520395,
#    'krx_0008': -63251677,
#    'krx_0018': -31581515,
#    'krx_0009': 96773633,
#    'pgmvol': 38182813339,
#    'fsc_listing': 3072411061,
#    'fsc_sjrate': '51.47',
#    'fsc_0009': 98625804,
#    'gm_volume': 901655957,
#    'gm_value': 4532617},
#   {'date': '20230413',
#    'close': 66100,
#    'sign': '2',
#    'change': 100,
#    'diff': '0.15',
#    'volume': 14618096,
#    'krx_0008': -64273043,
#    'krx_0018': -32176991,
#    'krx_0009': 98444572,
#    'pgmvol': 38183919712,
#    'fsc_listing': 3074047000,
#    'fsc_sjrate': '51.49',
#    'fsc_0009': 100261743,
#    'gm_volume': 900713268,
#    'gm_value': 4470538},
#   {'date': '20230412',
#    'close': 66000,
#    'sign': '2',
#    'change': 100,
#    'diff': '0.15',
#    'volume': 14800565,
#    'krx_0008': -63158224,
#    'krx_0018': -33274658,
#    'krx_0009': 98424991,
#    'pgmvol': 38183720213,
#    'fsc_listing': 3074013419,
#    'fsc_sjrate': '51.49',
#    'fsc_0009': 100228162,
#    'gm_volume': 900341746,
#    'gm_value': 4446124},
#   {'date': '20230411',
#    'close': 65900,
#    'sign': '2',
#    'change': 200,
#    'diff': '0.30',
#    'volume': 16204548,
#    'krx_0008': -61201721,
#    'krx_0018': -31738741,
#    'krx_0009': 94963661,
#    'pgmvol': 38182547373,
#    'fsc_listing': 3069825120,
#    'fsc_sjrate': '51.42',
#    'fsc_0009': 96039863,
#    'gm_volume': 899780829,
#    'gm_value': 4409229},
#   {'date': '20230410',
#    'close': 65700,
#    'sign': '2',
#    'change': 700,
#    'diff': '1.08',
#    'volume': 18758406,
#    'krx_0008': -58899124,
#    'krx_0018': -32978810,
#    'krx_0009': 93814782,
#    'pgmvol': 38183028309,
#    'fsc_listing': 3068974241,
#    'fsc_sjrate': '51.41',
#    'fsc_0009': 95188984,
#    'gm_volume': 899170628,
#    'gm_value': 4369255},
#   {'date': '20230407',
#    'close': 65000,
#    'sign': '2',
#    'change': 2700,
#    'diff': '4.33',
#    'volume': 27476120,
#    'krx_0008': -54501085,
#    'krx_0018': -32903373,
#    'krx_0009': 89281819,
#    'pgmvol': 38179877766,
#    'fsc_listing': 3064926246,
#    'fsc_sjrate': '51.34',
#    'fsc_0009': 91140989,
#    'gm_volume': 898671457,
#    'gm_value': 4336940},
#   {'date': '20230406',
#    'close': 62300,
#    'sign': '5',
#    'change': -1600,
#    'diff': '-2.50',
#    'volume': 14992747,
#    'krx_0008': -39314510,
#    'krx_0018': -34653123,
#    'krx_0009': 75669270,
#    'pgmvol': 38168198973,
#    'fsc_listing': 3050492697,
#    'fsc_sjrate': '51.10',
#    'fsc_0009': 76707440,
#    'gm_volume': 898166143,
#    'gm_value': 4305073},
#   {'date': '20230405',
#    'close': 63900,
#    'sign': '2',
#    'change': 300,
#    'diff': '0.47',
#    'volume': 9066149,
#    'krx_0008': -41369670,
#    'krx_0018': -32817364,
#    'krx_0009': 75938710,
#    'pgmvol': 38168107096,
#    'fsc_listing': 3050116684,
#    'fsc_sjrate': '51.09',
#    'fsc_0009': 76331427,
#    'gm_volume': 897689007,
#    'gm_value': 4274682},
#   {'date': '20230404',
#    'close': 63600,
#    'sign': '2',
#    'change': 500,
#    'diff': '0.79',
#    'volume': 11104517,
#    'krx_0008': -39143587,
#    'krx_0018': -32646116,
#    'krx_0009': 73493948,
#    'pgmvol': 38165819843,
#    'fsc_listing': 3047585024,
#    'fsc_sjrate': '51.05',
#    'fsc_0009': 73799767,
#    'gm_volume': 897402445,
#    'gm_value': 4256496},
#   {'date': '20230403',
#    'close': 63100,
#    'sign': '5',
#    'change': -900,
#    'diff': '-1.41',
#    'volume': 11967331,
#    'krx_0008': -37046827,
#    'krx_0018': -32944092,
#    'krx_0009': 71616146,
#    'pgmvol': 38165507649,
#    'fsc_listing': 3045471322,
#    'fsc_sjrate': '51.01',
#    'fsc_0009': 71686065,
#    'gm_volume': 896868330,
#    'gm_value': 4222620},
#   {'date': '20230331',
#    'close': 64000,
#    'sign': '2',
#    'change': 800,
#    'diff': '1.27',
#    'volume': 13399502,
#    'krx_0008': -37622023,
#    'krx_0018': -31393403,
#    'krx_0009': 70676640,
#    'pgmvol': 38165232105,
#    'fsc_listing': 3042410816,
#    'fsc_sjrate': '50.96',
#    'fsc_0009': 68625559,
#    'gm_volume': 896459231,
#    'gm_value': 4196483},
#   {'date': '20230330',
#    'close': 63200,
#    'sign': '2',
#    'change': 500,
#    'diff': '0.80',
#    'volume': 15085857,
#    'krx_0008': -32306198,
#    'krx_0018': -31806900,
#    'krx_0009': 65660729,
#    'pgmvol': 38163122305,
#    'fsc_listing': 3036413170,
#    'fsc_sjrate': '50.86',
#    'fsc_0009': 62627913,
#    'gm_volume': 895708890,
#    'gm_value': 4148906},
#   {'date': '20230329',
#    'close': 62700,
#    'sign': '5',
#    'change': -200,
#    'diff': '-0.32',
#    'volume': 11098114,
#    'krx_0008': -29367432,
#    'krx_0018': -31390406,
#    'krx_0009': 62296580,
#    'pgmvol': 38162208641,
#    'fsc_listing': 3036800280,
#    'fsc_sjrate': '50.87',
#    'fsc_0009': 63015023,
#    'gm_volume': 895360996,
#    'gm_value': 4127176},
#   {'date': '20230328',
#    'close': 62900,
#    'sign': '2',
#    'change': 800,
#    'diff': '1.29',
#    'volume': 11547657,
#    'krx_0008': -28875259,
#    'krx_0018': -32507083,
#    'krx_0009': 62920728,
#    'pgmvol': 38161304351,
#    'fsc_listing': 3040243186,
#    'fsc_sjrate': '50.93',
#    'fsc_0009': 66457929,
#    'gm_volume': 895174620,
#    'gm_value': 4115507},
#   {'date': '20230327',
#    'close': 62100,
#    'sign': '5',
#    'change': -900,
#    'diff': '-1.43',
#    'volume': 11039331,
#    'krx_0008': -27165412,
#    'krx_0018': -34287124,
#    'krx_0009': 62928636,
#    'pgmvol': 38160623723,
#    'fsc_listing': 3040001094,
#    'fsc_sjrate': '50.92',
#    'fsc_0009': 66215837,
#    'gm_volume': 894863228,
#    'gm_value': 4096084},
#   {'date': '20230324',
#    'close': 63000,
#    'sign': '2',
#    'change': 700,
#    'diff': '1.12',
#    'volume': 17494809,
#    'krx_0008': -26767894,
#    'krx_0018': -34693048,
#    'krx_0009': 62973676,
#    'pgmvol': 38161460427,
#    'fsc_listing': 3040249034,
#    'fsc_sjrate': '50.93',
#    'fsc_0009': 66463777,
#    'gm_volume': 893938453,
#    'gm_value': 4038173},
#   {'date': '20230323',
#    'close': 62300,
#    'sign': '2',
#    'change': 1200,
#    'diff': '1.96',
#    'volume': 15375389,
#    'krx_0008': -21311397,
#    'krx_0018': -32846200,
#    'krx_0009': 55570802,
#    'pgmvol': 38157427198,
#    'fsc_listing': 3033717796,
#    'fsc_sjrate': '50.82',
#    'fsc_0009': 59932539,
#    'gm_volume': 893561980,
#    'gm_value': 4014893},
#   {'date': '20230322',
#    'close': 61100,
#    'sign': '2',
#    'change': 800,
#    'diff': '1.33',
#    'volume': 8976554,
#    'krx_0008': -16502640,
#    'krx_0018': -33737669,
#    'krx_0009': 51506471,
#    'pgmvol': 38155060936,
#    'fsc_listing': 3030156153,
#    'fsc_sjrate': '50.76',
#    'fsc_0009': 56370896,
#    'gm_volume': 893438416,
#    'gm_value': 4007373},
#   {'date': '20230321',
#    'close': 60300,
#    'sign': '2',
#    'change': 100,
#    'diff': '0.17',
#    'volume': 8316048,
#    'krx_0008': -14070869,
#    'krx_0018': -34507011,
#    'krx_0009': 49792191,
#    'pgmvol': 38154388088,
#    'fsc_listing': 3028614032,
#    'fsc_sjrate': '50.73',
#    'fsc_0009': 54828775,
#    'gm_volume': 893123329,
#    'gm_value': 3988368},
#   {'date': '20230320',
#    'close': 60200,
#    'sign': '5',
#    'change': -1100,
#    'diff': '-1.79',
#    'volume': 9609319,
#    'krx_0008': -14011268,
#    'krx_0018': -34965197,
#    'krx_0009': 50206707,
#    'pgmvol': 38154696833,
#    'fsc_listing': 3028104808,
#    'fsc_sjrate': '50.72',
#    'fsc_0009': 54319551,
#    'gm_volume': 892131406,
#    'gm_value': 3928207},
#   {'date': '20230317',
#    'close': 61300,
#    'sign': '2',
#    'change': 1400,
#    'diff': '2.34',
#    'volume': 13882536,
#    'krx_0008': -15280962,
#    'krx_0018': -35161105,
#    'krx_0009': 51691432,
#    'pgmvol': 38156308279,
#    'fsc_listing': 3029991631,
#    'fsc_sjrate': '50.76',
#    'fsc_0009': 56206374,
#    'gm_volume': 891890779,
#    'gm_value': 3913501},
#   {'date': '20230316',
#    'close': 59900,
#    'sign': '2',
#    'change': 100,
#    'diff': '0.17',
#    'volume': 10609439,
#    'krx_0008': -11952046,
#    'krx_0018': -35288944,
#    'krx_0009': 48467069,
#    'pgmvol': 38154708178,
#    'fsc_listing': 3027317381,
#    'fsc_sjrate': '50.71',
#    'fsc_0009': 53532124,
#    'gm_volume': 891638793,
#    'gm_value': 3898513},
#   {'date': '20230315',
#    'close': 59800,
#    'sign': '2',
#    'change': 800,
#    'diff': '1.36',
#    'volume': 10305949,
#    'krx_0008': -11935975,
#    'krx_0018': -34908224,
#    'krx_0009': 48055844,
#    'pgmvol': 38154603829,
#    'fsc_listing': 3025958110,
#    'fsc_sjrate': '50.69',
#    'fsc_0009': 52172853,
#    'gm_volume': 891232878,
#    'gm_value': 3874180},
#   {'date': '20230314',
#    'close': 59000,
#    'sign': '5',
#    'change': -1000,
#    'diff': '-1.67',
#    'volume': 11261616,
#    'krx_0008': -10296241,
#    'krx_0018': -35610657,
#    'krx_0009': 47106564,
#    'pgmvol': 38154253613,
#    'fsc_listing': 3024837845,
#    'fsc_sjrate': '50.67',
#    'fsc_0009': 51052588,
#    'gm_volume': 890904002,
#    'gm_value': 3854694},
#   {'date': '20230313',
#    'close': 60000,
#    'sign': '2',
#    'change': 500,
#    'diff': '0.84',
#    'volume': 11831548,
#    'krx_0008': -11983104,
#    'krx_0018': -35666151,
#    'krx_0009': 48880260,
#    'pgmvol': 38156090631,
#    'fsc_listing': 3026204650,
#    'fsc_sjrate': '50.69',
#    'fsc_0009': 52419393,
#    'gm_volume': 890470569,
#    'gm_value': 3828692},
#   {'date': '20230310',
#    'close': 59500,
#    'sign': '5',
#    'change': -600,
#    'diff': '-1.00',
#    'volume': 11858460,
#    'krx_0008': -10781387,
#    'krx_0018': -36662546,
#    'krx_0009': 48452093,
#    'pgmvol': 38155448186,
#    'fsc_listing': 3024992666,
#    'fsc_sjrate': '50.67',
#    'fsc_0009': 51207409,
#    'gm_volume': 890018968,
#    'gm_value': 3801919},
#   {'date': '20230309',
#    'close': 60100,
#    'sign': '5',
#    'change': -200,
#    'diff': '-0.33',
#    'volume': 13976635,
#    'krx_0008': -12907209,
#    'krx_0018': -35025293,
#    'krx_0009': 49018085,
#    'pgmvol': 38156996423,
#    'fsc_listing': 3025292658,
#    'fsc_sjrate': '50.68',
#    'fsc_0009': 51507401,
#    'gm_volume': 889870669,
#    'gm_value': 3792996},
#   {'date': '20230308',
#    'close': 60300,
#    'sign': '5',
#    'change': -400,
#    'diff': '-0.66',
#    'volume': 13931262,
#    'krx_0008': -14188968,
#    'krx_0018': -37332126,
#    'krx_0009': 52645627,
#    'pgmvol': 38158852717,
#    'fsc_listing': 3028979700,
#    'fsc_sjrate': '50.74',
#    'fsc_0009': 55194443,
#    'gm_volume': 889577048,
#    'gm_value': 3775334},
#   {'date': '20230307',
#    'close': 60700,
#    'sign': '5',
#    'change': -800,
#    'diff': '-1.30',
#    'volume': 11469975,
#    'krx_0008': -15914684,
#    'krx_0018': -34034110,
#    'krx_0009': 51093310,
#    'pgmvol': 38159382057,
#    'fsc_listing': 3027159704,
#    'fsc_sjrate': '50.71',
#    'fsc_0009': 53374447,
#    'gm_volume': 889440687,
#    'gm_value': 3767016},
#   {'date': '20230306',
#    'close': 61500,
#    'sign': '2',
#    'change': 1000,
#    'diff': '1.65',
#    'volume': 13156083,
#    'krx_0008': -17167486,
#    'krx_0018': -33377120,
#    'krx_0009': 51729206,
#    'pgmvol': 38160076150,
#    'fsc_listing': 3028003920,
#    'fsc_sjrate': '50.72',
#    'fsc_0009': 54218663,
#    'gm_volume': 889003337,
#    'gm_value': 3740184},
#   {'date': '20230303',
#    'close': 60500,
#    'sign': '5',
#    'change': -300,
#    'diff': '-0.49',
#    'volume': 10669655,
#    'krx_0008': -13684580,
#    'krx_0018': -35643536,
#    'krx_0009': 50438218,
#    'pgmvol': 38158799142,
#    'fsc_listing': 3026692932,
#    'fsc_sjrate': '50.70',
#    'fsc_0009': 52907675,
#    'gm_volume': 888429819,
#    'gm_value': 3705327},
#   {'date': '20230302',
#    'close': 60800,
#    'sign': '2',
#    'change': 200,
#    'diff': '0.33',
#    'volume': 13049056,
#    'krx_0008': -14885482,
#    'krx_0018': -35410343,
#    'krx_0009': 51443806,
#    'pgmvol': 38162076128,
#    'fsc_listing': 3028440362,
#    'fsc_sjrate': '50.73',
#    'fsc_0009': 54655105,
#    'gm_volume': 887913112,
#    'gm_value': 3673774},
#   {'date': '20230228',
#    'close': 60600,
#    'sign': '2',
#    'change': 100,
#    'diff': '0.17',
#    'volume': 11812945,
#    'krx_0008': -14122283,
#    'krx_0018': -33792659,
#    'krx_0009': 48893195,
#    'pgmvol': 38160694331,
#    'fsc_listing': 3025304438,
#    'fsc_sjrate': '50.68',
#    'fsc_0009': 51519181,
#    'gm_volume': 887290148,
#    'gm_value': 3635785},
#   {'date': '20230227',
#    'close': 60500,
#    'sign': '5',
#    'change': -800,
#    'diff': '-1.31',
#    'volume': 11150697,
#    'krx_0008': -13443899,
#    'krx_0018': -34881618,
#    'krx_0009': 49259092,
#    'pgmvol': 38160559263,
#    'fsc_listing': 3026210335,
#    'fsc_sjrate': '50.69',
#    'fsc_0009': 52425078,
#    'gm_volume': 887035857,
#    'gm_value': 3620408},
#   {'date': '20230224',
#    'close': 61300,
#    'sign': '5',
#    'change': -700,
#    'diff': '-1.13',
#    'volume': 10167790,
#    'krx_0008': -16178406,
#    'krx_0018': -32994227,
#    'krx_0009': 50202710,
#    'pgmvol': 38159812647,
#    'fsc_listing': 3026673423,
#    'fsc_sjrate': '50.70',
#    'fsc_0009': 52888166,
#    'gm_volume': 886414947,
#    'gm_value': 3581838},
#   {'date': '20230223',
#    'close': 62000,
#    'sign': '2',
#    'change': 900,
#    'diff': '1.47',
#    'volume': 12948560,
#    'krx_0008': -17209615,
#    'krx_0018': -31988904,
#    'krx_0009': 50209196,
#    'pgmvol': 38161005551,
#    'fsc_listing': 3026922180,
#    'fsc_sjrate': '50.70',
#    'fsc_0009': 53136923,
#    'gm_volume': 886343993,
#    'gm_value': 3577434},
#   {'date': '20230222',
#    'close': 61100,
#    'sign': '5',
#    'change': -1000,
#    'diff': '-1.61',
#    'volume': 11909088,
#    'krx_0008': -15274396,
#    'krx_0018': -33248012,
#    'krx_0009': 49509656,
#    'pgmvol': 38161308608,
#    'fsc_listing': 3026291640,
#    'fsc_sjrate': '50.69',
#    'fsc_0009': 52506383,
#    'gm_volume': 886022296,
#    'gm_value': 3557698},
#   {'date': '20230221',
#    'close': 62100,
#    'sign': '5',
#    'change': -600,
#    'diff': '-0.96',
#    'volume': 7624592,
#    'krx_0008': -17867042,
#    'krx_0018': -30805137,
#    'krx_0009': 49743704,
#    'pgmvol': 38161379586,
#    'fsc_listing': 3025568688,
#    'fsc_sjrate': '50.68',
#    'fsc_0009': 51783431,
#    'gm_volume': 885919438,
#    'gm_value': 3551301},
#   {'date': '20230220',
#    'close': 62700,
#    'sign': '2',
#    'change': 100,
#    'diff': '0.16',
#    'volume': 12903247,
#    'krx_0008': -19407911,
#    'krx_0018': -29332020,
#    'krx_0009': 49806456,
#    'pgmvol': 38161336313,
#    'fsc_listing': 3025821940,
#    'fsc_sjrate': '50.69',
#    'fsc_0009': 52036683,
#    'gm_volume': 885707882,
#    'gm_value': 3538089},
#   {'date': '20230217',
#    'close': 62600,
#    'sign': '5',
#    'change': -1100,
#    'diff': '-1.73',
#    'volume': 10696387,
#    'krx_0008': -19625372,
#    'krx_0018': -29878541,
#    'krx_0009': 50588247,
#    'pgmvol': 38163367248,
#    'fsc_listing': 3026182851,
#    'fsc_sjrate': '50.69',
#    'fsc_0009': 52397594,
#    'gm_volume': 885472392,
#    'gm_value': 3523270},
#   {'date': '20230216',
#    'close': 63700,
#    'sign': '2',
#    'change': 1500,
#    'diff': '2.41',
#    'volume': 13748358,
#    'krx_0008': -20872042,
#    'krx_0018': -27804817,
#    'krx_0009': 49784461,
#    'pgmvol': 38163258900,
#    'fsc_listing': 3025320065,
#    'fsc_sjrate': '50.68',
#    'fsc_0009': 51534808,
#    'gm_volume': 884969876,
#    'gm_value': 3491566},
#   {'date': '20230215',
#    'close': 62200,
#    'sign': '5',
#    'change': -1000,
#    'diff': '-1.58',
#    'volume': 13182477,
#    'krx_0008': -16591911,
#    'krx_0018': -30538099,
#    'krx_0009': 48175828,
#    'pgmvol': 38161690446,
#    'fsc_listing': 3023518492,
#    'fsc_sjrate': '50.65',
#    'fsc_0009': 49733235,
#    'gm_volume': 884642466,
#    'gm_value': 3471005},
#   {'date': '20230214',
#    'close': 63200,
#    'sign': '2',
#    'change': 300,
#    'diff': '0.48',
#    'volume': 9126664,
#    'krx_0008': -18647027,
#    'krx_0018': -28084558,
#    'krx_0009': 47805218,
#    'pgmvol': 38161466794,
#    'fsc_listing': 3023151882,
#    'fsc_sjrate': '50.64',
#    'fsc_0009': 49366625,
#    'gm_volume': 884311263,
#    'gm_value': 3449957},
#   {'date': '20230213',
#    'close': 62900,
#    'sign': '2',
#    'change': 100,
#    'diff': '0.16',
#    'volume': 10700362,
#    'krx_0008': -16931496,
#    'krx_0018': -29432739,
#    'krx_0009': 47401027,
#    'pgmvol': 38161475540,
#    'fsc_listing': 3022797691,
#    'fsc_sjrate': '50.63',
#    'fsc_0009': 49012434,
#    'gm_volume': 883460222,
#    'gm_value': 3396693},
#   {'date': '20230210',
#    'close': 62800,
#    'sign': '5',
#    'change': -200,
#    'diff': '-0.32',
#    'volume': 9376576,
#    'krx_0008': -16720000,
#    'krx_0018': -27604049,
#    'krx_0009': 45136437,
#    'pgmvol': 38161869738,
#    'fsc_listing': 3020219612,
#    'fsc_sjrate': '50.59',
#    'fsc_0009': 46434355,
#    'gm_volume': 882913362,
#    'gm_value': 3362448},
#   {'date': '20230209',
#    'close': 63000,
#    'sign': '5',
#    'change': -100,
#    'diff': '-0.16',
#    'volume': 12164865,
#    'krx_0008': -17136077,
#    'krx_0018': -25386670,
#    'krx_0009': 43375867,
#    'pgmvol': 38161623457,
#    'fsc_listing': 3017760979,
#    'fsc_sjrate': '50.55',
#    'fsc_0009': 43975722,
#    'gm_volume': 882525536,
#    'gm_value': 3338053},
#   {'date': '20230208',
#    'close': 63100,
#    'sign': '2',
#    'change': 1200,
#    'diff': '1.94',
#    'volume': 12210425,
#    'krx_0008': -16950556,
#    'krx_0018': -24097498,
#    'krx_0009': 41822649,
#    'pgmvol': 38160736197,
#    'fsc_listing': 3015974361,
#    'fsc_sjrate': '50.52',
#    'fsc_0009': 42189104,
#    'gm_volume': 882203611,
#    'gm_value': 3317776},
#   {'date': '20230207',
#    'close': 61900,
#    'sign': '2',
#    'change': 300,
#    'diff': '0.49',
#    'volume': 14491039,
#    'krx_0008': -14745029,
#    'krx_0018': -23413937,
#    'krx_0009': 38833586,
#    'pgmvol': 38159954762,
#    'fsc_listing': 3012802298,
#    'fsc_sjrate': '50.47',
#    'fsc_0009': 39017041,
#    'gm_volume': 881906952,
#    'gm_value': 3299378},
#   {'date': '20230206',
#    'close': 61600,
#    'sign': '5',
#    'change': -2200,
#    'diff': '-3.45',
#    'volume': 15523623,
#    'krx_0008': -15244052,
#    'krx_0018': -22385681,
#    'krx_0009': 38270250,
#    'pgmvol': 38160087283,
#    'fsc_listing': 3011898262,
#    'fsc_sjrate': '50.45',
#    'fsc_0009': 38113005,
#    'gm_volume': 881566742,
#    'gm_value': 3278200},
#   {'date': '20230203',
#    'close': 63800,
#    'sign': '2',
#    'change': 300,
#    'diff': '0.47',
#    'volume': 14853606,
#    'krx_0008': -19212653,
#    'krx_0018': -20617282,
#    'krx_0009': 40545269,
#    'pgmvol': 38162361911,
#    'fsc_listing': 3014053481,
#    'fsc_sjrate': '50.49',
#    'fsc_0009': 40268224,
#    'gm_volume': 881215861,
#    'gm_value': 3255815},
#   {'date': '20230202',
#    'close': 63500,
#    'sign': '2',
#    'change': 1700,
#    'diff': '2.75',
#    'volume': 23173276,
#    'krx_0008': -17479943,
#    'krx_0018': -18595840,
#    'krx_0009': 36740159,
#    'pgmvol': 38158979481,
#    'fsc_listing': 3011043701,
#    'fsc_sjrate': '50.44',
#    'fsc_0009': 37258444,
#    'gm_volume': 880974674,
#    'gm_value': 3240527},
#   {'date': '20230201',
#    'close': 61800,
#    'sign': '2',
#    'change': 800,
#    'diff': '1.31',
#    'volume': 17218723,
#    'krx_0008': -12699561,
#    'krx_0018': -17363293,
#    'krx_0009': 31616976,
#    'pgmvol': 38156664212,
#    'fsc_listing': 3005826373,
#    'fsc_sjrate': '50.35',
#    'fsc_0009': 32041116,
#    'gm_volume': 879897745,
#    'gm_value': 3174189},
#   {'date': '20230131',
#    'close': 61000,
#    'sign': '5',
#    'change': -2300,
#    'diff': '-3.63',
#    'volume': 28338772,
#    'krx_0008': -13069178,
#    'krx_0018': -16851289,
#    'krx_0009': 31554116,
#    'pgmvol': 38155752233,
#    'fsc_listing': 3005520203,
#    'fsc_sjrate': '50.35',
#    'fsc_0009': 31734946,
#    'gm_volume': 879768707,
#    'gm_value': 3166259},
#   {'date': '20230130',
#    'close': 63300,
#    'sign': '5',
#    'change': -1300,
#    'diff': '-2.01',
#    'volume': 19189053,
#    'krx_0008': -18267349,
#    'krx_0018': -18386516,
#    'krx_0009': 38344778,
#    'pgmvol': 38158536520,
#    'fsc_listing': 3012326910,
#    'fsc_sjrate': '50.46',
#    'fsc_0009': 38541653,
#    'gm_volume': 879452477,
#    'gm_value': 3146011},
#   {'date': '20230127',
#    'close': 64600,
#    'sign': '2',
#    'change': 700,
#    'diff': '1.10',
#    'volume': 18185551,
#    'krx_0008': -18349160,
#    'krx_0018': -17709022,
#    'krx_0009': 36751330,
#    'pgmvol': 38157351861,
#    'fsc_listing': 3010762862,
#    'fsc_sjrate': '50.43',
#    'fsc_0009': 36977605,
#    'gm_volume': 879089319,
#    'gm_value': 3122526},
#   {'date': '20230126',
#    'close': 63900,
#    'sign': '2',
#    'change': 500,
#    'diff': '0.79',
#    'volume': 13278277,
#    'krx_0008': -12217653,
#    'krx_0018': -18149293,
#    'krx_0009': 30920607,
#    'pgmvol': 38155576306,
#    'fsc_listing': 3005053104,
#    'fsc_sjrate': '50.34',
#    'fsc_0009': 31267847,
#    'gm_volume': 878863015,
#    'gm_value': 3108103},
#   {'date': '20230125',
#    'close': 63400,
#    'sign': '2',
#    'change': 1600,
#    'diff': '2.59',
#    'volume': 16822710,
#    'krx_0008': -8776468,
#    'krx_0018': -18092532,
#    'krx_0009': 27335174,
#    'pgmvol': 38152913299,
#    'fsc_listing': 3001579071,
#    'fsc_sjrate': '50.28',
#    'fsc_0009': 27793814,
#    'gm_volume': 878451297,
#    'gm_value': 3081986},
#   {'date': '20230120',
#    'close': 61800,
#    'sign': '2',
#    'change': 300,
#    'diff': '0.49',
#    'volume': 9646327,
#    'krx_0008': -1166715,
#    'krx_0018': -18257424,
#    'krx_0009': 19865962,
#    'pgmvol': 38149576894,
#    'fsc_listing': 2995009859,
#    'fsc_sjrate': '50.17',
#    'fsc_0009': 21224602,
#    'gm_volume': 878081999,
#    'gm_value': 3059218},
#   {'date': '20230119',
#    'close': 61500,
#    'sign': '2',
#    'change': 1100,
#    'diff': '1.82',
#    'volume': 12808490,
#    'krx_0008': 481105,
#    'krx_0018': -18384521,
#    'krx_0009': 18330212,
#    'pgmvol': 38148817292,
#    'fsc_listing': 2993784109,
#    'fsc_sjrate': '50.15',
#    'fsc_0009': 19998852,
#    'gm_volume': 877935840,
#    'gm_value': 3050285},
#   {'date': '20230118',
#    'close': 60400,
#    'sign': '5',
#    'change': -600,
#    'diff': '-0.98',
#    'volume': 11584041,
#    'krx_0008': 3787972,
#    'krx_0018': -16961831,
#    'krx_0009': 13545129,
#    'pgmvol': 38145771137,
#    'fsc_listing': 2990511026,
#    'fsc_sjrate': '50.09',
#    'fsc_0009': 16725769,
#    'gm_volume': 877714345,
#    'gm_value': 3036902},
#   {'date': '20230117',
#    'close': 61000,
#    'sign': '5',
#    'change': -100,
#    'diff': '-0.16',
#    'volume': 9831456,
#    'krx_0008': 3111876,
#    'krx_0018': -16067784,
#    'krx_0009': 13285261,
#    'pgmvol': 38146632659,
#    'fsc_listing': 2989308003,
#    'fsc_sjrate': '50.07',
#    'fsc_0009': 15522746,
#    'gm_volume': 877586659,
#    'gm_value': 3029123},
#   {'date': '20230116',
#    'close': 61100,
#    'sign': '2',
#    'change': 300,
#    'diff': '0.49',
#    'volume': 10039972,
#    'krx_0008': 3613199,
#    'krx_0018': -15461915,
#    'krx_0009': 12159422,
#    'pgmvol': 38145570151,
#    'fsc_listing': 2988383164,
#    'fsc_sjrate': '50.06',
#    'fsc_0009': 14597907,
#    'gm_volume': 877290698,
#    'gm_value': 3010969},
#   {'date': '20230113',
#    'close': 60800,
#    'sign': '2',
#    'change': 300,
#    'diff': '0.50',
#    'volume': 12510328,
#    'krx_0008': 5804472,
#    'krx_0018': -16564433,
#    'krx_0009': 11070713,
#    'pgmvol': 38145314384,
#    'fsc_listing': 2987332055,
#    'fsc_sjrate': '50.04',
#    'fsc_0009': 13546798,
#    'gm_volume': 876944535,
#    'gm_value': 2989913},
#   {'date': '20230112',
#    'close': 60500,
#    'sign': '3',
#    'change': 0,
#    'diff': '0.00',
#    'volume': 16102561,
#    'krx_0008': 7858287,
#    'krx_0018': -16998515,
#    'krx_0009': 9680317,
#    'pgmvol': 38144624820,
# ...
#    'fsc_sjrate': '49.34',
#    'fsc_0009': -28017635,
#    'gm_volume': 841539634,
#    'gm_value': 910850},
#   {'date': '20220930',
#    'close': 53100,
#    'sign': '2',
#    'change': 500,
#    'diff': '0.95',
#    'volume': 22503249,
#    'krx_0008': 53130876,
#    'krx_0018': -23750442,
#    'krx_0009': -29649195,
#    'pgmvol': 38130888997,
#    'fsc_listing': 2941181170,
#    'fsc_sjrate': '49.27',
#    'fsc_0009': -32604087,
#    'gm_volume': 841073831,
#    'gm_value': 886390},
#   {'date': '20220929',
#    'close': 52600,
#    'sign': '5',
#    'change': -300,
#    'diff': '-0.57',
#    'volume': 13882080,
#    'krx_0008': 54994117,
#    'krx_0018': -24334848,
#    'krx_0009': -30935689,
#    'pgmvol': 38127763800,
#    'fsc_listing': 2939724022,
#    'fsc_sjrate': '49.24',
#    'fsc_0009': -34061235,
#    'gm_volume': 840759490,
#    'gm_value': 869679},
#   {'date': '20220928',
#    'close': 52900,
#    'sign': '5',
#    'change': -1300,
#    'diff': '-2.40',
#    'volume': 19991129,
#    'krx_0008': 54632923,
#    'krx_0018': -24160101,
#    'krx_0009': -30736551,
#    'pgmvol': 38128048383,
#    'fsc_listing': 2940716074,
#    'fsc_sjrate': '49.26',
#    'fsc_0009': -33069183,
#    'gm_volume': 839741054,
#    'gm_value': 815607},
#   {'date': '20220927',
#    'close': 54200,
#    'sign': '2',
#    'change': 300,
#    'diff': '0.56',
#    'volume': 16631289,
#    'krx_0008': 51947845,
#    'krx_0018': -23858775,
#    'krx_0009': -28297831,
#    'pgmvol': 38129590681,
#    'fsc_listing': 2943062542,
#    'fsc_sjrate': '49.30',
#    'fsc_0009': -30722715,
#    'gm_volume': 839404181,
#    'gm_value': 797427},
#   {'date': '20220926',
#    'close': 53900,
#    'sign': '5',
#    'change': -600,
#    'diff': '-1.10',
#    'volume': 15008449,
#    'krx_0008': 52292494,
#    'krx_0018': -25606151,
#    'krx_0009': -26933208,
#    'pgmvol': 38130975809,
#    'fsc_listing': 2943617219,
#    'fsc_sjrate': '49.31',
#    'fsc_0009': -30168038,
#    'gm_volume': 838899160,
#    'gm_value': 770245},
#   {'date': '20220923',
#    'close': 54500,
#    'sign': '2',
#    'change': 100,
#    'diff': '0.18',
#    'volume': 10555964,
#    'krx_0008': 52820566,
#    'krx_0018': -28342540,
#    'krx_0009': -24739125,
#    'pgmvol': 38133841152,
#    'fsc_listing': 2945888782,
#    'fsc_sjrate': '49.35',
#    'fsc_0009': -27896475,
#    'gm_volume': 838604833,
#    'gm_value': 754219},
#   {'date': '20220922',
#    'close': 54400,
#    'sign': '5',
#    'change': -900,
#    'diff': '-1.63',
#    'volume': 12786510,
#    'krx_0008': 52777601,
#    'krx_0018': -27317819,
#    'krx_0009': -25677091,
#    'pgmvol': 38133528208,
#    'fsc_listing': 2944596606,
#    'fsc_sjrate': '49.33',
#    'fsc_0009': -29188651,
#    'gm_volume': 838376476,
#    'gm_value': 741786},
#   {'date': '20220921',
#    'close': 55300,
#    'sign': '5',
#    'change': -500,
#    'diff': '-0.90',
#    'volume': 11863700,
#    'krx_0008': 49070143,
#    'krx_0018': -25487719,
#    'krx_0009': -23654004,
#    'pgmvol': 38134759575,
#    'fsc_listing': 2946955333,
#    'fsc_sjrate': '49.36',
#    'fsc_0009': -26829924,
#    'gm_volume': 838135774,
#    'gm_value': 728483},
#   {'date': '20220920',
#    'close': 55800,
#    'sign': '5',
#    'change': -600,
#    'diff': '-1.06',
#    'volume': 14041465,
#    'krx_0008': 45847695,
#    'krx_0018': -25245571,
#    'krx_0009': -20617575,
#    'pgmvol': 38135372733,
#    'fsc_listing': 2950760762,
#    'fsc_sjrate': '49.43',
#    'fsc_0009': -23024495,
#    'gm_volume': 838048340,
#    'gm_value': 723574},
#   {'date': '20220919',
#    'close': 56400,
#    'sign': '2',
#    'change': 200,
#    'diff': '0.36',
#    'volume': 12278653,
#    'krx_0008': 43474475,
#    'krx_0018': -26186109,
#    'krx_0009': -17213767,
#    'pgmvol': 38136075425,
#    'fsc_listing': 2954064340,
#    'fsc_sjrate': '49.48',
#    'fsc_0009': -19720917,
#    'gm_volume': 837833223,
#    'gm_value': 711437},
#   {'date': '20220916',
#    'close': 56200,
#    'sign': '2',
#    'change': 200,
#    'diff': '0.36',
#    'volume': 13456503,
#    'krx_0008': 43554870,
#    'krx_0018': -26932636,
#    'krx_0009': -16498030,
#    'pgmvol': 38134753910,
#    'fsc_listing': 2954444957,
#    'fsc_sjrate': '49.49',
#    'fsc_0009': -19340300,
#    'gm_volume': 837447361,
#    'gm_value': 689880},
#   {'date': '20220915',
#    'close': 56000,
#    'sign': '5',
#    'change': -800,
#    'diff': '-1.41',
#    'volume': 11664819,
#    'krx_0008': 41637230,
#    'krx_0018': -25255758,
#    'krx_0009': -16230653,
#    'pgmvol': 38136073079,
#    'fsc_listing': 2955038684,
#    'fsc_sjrate': '49.50',
#    'fsc_0009': -18746573,
#    'gm_volume': 836531791,
#    'gm_value': 638353},
#   {'date': '20220914',
#    'close': 56800,
#    'sign': '5',
#    'change': -1300,
#    'diff': '-2.24',
#    'volume': 12524961,
#    'krx_0008': 37875816,
#    'krx_0018': -24195388,
#    'krx_0009': -13398463,
#    'pgmvol': 38137506607,
#    'fsc_listing': 2957697174,
#    'fsc_sjrate': '49.54',
#    'fsc_0009': -16088083,
#    'gm_volume': 836311238,
#    'gm_value': 625852},
#   {'date': '20220913',
#    'close': 58100,
#    'sign': '2',
#    'change': 2500,
#    'diff': '4.50',
#    'volume': 17166581,
#    'krx_0008': 36439686,
#    'krx_0018': -22850157,
#    'krx_0009': -13303647,
#    'pgmvol': 38137497325,
#    'fsc_listing': 2957674824,
#    'fsc_sjrate': '49.54',
#    'fsc_0009': -16110433,
#    'gm_volume': 836207680,
#    'gm_value': 619869},
#   {'date': '20220908',
#    'close': 55600,
#    'sign': '5',
#    'change': -400,
#    'diff': '-0.71',
#    'volume': 18000016,
#    'krx_0008': 40942170,
#    'krx_0018': -26046751,
#    'krx_0009': -14617101,
#    'pgmvol': 38136197733,
#    'fsc_listing': 2956552587,
#    'fsc_sjrate': '49.53',
#    'fsc_0009': -17232670,
#    'gm_volume': 835741141,
#    'gm_value': 593782},
#   {'date': '20220907',
#    'close': 56000,
#    'sign': '5',
#    'change': -1100,
#    'diff': '-1.93',
#    'volume': 17384854,
#    'krx_0008': 36986751,
#    'krx_0018': -28167846,
#    'krx_0009': -8658224,
#    'pgmvol': 38139098267,
#    'fsc_listing': 2962475920,
#    'fsc_sjrate': '49.62',
#    'fsc_0009': -11309337,
#    'gm_volume': 835293086,
#    'gm_value': 568662},
#   {'date': '20220906',
#    'close': 57100,
#    'sign': '3',
#    'change': 0,
#    'diff': '0.00',
#    'volume': 7503086,
#    'krx_0008': 31309010,
#    'krx_0018': -27008365,
#    'krx_0009': -4054632,
#    'pgmvol': 38140648982,
#    'fsc_listing': 2967411152,
#    'fsc_sjrate': '49.71',
#    'fsc_0009': -6374105,
#    'gm_volume': 835267943,
#    'gm_value': 567226},
#   {'date': '20220905',
#    'close': 57100,
#    'sign': '5',
#    'change': -400,
#    'diff': '-0.70',
#    'volume': 11425977,
#    'krx_0008': 30136508,
#    'krx_0018': -26541608,
#    'krx_0009': -3329224,
#    'pgmvol': 38140826162,
#    'fsc_listing': 2968024377,
#    'fsc_sjrate': '49.72',
#    'fsc_0009': -5760880,
#    'gm_volume': 834915227,
#    'gm_value': 546963},
#   {'date': '20220902',
#    'close': 57500,
#    'sign': '5',
#    'change': -900,
#    'diff': '-1.54',
#    'volume': 15040310,
#    'krx_0008': 28429074,
#    'krx_0018': -27245639,
#    'krx_0009': -840200,
#    'pgmvol': 38142568951,
#    'fsc_listing': 2970775551,
#    'fsc_sjrate': '49.76',
#    'fsc_0009': -3009706,
#    'gm_volume': 834128080,
#    'gm_value': 501377},
#   {'date': '20220901',
#    'close': 58400,
#    'sign': '5',
#    'change': -1300,
#    'diff': '-2.18',
#    'volume': 14905777,
#    'krx_0008': 23025472,
#    'krx_0018': -25615617,
#    'krx_0009': 3064448,
#    'pgmvol': 38145143128,
#    'fsc_listing': 2974218467,
#    'fsc_sjrate': '49.82',
#    'fsc_0009': 433210,
#    'gm_volume': 832125707,
#    'gm_value': 384169},
#   {'date': '20220831',
#    'close': 59700,
#    'sign': '2',
#    'change': 900,
#    'diff': '1.53',
#    'volume': 14203512,
#    'krx_0008': 18641751,
#    'krx_0018': -21746020,
#    'krx_0009': 3632435,
#    'pgmvol': 38147319102,
#    'fsc_listing': 2974643754,
#    'fsc_sjrate': '49.83',
#    'fsc_0009': 858497,
#    'gm_volume': 831419219,
#    'gm_value': 342351},
#   {'date': '20220830',
#    'close': 58800,
#    'sign': '2',
#    'change': 200,
#    'diff': '0.34',
#    'volume': 9690044,
#    'krx_0008': 19536667,
#    'krx_0018': -19583670,
#    'krx_0009': 561845,
#    'pgmvol': 38144260245,
#    'fsc_listing': 2971425254,
#    'fsc_sjrate': '49.77',
#    'fsc_0009': -2360003,
#    'gm_volume': 831188004,
#    'gm_value': 328808},
#   {'date': '20220829',
#    'close': 58600,
#    'sign': '5',
#    'change': -1400,
#    'diff': '-2.33',
#    'volume': 9841329,
#    'krx_0008': 17248658,
#    'krx_0018': -19142771,
#    'krx_0009': 2461252,
#    'pgmvol': 38145888882,
#    'fsc_listing': 2972909661,
#    'fsc_sjrate': '49.80',
#    'fsc_0009': -875596,
#    'gm_volume': 830612183,
#    'gm_value': 294988},
#   {'date': '20220826',
#    'close': 60000,
#    'sign': '2',
#    'change': 300,
#    'diff': '0.50',
#    'volume': 9499995,
#    'krx_0008': 13718042,
#    'krx_0018': -16115429,
#    'krx_0009': 3018561,
#    'pgmvol': 38146875364,
#    'fsc_listing': 2974158300,
#    'fsc_sjrate': '49.82',
#    'fsc_0009': 373043,
#    'gm_volume': 830424971,
#    'gm_value': 283698},
#   {'date': '20220825',
#    'close': 59700,
#    'sign': '2',
#    'change': 700,
#    'diff': '1.19',
#    'volume': 5767902,
#    'krx_0008': 14695643,
#    'krx_0018': -16333946,
#    'krx_0009': 2327186,
#    'pgmvol': 38147238967,
#    'fsc_listing': 2973294725,
#    'fsc_sjrate': '49.81',
#    'fsc_0009': -490532,
#    'gm_volume': 830362986,
#    'gm_value': 280008},
#   {'date': '20220824',
#    'close': 59000,
#    'sign': '5',
#    'change': -100,
#    'diff': '-0.17',
#    'volume': 8888486,
#    'krx_0008': 15081354,
#    'krx_0018': -16056920,
#    'krx_0009': 1731447,
#    'pgmvol': 38147410472,
#    'fsc_listing': 2973086966,
#    'fsc_sjrate': '49.80',
#    'fsc_0009': -698291,
#    'gm_volume': 830266414,
#    'gm_value': 274296},
#   {'date': '20220823',
#    'close': 59100,
#    'sign': '5',
#    'change': -900,
#    'diff': '-1.50',
#    'volume': 9041629,
#    'krx_0008': 13422341,
#    'krx_0018': -14212733,
#    'krx_0009': 1595221,
#    'pgmvol': 38149016650,
#    'fsc_listing': 2972803760,
#    'fsc_sjrate': '49.80',
#    'fsc_0009': -981497,
#    'gm_volume': 830204654,
#    'gm_value': 270635},
#   {'date': '20220822',
#    'close': 60000,
#    'sign': '5',
#    'change': -900,
#    'diff': '-1.48',
#    'volume': 8259865,
#    'krx_0008': 11029032,
#    'krx_0018': -12814898,
#    'krx_0009': 2559640,
#    'pgmvol': 38150072749,
#    'fsc_listing': 2973455175,
#    'fsc_sjrate': '49.81',
#    'fsc_0009': -330082,
#    'gm_volume': 830090139,
#    'gm_value': 263759},
#   {'date': '20220819',
#    'close': 60900,
#    'sign': '5',
#    'change': -600,
#    'diff': '-0.98',
#    'volume': 6923679,
#    'krx_0008': 9604946,
#    'krx_0018': -11564734,
#    'krx_0009': 2755485,
#    'pgmvol': 38150415433,
#    'fsc_listing': 2973627030,
#    'fsc_sjrate': '49.81',
#    'fsc_0009': -158227,
#    'gm_volume': 830028148,
#    'gm_value': 259981},
#   {'date': '20220818',
#    'close': 61500,
#    'sign': '2',
#    'change': 1100,
#    'diff': '1.82',
#    'volume': 16372754,
#    'krx_0008': 8972819,
#    'krx_0018': -11224049,
#    'krx_0009': 3067026,
#    'pgmvol': 38151144434,
#    'fsc_listing': 2973522571,
#    'fsc_sjrate': '49.81',
#    'fsc_0009': -262686,
#    'gm_volume': 829927979,
#    'gm_value': 253867},
#   {'date': '20220817',
#    'close': 60400,
#    'sign': '5',
#    'change': -600,
#    'diff': '-0.98',
#    'volume': 9061518,
#    'krx_0008': 11934376,
#    'krx_0018': -9867832,
#    'krx_0009': -1381197,
#    'pgmvol': 38148778253,
#    'fsc_listing': 2968930408,
#    'fsc_sjrate': '49.73',
#    'fsc_0009': -4854849,
#    'gm_volume': 829872200,
#    'gm_value': 250498},
#   {'date': '20220816',
#    'close': 61000,
#    'sign': '2',
#    'change': 800,
#    'diff': '1.33',
#    'volume': 15036727,
#    'krx_0008': 11146991,
#    'krx_0018': -9692636,
#    'krx_0009': -953270,
#    'pgmvol': 38149123494,
#    'fsc_listing': 2969458335,
#    'fsc_sjrate': '49.74',
#    'fsc_0009': -4326922,
#    'gm_volume': 829728860,
#    'gm_value': 241777},
#   {'date': '20220812',
#    'close': 60200,
#    'sign': '2',
#    'change': 300,
#    'diff': '0.50',
#    'volume': 10786658,
#    'krx_0008': 12550559,
#    'krx_0018': -9728892,
#    'krx_0009': -2151465,
#    'pgmvol': 38149679226,
#    'fsc_listing': 2968632480,
#    'fsc_sjrate': '49.73',
#    'fsc_0009': -5152777,
#    'gm_volume': 829586858,
#    'gm_value': 233250},
#   {'date': '20220811',
#    'close': 59900,
#    'sign': '2',
#    'change': 800,
#    'diff': '1.35',
#    'volume': 15141941,
#    'krx_0008': 12853114,
#    'krx_0018': -9682905,
#    'krx_0009': -2141641,
#    'pgmvol': 38148952966,
#    'fsc_listing': 2968412504,
#    'fsc_sjrate': '49.72',
#    'fsc_0009': -5372753,
#    'gm_volume': 829451564,
#    'gm_value': 225178},
#   {'date': '20220810',
#    'close': 59100,
#    'sign': '5',
#    'change': -900,
#    'diff': '-1.50',
#    'volume': 18084349,
#    'krx_0008': 12032215,
#    'krx_0018': -10977014,
#    'krx_0009': 10262,
#    'pgmvol': 38148457543,
#    'fsc_listing': 2970352957,
#    'fsc_sjrate': '49.76',
#    'fsc_0009': -3432300,
#    'gm_volume': 829169329,
#    'gm_value': 208562},
#   {'date': '20220809',
#    'close': 60000,
#    'sign': '5',
#    'change': -800,
#    'diff': '-1.32',
#    'volume': 18251170,
#    'krx_0008': 7732733,
#    'krx_0018': -8486898,
#    'krx_0009': 1990765,
#    'pgmvol': 38150569028,
#    'fsc_listing': 2973957070,
#    'fsc_sjrate': '49.82',
#    'fsc_0009': 171813,
#    'gm_volume': 828816624,
#    'gm_value': 187370},
#   {'date': '20220808',
#    'close': 60800,
#    'sign': '5',
#    'change': -700,
#    'diff': '-1.14',
#    'volume': 11313150,
#    'krx_0008': 4146761,
#    'krx_0018': -8665113,
#    'krx_0009': 5812812,
#    'pgmvol': 38151061765,
#    'fsc_listing': 2977890657,
#    'fsc_sjrate': '49.88',
#    'fsc_0009': 4105400,
#    'gm_volume': 828507696,
#    'gm_value': 168539},
#   {'date': '20220805',
#    'close': 61500,
#    'sign': '3',
#    'change': 0,
#    'diff': '0.00',
#    'volume': 9567620,
#    'krx_0008': 2037166,
#    'krx_0018': -6806394,
#    'krx_0009': 6097154,
#    'pgmvol': 38150705584,
#    'fsc_listing': 2977991499,
#    'fsc_sjrate': '49.88',
#    'fsc_0009': 4206242,
#    'gm_volume': 827399455,
#    'gm_value': 100381},
#   {'date': '20220804',
#    'close': 61500,
#    'sign': '2',
#    'change': 200,
#    'diff': '0.33',
#    'volume': 9125439,
#    'krx_0008': 1756346,
#    'krx_0018': -7146394,
#    'krx_0009': 6694276,
#    'pgmvol': 38149374601,
#    'fsc_listing': 2978612121,
#    'fsc_sjrate': '49.89',
#    'fsc_0009': 4826864,
#    'gm_volume': 827248032,
#    'gm_value': 91065},
#   {'date': '20220803',
#    'close': 61300,
#    'sign': '5',
#    'change': -400,
#    'diff': '-0.65',
#    'volume': 10053861,
#    'krx_0008': 1906146,
#    'krx_0018': -6386504,
#    'krx_0009': 5777031,
#    'pgmvol': 38148323597,
#    'fsc_listing': 2977784376,
#    'fsc_sjrate': '49.88',
#    'fsc_0009': 3999119,
#    'gm_volume': 827011739,
#    'gm_value': 76599},
#   {'date': '20220802',
#    'close': 61700,
#    'sign': '2',
#    'change': 400,
#    'diff': '0.65',
#    'volume': 13614895,
#    'krx_0008': 403427,
#    'krx_0018': -5051242,
#    'krx_0009': 5965251,
#    'pgmvol': 38148886675,
#    'fsc_listing': 2977990096,
#    'fsc_sjrate': '49.88',
#    'fsc_0009': 4204839,
#    'gm_volume': 826885452,
#    'gm_value': 68877},
#   {'date': '20220801',
#    'close': 61300,
#    'sign': '5',
#    'change': -100,
#    'diff': '-0.16',
#    'volume': 13154816,
#    'krx_0008': 1397942,
#    'krx_0018': -2534941,
#    'krx_0009': 2439849,
#    'pgmvol': 38146960257,
#    'fsc_listing': 2974186694,
#    'fsc_sjrate': '49.82',
#    'fsc_0009': 401437,
#    'gm_volume': 826699283,
#    'gm_value': 57565},
#   {'date': '20220729',
#    'close': 61400,
#    'sign': '5',
#    'change': -500,
#    'diff': '-0.81',
#    'volume': 15093120,
#    'krx_0008': 867455,
#    'krx_0018': -1481566,
#    'krx_0009': 1885858,
#    'pgmvol': 38146646463,
#    'fsc_listing': 2973939771,
#    'fsc_sjrate': '49.82',
#    'fsc_0009': 154514,
#    'gm_volume': 826008945,
#    'gm_value': 14989},
#   {'date': '20220728',
#    'close': 61900,
#    'sign': '2',
#    'change': 100,
#    'diff': '0.16',
#    'volume': 10745302,
#    'krx_0008': -367779,
#    'krx_0018': -1330698,
#    'krx_0009': 2893796,
#    'pgmvol': 38148270422,
#    'fsc_listing': 2975485738,
#    'fsc_sjrate': '49.84',
#    'fsc_0009': 1700481,
#    'gm_volume': 825853773,
#    'gm_value': 5349},
#   {'date': '20220727',
#    'close': 61800,
#    'sign': '2',
#    'change': 100,
#    'diff': '0.16',
#    'volume': 7320997,
#    'krx_0008': -159210,
#    'krx_0018': -770633,
#    'krx_0009': 2116679,
#    'pgmvol': 38147574907,
#    'fsc_listing': 2973391951,
#    'fsc_sjrate': '49.81',
#    'fsc_0009': -393306,
#    'gm_volume': 825766704,
#    'gm_value': 0}],
#  'rsp_cd': '00000',
#  'rsp_msg': '정상적으로 조회가 완료되었습니다.'}

# %%
res.json()
# Out:
# {'t1716OutBlock': [{'date': '20230728',
#    'close': 50600,
#    'sign': '3',
#    'change': 0,
#    'diff': '0.00',
#    'volume': 1539813,
#    'krx_0008': 16125396,
#    'krx_0018': -2489070,
#    'krx_0009': -13127206,
#    'pgmvol': 5481559833,
#    'fsc_listing': 116220154,
#    'fsc_sjrate': '26.16',
#    'fsc_0009': -11918120,
#    'gm_volume': 917850074,
#    'gm_value': 2412982},
#   {'date': '20230727',
#    'close': 50600,
#    'sign': '2',
#    'change': 2800,
#    'diff': '5.86',
#    'volume': 2861543,
#    'krx_0008': 16575511,
#    'krx_0018': -2878455,
#    'krx_0009': -13199401,
#    'pgmvol': 5481521712,
#    'fsc_listing': 116147959,
#    'fsc_sjrate': '26.14',
#    'fsc_0009': -11990315,
#    'gm_volume': 917740260,
#    'gm_value': 2407490},
#   {'date': '20230726',
#    'close': 47800,
#    'sign': '5',
#    'change': -1050,
#    'diff': '-2.15',
#    'volume': 3798977,
#    'krx_0008': 17894333,
#    'krx_0018': -3327065,
#    'krx_0009': -14079283,
#    'pgmvol': 5480641727,
#    'fsc_listing': 115277103,
#    'fsc_sjrate': '25.95',
#    'fsc_0009': -12861171,
#    'gm_volume': 917521896,
#    'gm_value': 2397112},
#   {'date': '20230725',
#    'close': 48850,
#    'sign': '5',
#    'change': -1000,
#    'diff': '-2.01',
#    'volume': 1788062,
#    'krx_0008': 18128855,
#    'krx_0018': -3381087,
#    'krx_0009': -14268572,
#    'pgmvol': 5480358080,
#    'fsc_listing': 115112196,
#    'fsc_sjrate': '25.91',
#    'fsc_0009': -13026078,
#    'gm_volume': 917439283,
#    'gm_value': 2393064},
#   {'date': '20230724',
#    'close': 49850,
#    'sign': '5',
#    'change': -750,
#    'diff': '-1.48',
#    'volume': 1943708,
#    'krx_0008': 17842739,
#    'krx_0018': -3271809,
#    'krx_0009': -14093638,
#    'pgmvol': 5480548504,
#    'fsc_listing': 115348270,
#    'fsc_sjrate': '25.96',
#    'fsc_0009': -12790004,
#    'gm_volume': 917311455,
#    'gm_value': 2386712},
#   {'date': '20230721',
#    'close': 50600,
#    'sign': '2',
#    'change': 100,
#    'diff': '0.20',
#    'volume': 1200404,
#    'krx_0008': 18078562,
#    'krx_0018': -3382984,
#    'krx_0009': -14220269,
#    'pgmvol': 5480458789,
#    'fsc_listing': 115221639,
#    'fsc_sjrate': '25.94',
#    'fsc_0009': -12916635,
#    'gm_volume': 917239539,
#    'gm_value': 2383091},
#   {'date': '20230720',
#    'close': 50500,
#    'sign': '2',
#    'change': 100,
#    'diff': '0.20',
#    'volume': 1150775,
#    'krx_0008': 18251770,
#    'krx_0018': -3477598,
#    'krx_0009': -14315849,
#    'pgmvol': 5480229127,
#    'fsc_listing': 115110409,
#    'fsc_sjrate': '25.91',
#    'fsc_0009': -13027865,
#    'gm_volume': 917178955,
#    'gm_value': 2380027},
#   {'date': '20230719',
#    'close': 50400,
#    'sign': '5',
#    'change': -1400,
#    'diff': '-2.70',
#    'volume': 1674191,
#    'krx_0008': 18353018,
#    'krx_0018': -3408161,
#    'krx_0009': -14495152,
#    'pgmvol': 5480043908,
#    'fsc_listing': 114910131,
#    'fsc_sjrate': '25.87',
#    'fsc_0009': -13228143,
#    'gm_volume': 916949421,
#    'gm_value': 2368426},
#   {'date': '20230718',
#    'close': 51800,
#    'sign': '5',
#    'change': -900,
#    'diff': '-1.71',
#    'volume': 1486148,
#    'krx_0008': 18042507,
#    'krx_0018': -3062547,
#    'krx_0009': -14531878,
#    'pgmvol': 5479973201,
#    'fsc_listing': 114938405,
#    'fsc_sjrate': '25.87',
#    'fsc_0009': -13199869,
#    'gm_volume': 916763509,
#    'gm_value': 2358801},
#   {'date': '20230717',
#    'close': 52700,
#    'sign': '5',
#    'change': -100,
#    'diff': '-0.19',
#    'volume': 1411212,
#    'krx_0008': 18225854,
#    'krx_0018': -2811731,
#    'krx_0009': -14982544,
#    'pgmvol': 5479611257,
#    'fsc_listing': 114467739,
#    'fsc_sjrate': '25.77',
#    'fsc_0009': -13670535,
#    'gm_volume': 916626128,
#    'gm_value': 2351584},
#   {'date': '20230714',
#    'close': 52800,
#    'sign': '2',
#    'change': 900,
#    'diff': '1.73',
#    'volume': 1900674,
#    'krx_0008': 18353938,
#    'krx_0018': -2679021,
#    'krx_0009': -15253258,
#    'pgmvol': 5479405741,
#    'fsc_listing': 114190025,
#    'fsc_sjrate': '25.70',
#    'fsc_0009': -13948249,
#    'gm_volume': 916529598,
#    'gm_value': 2346526},
#   {'date': '20230713',
#    'close': 51900,
#    'sign': '2',
#    'change': 300,
#    'diff': '0.58',
#    'volume': 1955527,
#    'krx_0008': 18973544,
#    'krx_0018': -3069441,
#    'krx_0009': -15518194,
#    'pgmvol': 5479175725,
#    'fsc_listing': 113855089,
#    'fsc_sjrate': '25.63',
#    'fsc_0009': -14283185,
#    'gm_volume': 916450705,
#    'gm_value': 2342421},
#   {'date': '20230712',
#    'close': 51600,
#    'sign': '2',
#    'change': 900,
#    'diff': '1.78',
#    'volume': 1658795,
#    'krx_0008': 19358888,
#    'krx_0018': -3203368,
#    'krx_0009': -15781051,
#    'pgmvol': 5479128521,
#    'fsc_listing': 113707232,
#    'fsc_sjrate': '25.59',
#    'fsc_0009': -14431042,
#    'gm_volume': 916336221,
#    'gm_value': 2336571},
#   {'date': '20230711',
#    'close': 50700,
#    'sign': '2',
#    'change': 850,
#    'diff': '1.71',
#    'volume': 1212718,
#    'krx_0008': 19702656,
#    'krx_0018': -3440797,
#    'krx_0009': -15914093,
#    'pgmvol': 5479119530,
#    'fsc_listing': 113560910,
#    'fsc_sjrate': '25.56',
#    'fsc_0009': -14577364,
#    'gm_volume': 916240866,
#    'gm_value': 2331769},
#   {'date': '20230710',
#    'close': 49850,
#    'sign': '3',
#    'change': 0,
#    'diff': '0.00',
#    'volume': 1068139,
#    'krx_0008': 19902072,
#    'krx_0018': -3480389,
#    'krx_0009': -16110933,
#    'pgmvol': 5479130740,
#    'fsc_listing': 113310070,
#    'fsc_sjrate': '25.51',
#    'fsc_0009': -14828204,
#    'gm_volume': 916154055,
#    'gm_value': 2327435},
#   {'date': '20230707',
#    'close': 49850,
#    'sign': '5',
#    'change': -1050,
#    'diff': '-2.06',
#    'volume': 1601750,
#    'krx_0008': 19977162,
#    'krx_0018': -3495227,
#    'krx_0009': -16179190,
#    'pgmvol': 5479133737,
#    'fsc_listing': 113238813,
#    'fsc_sjrate': '25.49',
#    'fsc_0009': -14899461,
#    'gm_volume': 915582801,
#    'gm_value': 2298577},
#   {'date': '20230706',
#    'close': 50900,
#    'sign': '2',
#    'change': 2050,
#    'diff': '4.20',
#    'volume': 3139685,
#    'krx_0008': 19720932,
#    'krx_0018': -3236639,
#    'krx_0009': -16174938,
#    'pgmvol': 5479394627,
#    'fsc_listing': 113213065,
#    'fsc_sjrate': '25.48',
#    'fsc_0009': -14925209,
#    'gm_volume': 915353663,
#    'gm_value': 2287011},
#   {'date': '20230705',
#    'close': 48850,
#    'sign': '5',
#    'change': -1100,
#    'diff': '-2.20',
#    'volume': 2700066,
#    'krx_0008': 20445576,
#    'krx_0018': -3391212,
#    'krx_0009': -16735745,
#    'pgmvol': 5479170013,
#    'fsc_listing': 112602258,
#    'fsc_sjrate': '25.35',
#    'fsc_0009': -15536016,
#    'gm_volume': 914826928,
#    'gm_value': 2261093},
#   {'date': '20230704',
#    'close': 49950,
#    'sign': '5',
#    'change': -1050,
#    'diff': '-2.06',
#    'volume': 1445459,
#    'krx_0008': 19695983,
#    'krx_0018': -2916975,
#    'krx_0009': -16487466,
#    'pgmvol': 5479452602,
#    'fsc_listing': 112718537,
#    'fsc_sjrate': '25.38',
#    'fsc_0009': -15419737,
#    'gm_volume': 914640890,
#    'gm_value': 2251765},
#   {'date': '20230703',
#    'close': 51000,
#    'sign': '2',
#    'change': 1900,
#    'diff': '3.87',
#    'volume': 1691513,
#    'krx_0008': 19195002,
#    'krx_0018': -2537062,
#    'krx_0009': -16361480,
#    'pgmvol': 5479876876,
#    'fsc_listing': 112908136,
#    'fsc_sjrate': '25.42',
#    'fsc_0009': -15230138,
#    'gm_volume': 914563945,
#    'gm_value': 2247882},
#   {'date': '20230630',
#    'close': 49100,
#    'sign': '2',
#    'change': 100,
#    'diff': '0.20',
#    'volume': 1268925,
#    'krx_0008': 19563701,
#    'krx_0018': -2868413,
#    'krx_0009': -16392221,
#    'pgmvol': 5479911762,
#    'fsc_listing': 112877395,
#    'fsc_sjrate': '25.42',
#    'fsc_0009': -15260879,
#    'gm_volume': 914402192,
#    'gm_value': 2239947},
#   {'date': '20230629',
#    'close': 49000,
#    'sign': '3',
#    'change': 0,
#    'diff': '0.00',
#    'volume': 1287518,
#    'krx_0008': 19454677,
#    'krx_0018': -2935030,
#    'krx_0009': -16228371,
#    'pgmvol': 5480089694,
#    'fsc_listing': 112351245,
#    'fsc_sjrate': '25.30',
#    'fsc_0009': -15787029,
#    'gm_volume': 914276074,
#    'gm_value': 2233735},
#   {'date': '20230628',
#    'close': 49000,
#    'sign': '5',
#    'change': -350,
#    'diff': '-0.71',
#    'volume': 1659730,
#    'krx_0008': 19342811,
#    'krx_0018': -2902604,
#    'krx_0009': -16132215,
#    'pgmvol': 5480206747,
#    'fsc_listing': 112447401,
#    'fsc_sjrate': '25.32',
#    'fsc_0009': -15690873,
#    'gm_volume': 914019129,
#    'gm_value': 2221152},
#   {'date': '20230627',
#    'close': 49350,
#    'sign': '5',
#    'change': -650,
#    'diff': '-1.30',
#    'volume': 1333727,
#    'krx_0008': 19014205,
#    'krx_0018': -2842868,
#    'krx_0009': -15872260,
#    'pgmvol': 5480401105,
#    'fsc_listing': 112707356,
#    'fsc_sjrate': '25.38',
#    'fsc_0009': -15430918,
#    'gm_volume': 913861089,
#    'gm_value': 2213325},
#   {'date': '20230626',
#    'close': 50000,
#    'sign': '2',
#    'change': 300,
#    'diff': '0.60',
#    'volume': 1872956,
#    'krx_0008': 18510376,
#    'krx_0018': -2716974,
#    'krx_0009': -15493698,
#    'pgmvol': 5480744261,
#    'fsc_listing': 113085430,
#    'fsc_sjrate': '25.46',
#    'fsc_0009': -15052844,
#    'gm_volume': 913524881,
#    'gm_value': 2196601},
#   {'date': '20230623',
#    'close': 49700,
#    'sign': '5',
#    'change': -600,
#    'diff': '-1.19',
#    'volume': 1694574,
#    'krx_0008': 18510914,
#    'krx_0018': -2862710,
#    'krx_0009': -15347613,
#    'pgmvol': 5481157493,
#    'fsc_listing': 113001515,
#    'fsc_sjrate': '25.44',
#    'fsc_0009': -15136759,
#    'gm_volume': 913266221,
#    'gm_value': 2183734},
#   {'date': '20230622',
#    'close': 50300,
#    'sign': '5',
#    'change': -200,
#    'diff': '-0.40',
#    'volume': 1336297,
#    'krx_0008': 17933396,
#    'krx_0018': -2600672,
#    'krx_0009': -15022870,
#    'pgmvol': 5481494922,
#    'fsc_listing': 113266258,
#    'fsc_sjrate': '25.50',
#    'fsc_0009': -14872016,
#    'gm_volume': 913135510,
#    'gm_value': 2177113},
#   {'date': '20230621',
#    'close': 50500,
#    'sign': '5',
#    'change': -1200,
#    'diff': '-2.32',
#    'volume': 2027881,
#    'krx_0008': 17632000,
#    'krx_0018': -2534074,
#    'krx_0009': -14787623,
#    'pgmvol': 5481590313,
#    'fsc_listing': 113191505,
#    'fsc_sjrate': '25.49',
#    'fsc_0009': -14946769,
#    'gm_volume': 912920288,
#    'gm_value': 2166156},
#   {'date': '20230620',
#    'close': 51700,
#    'sign': '5',
#    'change': -800,
#    'diff': '-1.52',
#    'volume': 1735023,
#    'krx_0008': 17150581,
#    'krx_0018': -2274611,
#    'krx_0009': -14568799,
#    'pgmvol': 5481783130,
#    'fsc_listing': 113409841,
#    'fsc_sjrate': '25.54',
#    'fsc_0009': -14728433,
#    'gm_volume': 912768266,
#    'gm_value': 2158267},
#   {'date': '20230619',
#    'close': 52500,
#    'sign': '5',
#    'change': -1100,
#    'diff': '-2.05',
#    'volume': 2131119,
#    'krx_0008': 16532553,
#    'krx_0018': -1990234,
#    'krx_0009': -14259205,
#    'pgmvol': 5481936764,
#    'fsc_listing': 113768948,
#    'fsc_sjrate': '25.62',
#    'fsc_0009': -14369326,
#    'gm_volume': 912493427,
#    'gm_value': 2143870},
#   {'date': '20230616',
#    'close': 53600,
#    'sign': '5',
#    'change': -300,
#    'diff': '-0.56',
#    'volume': 1724529,
#    'krx_0008': 16105235,
#    'krx_0018': -1695635,
#    'krx_0009': -14128500,
#    'pgmvol': 5482054980,
#    'fsc_listing': 113899166,
#    'fsc_sjrate': '25.65',
#    'fsc_0009': -14239108,
#    'gm_volume': 912300109,
#    'gm_value': 2133455},
#   {'date': '20230615',
#    'close': 53900,
#    'sign': '5',
#    'change': -1800,
#    'diff': '-3.23',
#    'volume': 2717595,
#    'krx_0008': 15505507,
#    'krx_0018': -1337597,
#    'krx_0009': -13887974,
#    'pgmvol': 5482226995,
#    'fsc_listing': 114069868,
#    'fsc_sjrate': '25.69',
#    'fsc_0009': -14068406,
#    'gm_volume': 912045773,
#    'gm_value': 2119604},
#   {'date': '20230614',
#    'close': 55700,
#    'sign': '5',
#    'change': -700,
#    'diff': '-1.24',
#    'volume': 2051297,
#    'krx_0008': 14355649,
#    'krx_0018': -629329,
#    'krx_0009': -13408561,
#    'pgmvol': 5482705914,
#    'fsc_listing': 114548794,
#    'fsc_sjrate': '25.79',
#    'fsc_0009': -13589480,
#    'gm_volume': 911793687,
#    'gm_value': 2105559},
#   {'date': '20230613',
#    'close': 56400,
#    'sign': '5',
#    'change': -200,
#    'diff': '-0.35',
#    'volume': 1101921,
#    'krx_0008': 14071067,
#    'krx_0018': -756506,
#    'krx_0009': -13004718,
#    'pgmvol': 5483063353,
#    'fsc_listing': 114951663,
#    'fsc_sjrate': '25.88',
#    'fsc_0009': -13186611,
#    'gm_volume': 911705653,
#    'gm_value': 2100590},
#   {'date': '20230612',
#    'close': 56600,
#    'sign': '2',
#    'change': 200,
#    'diff': '0.35',
#    'volume': 867990,
#    'krx_0008': 13750294,
#    'krx_0018': -627922,
#    'krx_0009': -12810071,
#    'pgmvol': 5483328462,
#    'fsc_listing': 115146310,
#    'fsc_sjrate': '25.93',
#    'fsc_0009': -12991964,
#    'gm_volume': 911575719,
#    'gm_value': 2093226},
#   {'date': '20230609',
#    'close': 56400,
#    'sign': '5',
#    'change': -100,
#    'diff': '-0.18',
#    'volume': 1732451,
#    'krx_0008': 13823386,
#    'krx_0018': -641346,
#    'krx_0009': -12866888,
#    'pgmvol': 5483289520,
#    'fsc_listing': 115089493,
#    'fsc_sjrate': '25.91',
#    'fsc_0009': -13048781,
#    'gm_volume': 911426784,
#    'gm_value': 2084784},
#   {'date': '20230608',
#    'close': 56500,
#    'sign': '5',
#    'change': -900,
#    'diff': '-1.57',
#    'volume': 1734613,
#    'krx_0008': 13656827,
#    'krx_0018': -417050,
#    'krx_0009': -12910649,
#    'pgmvol': 5483428025,
#    'fsc_listing': 115037732,
#    'fsc_sjrate': '25.91',
#    'fsc_0009': -13100542,
#    'gm_volume': 911206461,
#    'gm_value': 2072321},
#   {'date': '20230607',
#    'close': 57400,
#    'sign': '2',
#    'change': 300,
#    'diff': '0.53',
#    'volume': 1001270,
#    'krx_0008': 13477323,
#    'krx_0018': -309624,
#    'krx_0009': -12836656,
#    'pgmvol': 5483550332,
#    'fsc_listing': 115111725,
#    'fsc_sjrate': '25.93',
#    'fsc_0009': -13026549,
#    'gm_volume': 911159508,
#    'gm_value': 2069622},
#   {'date': '20230605',
#    'close': 57100,
#    'sign': '5',
#    'change': -100,
#    'diff': '-0.17',
#    'volume': 1035494,
#    'krx_0008': 13669325,
#    'krx_0018': -431007,
#    'krx_0009': -12928667,
#    'pgmvol': 5483421188,
#    'fsc_listing': 115161556,
#    'fsc_sjrate': '25.94',
#    'fsc_0009': -12976718,
#    'gm_volume': 911093848,
#    'gm_value': 2065854},
#   {'date': '20230602',
#    'close': 57200,
#    'sign': '2',
#    'change': 1100,
#    'diff': '1.96',
#    'volume': 1677624,
#    'krx_0008': 13673045,
#    'krx_0018': -490455,
#    'krx_0009': -12873025,
#    'pgmvol': 5483505461,
#    'fsc_listing': 115252430,
#    'fsc_sjrate': '25.96',
#    'fsc_0009': -12885844,
#    'gm_volume': 910977910,
#    'gm_value': 2059267},
#   {'date': '20230601',
#    'close': 56100,
#    'sign': '5',
#    'change': -100,
#    'diff': '-0.18',
#    'volume': 1004709,
#    'krx_0008': 14293594,
#    'krx_0018': -1081155,
#    'krx_0009': -12902331,
#    'pgmvol': 5483508403,
#    'fsc_listing': 115209737,
#    'fsc_sjrate': '25.95',
#    'fsc_0009': -12928537,
#    'gm_volume': 910885365,
#    'gm_value': 2054068},
#   {'date': '20230531',
#    'close': 56200,
#    'sign': '5',
#    'change': -600,
#    'diff': '-1.06',
#    'volume': 1982342,
#    'krx_0008': 14095868,
#    'krx_0018': -917869,
#    'krx_0009': -12864900,
#    'pgmvol': 5483546347,
#    'fsc_listing': 115247182,
#    'fsc_sjrate': '25.96',
#    'fsc_0009': -12891092,
#    'gm_volume': 910790831,
#    'gm_value': 2048745},
#   {'date': '20230530',
#    'close': 56800,
#    'sign': '2',
#    'change': 200,
#    'diff': '0.35',
#    'volume': 1155964,
#    'krx_0008': 13696258,
#    'krx_0018': -777557,
#    'krx_0009': -12566207,
#    'pgmvol': 5483817763,
#    'fsc_listing': 115546365,
#    'fsc_sjrate': '26.03',
#    'fsc_0009': -12591909,
#    'gm_volume': 910730027,
#    'gm_value': 2045301},
#   {'date': '20230526',
#    'close': 56600,
#    'sign': '5',
#    'change': -100,
#    'diff': '-0.18',
#    'volume': 709988,
#    'krx_0008': 13595817,
#    'krx_0018': -793463,
#    'krx_0009': -12454484,
#    'pgmvol': 5483846446,
#    'fsc_listing': 115658088,
#    'fsc_sjrate': '26.05',
#    'fsc_0009': -12480186,
#    'gm_volume': 910692458,
#    'gm_value': 2043172},
#   {'date': '20230525',
#    'close': 56700,
#    'sign': '5',
#    'change': -100,
#    'diff': '-0.18',
#    'volume': 1177829,
#    'krx_0008': 13516104,
#    'krx_0018': -690467,
#    'krx_0009': -12476269,
#    'pgmvol': 5483838785,
#    'fsc_listing': 115635812,
#    'fsc_sjrate': '26.05',
#    'fsc_0009': -12502462,
#    'gm_volume': 910584569,
#    'gm_value': 2037063},
#   {'date': '20230524',
#    'close': 56800,
#    'sign': '5',
#    'change': -1200,
#    'diff': '-2.07',
#    'volume': 1258754,
#    'krx_0008': 13245556,
#    'krx_0018': -520682,
#    'krx_0009': -12375597,
#    'pgmvol': 5483919177,
#    'fsc_listing': 115778684,
#    'fsc_sjrate': '26.08',
#    'fsc_0009': -12359590,
#    'gm_volume': 910458067,
#    'gm_value': 2029856},
#   {'date': '20230523',
#    'close': 58000,
#    'sign': '2',
#    'change': 100,
#    'diff': '0.17',
#    'volume': 1015317,
#    'krx_0008': 12758405,
#    'krx_0018': -322009,
#    'krx_0009': -12074959,
#    'pgmvol': 5484222675,
#    'fsc_listing': 116150939,
#    'fsc_sjrate': '26.16',
#    'fsc_0009': -11987335,
#    'gm_volume': 910410407,
#    'gm_value': 2027098},
#   {'date': '20230522',
#    'close': 57900,
#    'sign': '3',
#    'change': 0,
#    'diff': '0.00',
#    'volume': 985462,
#    'krx_0008': 12891053,
#    'krx_0018': -431016,
#    'krx_0009': -12096078,
#    'pgmvol': 5484097785,
#    'fsc_listing': 116129820,
#    'fsc_sjrate': '26.16',
#    'fsc_0009': -12008454,
#    'gm_volume': 910335447,
#    'gm_value': 2022756},
#   {'date': '20230519',
#    'close': 57900,
#    'sign': '2',
#    'change': 700,
#    'diff': '1.22',
#    'volume': 1375866,
#    'krx_0008': 12947096,
#    'krx_0018': -560525,
#    'krx_0009': -12027611,
#    'pgmvol': 5484059048,
#    'fsc_listing': 116217927,
#    'fsc_sjrate': '26.18',
#    'fsc_0009': -11920347,
#    'gm_volume': 910286377,
#    'gm_value': 2019923},
#   {'date': '20230518',
#    'close': 57200,
#    'sign': '5',
#    'change': -500,
#    'diff': '-0.87',
#    'volume': 1112295,
#    'krx_0008': 13306354,
#    'krx_0018': -797522,
#    'krx_0009': -12159998,
#    'pgmvol': 5483879883,
#    'fsc_listing': 116150577,
#    'fsc_sjrate': '26.16',
#    'fsc_0009': -11987697,
#    'gm_volume': 910198057,
#    'gm_value': 2014874},
#   {'date': '20230517',
#    'close': 57700,
#    'sign': '2',
#    'change': 1600,
#    'diff': '2.85',
#    'volume': 2035175,
#    'krx_0008': 12953125,
#    'krx_0018': -703252,
#    'krx_0009': -11889949,
#    'pgmvol': 5484100015,
#    'fsc_listing': 116411088,
#    'fsc_sjrate': '26.22',
#    'fsc_0009': -11727186,
#    'gm_volume': 910080854,
#    'gm_value': 2008194},
#   {'date': '20230516',
#    'close': 56100,
#    'sign': '5',
#    'change': -700,
#    'diff': '-1.23',
#    'volume': 922948,
#    'krx_0008': 13733843,
#    'krx_0018': -1379702,
#    'krx_0009': -12003772,
#    'pgmvol': 5483926511,
#    'fsc_listing': 116297265,
#    'fsc_sjrate': '26.08',
#    'fsc_0009': -11841009,
#    'gm_volume': 909996155,
#    'gm_value': 2003410},
#   {'date': '20230515',
#    'close': 56800,
#    'sign': '2',
#    'change': 200,
#    'diff': '0.35',
#    'volume': 879909,
#    'krx_0008': 13529012,
#    'krx_0018': -1293047,
#    'krx_0009': -11877349,
#    'pgmvol': 5484072296,
#    'fsc_listing': 116438328,
#    'fsc_sjrate': '26.12',
#    'fsc_0009': -11699946,
#    'gm_volume': 909917183,
#    'gm_value': 1998939},
#   {'date': '20230512',
#    'close': 56600,
#    'sign': '2',
#    'change': 600,
#    'diff': '1.07',
#    'volume': 1236080,
#    'krx_0008': 13576258,
#    'krx_0018': -1270995,
#    'krx_0009': -11941978,
#    'pgmvol': 5484083315,
#    'fsc_listing': 116433199,
#    'fsc_sjrate': '26.12',
#    'fsc_0009': -11705075,
#    'gm_volume': 909862990,
#    'gm_value': 1995869},
#   {'date': '20230511',
#    'close': 56000,
#    'sign': '5',
#    'change': -500,
#    'diff': '-0.88',
#    'volume': 1190339,
#    'krx_0008': 13810398,
#    'krx_0018': -1294573,
#    'krx_0009': -12153399,
#    'pgmvol': 5483892496,
#    'fsc_listing': 116223178,
#    'fsc_sjrate': '26.07',
#    'fsc_0009': -11915096,
#    'gm_volume': 909749943,
#    'gm_value': 1989468},
#   {'date': '20230510',
#    'close': 56500,
#    'sign': '5',
#    'change': -1000,
#    'diff': '-1.74',
#    'volume': 1364811,
#    'krx_0008': 13623740,
#    'krx_0018': -1175345,
#    'krx_0009': -12083022,
#    'pgmvol': 5483871566,
#    'fsc_listing': 116293555,
#    'fsc_sjrate': '26.09',
#    'fsc_0009': -11844719,
#    'gm_volume': 909625555,
#    'gm_value': 1982412},
#   {'date': '20230509',
#    'close': 57500,
#    'sign': '5',
#    'change': -200,
#    'diff': '-0.35',
#    'volume': 1412568,
#    'krx_0008': 13254280,
#    'krx_0018': -921846,
#    'krx_0009': -11963530,
#    'pgmvol': 5484066119,
#    'fsc_listing': 116413047,
#    'fsc_sjrate': '26.12',
#    'fsc_0009': -11725227,
#    'gm_volume': 909555679,
#    'gm_value': 1978381},
#   {'date': '20230508',
#    'close': 57700,
#    'sign': '2',
#    'change': 500,
#    'diff': '0.87',
#    'volume': 1821528,
#    'krx_0008': 13080672,
#    'krx_0018': -768831,
#    'krx_0009': -11945069,
#    'pgmvol': 5483993743,
#    'fsc_listing': 116424504,
#    'fsc_sjrate': '26.12',
#    'fsc_0009': -11713770,
#    'gm_volume': 909446491,
#    'gm_value': 1972079},
#   {'date': '20230504',
#    'close': 57200,
#    'sign': '5',
#    'change': -1100,
#    'diff': '-1.89',
#    'volume': 2285474,
#    'krx_0008': 13106113,
#    'krx_0018': -888811,
#    'krx_0009': -11844871,
#    'pgmvol': 5484038438,
#    'fsc_listing': 116560464,
#    'fsc_sjrate': '26.15',
#    'fsc_0009': -11577810,
#    'gm_volume': 909163783,
#    'gm_value': 1956038},
#   {'date': '20230503',
#    'close': 58300,
#    'sign': '5',
#    'change': -200,
#    'diff': '-0.34',
#    'volume': 1047114,
#    'krx_0008': 12601665,
#    'krx_0018': -354246,
#    'krx_0009': -11869866,
#    'pgmvol': 5484187582,
#    'fsc_listing': 116587299,
#    'fsc_sjrate': '26.16',
#    'fsc_0009': -11550975,
#    'gm_volume': 909014054,
#    'gm_value': 1947304},
#   {'date': '20230502',
#    'close': 58500,
#    'sign': '2',
#    'change': 400,
#    'diff': '0.69',
#    'volume': 1124552,
#    'krx_0008': 12591465,
#    'krx_0018': -397538,
#    'krx_0009': -11830688,
#    'pgmvol': 5484101955,
#    'fsc_listing': 116626437,
#    'fsc_sjrate': '26.17',
#    'fsc_0009': -11511837,
#    'gm_volume': 908922493,
#    'gm_value': 1941976},
#   {'date': '20230428',
#    'close': 58100,
#    'sign': '2',
#    'change': 2300,
#    'diff': '4.12',
#    'volume': 3118097,
#    'krx_0008': 12804763,
#    'krx_0018': -556287,
#    'krx_0009': -11881472,
#    'pgmvol': 5484067682,
#    'fsc_listing': 116590593,
#    'fsc_sjrate': '26.16',
#    'fsc_0009': -11547681,
#    'gm_volume': 908798212,
#    'gm_value': 1934775},
#   {'date': '20230427',
#    'close': 55800,
#    'sign': '5',
#    'change': -700,
#    'diff': '-1.24',
#    'volume': 1311670,
#    'krx_0008': 13944384,
#    'krx_0018': -1407757,
#    'krx_0009': -12181576,
#    'pgmvol': 5483706742,
#    'fsc_listing': 116432082,
#    'fsc_sjrate': '26.13',
#    'fsc_0009': -11706192,
#    'gm_volume': 908652907,
#    'gm_value': 1926687},
#   {'date': '20230426',
#    'close': 56500,
#    'sign': '2',
#    'change': 500,
#    'diff': '0.89',
#    'volume': 1452179,
#    'krx_0008': 13695920,
#    'krx_0018': -1064009,
#    'krx_0009': -12273232,
#    'pgmvol': 5483634497,
#    'fsc_listing': 116377010,
#    'fsc_sjrate': '26.11',
#    'fsc_0009': -11761264,
#    'gm_volume': 908465535,
#    'gm_value': 1916122},
#   {'date': '20230425',
#    'close': 56000,
#    'sign': '5',
#    'change': -1200,
#    'diff': '-2.10',
#    'volume': 1791028,
#    'krx_0008': 13659242,
#    'krx_0018': -874429,
#    'krx_0009': -12429078,
#    'pgmvol': 5483318830,
#    'fsc_listing': 116208787,
#    'fsc_sjrate': '26.08',
#    'fsc_0009': -11929487,
#    'gm_volume': 908334186,
#    'gm_value': 1908718},
#   {'date': '20230424',
#    'close': 57200,
#    'sign': '5',
#    'change': -700,
#    'diff': '-1.21',
#    'volume': 961915,
#    'krx_0008': 13377676,
#    'krx_0018': -729940,
#    'krx_0009': -12401193,
#    'pgmvol': 5483285970,
#    'fsc_listing': 116214874,
#    'fsc_sjrate': '26.08',
#    'fsc_0009': -11923400,
#    'gm_volume': 908215768,
#    'gm_value': 1901927},
#   {'date': '20230421',
#    'close': 57900,
#    'sign': '3',
#    'change': 0,
#    'diff': '0.00',
#    'volume': 1212125,
#    'krx_0008': 13330185,
#    'krx_0018': -736182,
#    'krx_0009': -12348857,
#    'pgmvol': 5483368712,
#    'fsc_listing': 116195810,
#    'fsc_sjrate': '26.07',
#    'fsc_0009': -11942464,
#    'gm_volume': 908084087,
#    'gm_value': 1894324},
#   {'date': '20230420',
#    'close': 57900,
#    'sign': '5',
#    'change': -700,
#    'diff': '-1.19',
#    'volume': 1322250,
#    'krx_0008': 13352414,
#    'krx_0018': -766385,
#    'krx_0009': -12341375,
#    'pgmvol': 5483378754,
#    'fsc_listing': 116208614,
#    'fsc_sjrate': '26.08',
#    'fsc_0009': -11929660,
#    'gm_volume': 907946199,
#    'gm_value': 1886303},
#   {'date': '20230419',
#    'close': 58600,
#    'sign': '5',
#    'change': -400,
#    'diff': '-0.68',
#    'volume': 1086274,
#    'krx_0008': 13120767,
#    'krx_0018': -745799,
#    'krx_0009': -12128969,
#    'pgmvol': 5483449257,
#    'fsc_listing': 116435403,
#    'fsc_sjrate': '26.13',
#    'fsc_0009': -11702871,
#    'gm_volume': 907891425,
#    'gm_value': 1883084},
#   {'date': '20230418',
#    'close': 59000,
#    'sign': '5',
#    'change': -1100,
#    'diff': '-1.83',
#    'volume': 1731564,
#    'krx_0008': 12913586,
#    'krx_0018': -631630,
#    'krx_0009': -12048380,
#    'pgmvol': 5483538858,
#    'fsc_listing': 116536640,
#    'fsc_sjrate': '26.15',
#    'fsc_0009': -11601634,
#    'gm_volume': 907759139,
#    'gm_value': 1875258},
#   {'date': '20230417',
#    'close': 60100,
#    'sign': '5',
#    'change': -400,
#    'diff': '-0.66',
#    'volume': 1450046,
#    'krx_0008': 12481883,
#    'krx_0018': -232812,
#    'krx_0009': -12016731,
#    'pgmvol': 5483767904,
#    'fsc_listing': 116609610,
#    'fsc_sjrate': '26.17',
#    'fsc_0009': -11528664,
#    'gm_volume': 907679537,
#    'gm_value': 1870487},
#   {'date': '20230414',
#    'close': 60500,
#    'sign': '2',
#    'change': 1000,
#    'diff': '1.68',
#    'volume': 2464952,
#    'krx_0008': 12352523,
#    'krx_0018': -84458,
#    'krx_0009': -12028331,
#    'pgmvol': 5483822982,
#    'fsc_listing': 116649256,
#    'fsc_sjrate': '26.17',
#    'fsc_0009': -11489018,
#    'gm_volume': 907596996,
#    'gm_value': 1865523},
#   {'date': '20230413',
#    'close': 59500,
#    'sign': '2',
#    'change': 800,
#    'diff': '1.36',
#    'volume': 1591961,
#    'krx_0008': 13116110,
#    'krx_0018': -272261,
#    'krx_0009': -12498825,
#    'pgmvol': 5483412184,
#    'fsc_listing': 116174273,
#    'fsc_sjrate': '26.07',
#    'fsc_0009': -11964001,
#    'gm_volume': 907511053,
#    'gm_value': 1860443},
#   {'date': '20230412',
#    'close': 58700,
#    'sign': '5',
#    'change': -600,
#    'diff': '-1.01',
#    'volume': 1486194,
#    'krx_0008': 13357083,
#    'krx_0018': -603042,
#    'krx_0009': -12417817,
#    'pgmvol': 5483412506,
#    'fsc_listing': 116255281,
#    'fsc_sjrate': '26.09',
#    'fsc_0009': -11882993,
#    'gm_volume': 907355365,
#    'gm_value': 1851289},
#   {'date': '20230411',
#    'close': 59300,
#    'sign': '2',
#    'change': 1200,
#    'diff': '2.07',
#    'volume': 2184527,
#    'krx_0008': 13210486,
#    'krx_0018': -450336,
#    'krx_0009': -12458707,
#    'pgmvol': 5483383452,
#    'fsc_listing': 116131687,
#    'fsc_sjrate': '26.06',
#    'fsc_0009': -12006587,
#    'gm_volume': 907225598,
#    'gm_value': 1843641},
#   {'date': '20230410',
#    'close': 58100,
#    'sign': '5',
#    'change': -500,
#    'diff': '-0.85',
#    'volume': 2103339,
#    'krx_0008': 13619727,
#    'krx_0018': -825737,
#    'krx_0009': -12508164,
#    'pgmvol': 5483336645,
#    'fsc_listing': 116132230,
#    'fsc_sjrate': '26.06',
#    'fsc_0009': -12006044,
#    'gm_volume': 907030014,
#    'gm_value': 1832317},
#   {'date': '20230407',
#    'close': 58600,
#    'sign': '3',
#    'change': 0,
#    'diff': '0.00',
#    'volume': 1650319,
#    'krx_0008': 13747926,
#    'krx_0018': -828519,
#    'krx_0009': -12614468,
#    'pgmvol': 5483361540,
#    'fsc_listing': 116046514,
#    'fsc_sjrate': '26.04',
#    'fsc_0009': -12091760,
#    'gm_volume': 906627520,
#    'gm_value': 1808679},
#   {'date': '20230406',
#    'close': 58600,
#    'sign': '5',
#    'change': -1900,
#    'diff': '-3.14',
#    'volume': 2659408,
#    'krx_0008': 13332180,
#    'krx_0018': -603376,
#    'krx_0009': -12417887,
#    'pgmvol': 5483555436,
#    'fsc_listing': 116201627,
#    'fsc_sjrate': '26.07',
#    'fsc_0009': -11936647,
#    'gm_volume': 906329348,
#    'gm_value': 1791094},
#   {'date': '20230405',
#    'close': 60500,
#    'sign': '5',
#    'change': -200,
#    'diff': '-0.33',
#    'volume': 1227329,
#    'krx_0008': 12048891,
#    'krx_0018': 164347,
#    'krx_0009': -11879956,
#    'pgmvol': 5484023391,
#    'fsc_listing': 116791853,
#    'fsc_sjrate': '26.21',
#    'fsc_0009': -11346421,
#    'gm_volume': 906227621,
#    'gm_value': 1784937},
#   {'date': '20230404',
#    'close': 60700,
#    'sign': '2',
#    'change': 500,
#    'diff': '0.83',
#    'volume': 1380518,
#    'krx_0008': 12143767,
#    'krx_0018': 272766,
#    'krx_0009': -12076371,
#    'pgmvol': 5483788795,
#    'fsc_listing': 116641449,
#    'fsc_sjrate': '26.18',
#    'fsc_0009': -11496825,
#    'gm_volume': 906007498,
#    'gm_value': 1771666},
#   {'date': '20230403',
#    'close': 60200,
#    'sign': '5',
#    'change': -900,
#    'diff': '-1.47',
#    'volume': 1683150,
#    'krx_0008': 12336160,
#    'krx_0018': 271830,
#    'krx_0009': -12263740,
#    'pgmvol': 5483583958,
#    'fsc_listing': 116565499,
#    'fsc_sjrate': '26.16',
#    'fsc_0009': -11572775,
#    'gm_volume': 905883128,
#    'gm_value': 1764145},
#   {'date': '20230331',
#    'close': 61100,
#    'sign': '2',
#    'change': 1000,
#    'diff': '1.66',
#    'volume': 1745559,
#    'krx_0008': 12044014,
#    'krx_0018': 591002,
#    'krx_0009': -12288970,
#    'pgmvol': 5483630956,
#    'fsc_listing': 116458652,
#    'fsc_sjrate': '26.14',
#    'fsc_0009': -11679622,
#    'gm_volume': 905817082,
#    'gm_value': 1760134},
#   {'date': '20230330',
#    'close': 60100,
#    'sign': '5',
#    'change': -300,
#    'diff': '-0.50',
#    'volume': 1707493,
#    'krx_0008': 12502789,
#    'krx_0018': 521838,
#    'krx_0009': -12678202,
#    'pgmvol': 5483269168,
#    'fsc_listing': 116004975,
#    'fsc_sjrate': '26.03',
#    'fsc_0009': -12133299,
#    'gm_volume': 905782086,
#    'gm_value': 1758025},
#   {'date': '20230329',
#    'close': 60400,
#    'sign': '5',
#    'change': -300,
#    'diff': '-0.49',
#    'volume': 1144119,
#    'krx_0008': 12281656,
#    'krx_0018': 697624,
#    'krx_0009': -12692414,
#    'pgmvol': 5483280932,
#    'fsc_listing': 116282618,
#    'fsc_sjrate': '26.10',
#    'fsc_0009': -11855656,
#    'gm_volume': 905756696,
#    'gm_value': 1756491},
#   {'date': '20230328',
#    'close': 60700,
#    'sign': '3',
#    'change': 0,
#    'diff': '0.00',
#    'volume': 1326335,
#    'krx_0008': 12279789,
#    'krx_0018': 773926,
#    'krx_0009': -12773654,
#    'pgmvol': 5483272177,
#    'fsc_listing': 116067577,
#    'fsc_sjrate': '26.05',
#    'fsc_0009': -12070697,
#    'gm_volume': 905654171,
#    'gm_value': 1750298},
#   {'date': '20230327',
#    'close': 60700,
#    'sign': '5',
#    'change': -700,
#    'diff': '-1.14',
#    'volume': 1490544,
#    'krx_0008': 12149161,
#    'krx_0018': 804782,
#    'krx_0009': -12720905,
#    'pgmvol': 5483314075,
#    'fsc_listing': 116120326,
#    'fsc_sjrate': '26.06',
#    'fsc_0009': -12017948,
#    'gm_volume': 905606797,
#    'gm_value': 1747438},
#   {'date': '20230324',
#    'close': 61400,
#    'sign': '5',
#    'change': -200,
#    'diff': '-0.32',
#    'volume': 1323550,
#    'krx_0008': 12119785,
#    'krx_0018': 765066,
#    'krx_0009': -12823261,
#    'pgmvol': 5483161068,
#    'fsc_listing': 115507970,
#    'fsc_sjrate': '25.92',
#    'fsc_0009': -12630304,
#    'gm_volume': 905599759,
#    'gm_value': 1747004},
#   {'date': '20230323',
#    'close': 61600,
#    'sign': '5',
#    'change': -1100,
#    'diff': '-1.75',
#    'volume': 1685484,
#    'krx_0008': 12188284,
#    'krx_0018': 785158,
#    'krx_0009': -13001702,
#    'pgmvol': 5482997357,
#    'fsc_listing': 115329529,
#    'fsc_sjrate': '25.88',
#    'fsc_0009': -12808745,
#    'gm_volume': 905472604,
#    'gm_value': 1739199},
#   {'date': '20230322',
#    'close': 62700,
#    'sign': '2',
#    'change': 1800,
#    'diff': '2.96',
#    'volume': 2243729,
#    'krx_0008': 12015861,
#    'krx_0018': 930271,
#    'krx_0009': -13001028,
#    'pgmvol': 5483038024,
#    'fsc_listing': 114830203,
#    'fsc_sjrate': '25.77',
#    'fsc_0009': -13308071,
#    'gm_volume': 905451203,
#    'gm_value': 1737871},
#   {'date': '20230321',
#    'close': 60900,
#    'sign': '5',
#    'change': -100,
#    'diff': '-0.16',
#    'volume': 1093952,
#    'krx_0008': 12822581,
#    'krx_0018': 477545,
#    'krx_0009': -13446342,
#    'pgmvol': 5482610365,
#    'fsc_listing': 114384889,
#    'fsc_sjrate': '25.67',
#    'fsc_0009': -13753385,
#    'gm_volume': 905405104,
#    'gm_value': 1735063},
#   {'date': '20230320',
#    'close': 61000,
#    'sign': '2',
#    'change': 800,
#    'diff': '1.33',
#    'volume': 2051491,
#    'krx_0008': 12946511,
#    'krx_0018': 433697,
#    'krx_0009': -13525651,
#    'pgmvol': 5482557847,
#    'fsc_listing': 114262294,
#    'fsc_sjrate': '25.64',
#    'fsc_0009': -13875980,
#    'gm_volume': 905315408,
#    'gm_value': 1729588},
#   {'date': '20230317',
#    'close': 60200,
#    'sign': '2',
#    'change': 300,
#    'diff': '0.50',
#    'volume': 1658278,
#    'krx_0008': 13471610,
#    'krx_0018': -34733,
#    'krx_0009': -13578420,
#    'pgmvol': 5482499310,
#    'fsc_listing': 114209525,
#    'fsc_sjrate': '25.63',
#    'fsc_0009': -13928749,
#    'gm_volume': 905233314,
#    'gm_value': 1724646},
#   {'date': '20230316',
#    'close': 59900,
#    'sign': '2',
#    'change': 600,
#    'diff': '1.01',
#    'volume': 1976894,
#    'krx_0008': 13565988,
#    'krx_0018': -166293,
#    'krx_0009': -13604494,
#    'pgmvol': 5482464186,
#    'fsc_listing': 114183451,
#    'fsc_sjrate': '25.63',
#    'fsc_0009': -13954823,
#    'gm_volume': 905154362,
#    'gm_value': 1719967},
#   {'date': '20230315',
#    'close': 59300,
#    'sign': '5',
#    'change': -100,
#    'diff': '-0.17',
#    'volume': 1885060,
#    'krx_0008': 14124990,
#    'krx_0018': -430567,
#    'krx_0009': -13922027,
#    'pgmvol': 5482127583,
#    'fsc_listing': 113857948,
#    'fsc_sjrate': '25.55',
#    'fsc_0009': -14280326,
#    'gm_volume': 904992483,
#    'gm_value': 1710341},
#   {'date': '20230314',
#    'close': 59400,
#    'sign': '5',
#    'change': -1400,
#    'diff': '-2.30',
#    'volume': 2165223,
#    'krx_0008': 13778688,
#    'krx_0018': -542727,
#    'krx_0009': -13456561,
#    'pgmvol': 5482568394,
#    'fsc_listing': 114432414,
#    'fsc_sjrate': '25.68',
#    'fsc_0009': -13705860,
#    'gm_volume': 904806947,
#    'gm_value': 1699179},
#   {'date': '20230313',
#    'close': 60800,
#    'sign': '2',
#    'change': 2700,
#    'diff': '4.65',
#    'volume': 5720123,
#    'krx_0008': 13572282,
#    'krx_0018': -628803,
#    'krx_0009': -13163567,
#    'pgmvol': 5482750002,
#    'fsc_listing': 114731922,
#    'fsc_sjrate': '25.75',
#    'fsc_0009': -13406352,
#    'gm_volume': 904304829,
#    'gm_value': 1669009},
#   {'date': '20230310',
#    'close': 58100,
#    'sign': '5',
#    'change': -900,
#    'diff': '-1.53',
#    'volume': 2009728,
#    'krx_0008': 13366138,
#    'krx_0018': -557272,
#    'krx_0009': -13045346,
#    'pgmvol': 5482604918,
#    'fsc_listing': 114964031,
#    'fsc_sjrate': '25.80',
#    'fsc_0009': -13174243,
#    'gm_volume': 904011514,
#    'gm_value': 1652026},
#   {'date': '20230309',
#    'close': 59000,
#    'sign': '5',
#    'change': -100,
#    'diff': '-0.17',
#    'volume': 1941341,
#    'krx_0008': 12909099,
#    'krx_0018': -271720,
#    'krx_0009': -12858162,
#    'pgmvol': 5482534217,
#    'fsc_listing': 115017215,
#    'fsc_sjrate': '25.81',
#    'fsc_0009': -13121059,
#    'gm_volume': 903829814,
#    'gm_value': 1641225},
#   {'date': '20230308',
#    'close': 59100,
#    'sign': '5',
#    'change': -2400,
#    'diff': '-3.90',
#    'volume': 2920456,
#    'krx_0008': 12396565,
#    'krx_0018': -242123,
#    'krx_0009': -12340298,
#    'pgmvol': 5482849239,
#    'fsc_listing': 115611079,
#    'fsc_sjrate': '25.95',
#    'fsc_0009': -12527195,
#    'gm_volume': 903296318,
#    'gm_value': 1609447},
#   {'date': '20230307',
#    'close': 61500,
#    'sign': '5',
#    'change': -2100,
#    'diff': '-3.30',
#    'volume': 2322926,
#    'krx_0008': 11026268,
#    'krx_0018': 567922,
#    'krx_0009': -11893262,
#    'pgmvol': 5483287525,
#    'fsc_listing': 116058606,
#    'fsc_sjrate': '26.05',
#    'fsc_0009': -12079668,
#    'gm_volume': 902947740,
#    'gm_value': 1587887},
#   {'date': '20230306',
#    'close': 63600,
#    'sign': '2',
#    'change': 2600,
#    'diff': '4.26',
#    'volume': 2768767,
#    'krx_0008': 10085923,
#    'krx_0018': 1030164,
#    'krx_0009': -11411409,
#    'pgmvol': 5483796252,
#    'fsc_listing': 116730459,
#    'fsc_sjrate': '26.20',
#    'fsc_0009': -11407815,
#    'gm_volume': 902891372,
#    'gm_value': 1584323},
#   {'date': '20230303',
#    'close': 61000,
#    'sign': '5',
#    'change': -200,
#    'diff': '-0.33',
#    'volume': 1250945,
#    'krx_0008': 11223994,
#    'krx_0018': 569411,
#    'krx_0009': -12108185,
#    'pgmvol': 5483101264,
#    'fsc_listing': 115841683,
#    'fsc_sjrate': '26.00',
#    'fsc_0009': -12296591,
#    'gm_volume': 902782801,
#    'gm_value': 1577674},
#   {'date': '20230302',
#    'close': 61200,
#    'sign': '5',
#    'change': -1200,
#    'diff': '-1.92',
#    'volume': 1842975,
#    'krx_0008': 10955008,
#    'krx_0018': 637547,
#    'krx_0009': -11873092,
#    'pgmvol': 5483371401,
#    'fsc_listing': 116176776,
#    'fsc_sjrate': '26.08',
#    'fsc_0009': -11961498,
#    'gm_volume': 902599602,
#    'gm_value': 1566428},
#   {'date': '20230228',
#    'close': 62400,
#    'sign': '2',
#    'change': 500,
#    'diff': '0.81',
#    'volume': 1808156,
#    'krx_0008': 10503454,
#    'krx_0018': 999517,
#    'krx_0009': -11536377,
#    'pgmvol': 5483727860,
#    'fsc_listing': 116483123,
#    'fsc_sjrate': '26.15',
#    'fsc_0009': -11655151,
#    'gm_volume': 902472314,
#    'gm_value': 1558463},
#   {'date': '20230227',
#    'close': 61900,
#    'sign': '2',
#    'change': 100,
#    'diff': '0.16',
#    'volume': 1407458,
#    'krx_0008': 10813713,
#    'krx_0018': 728931,
#    'krx_0009': -11527893,
#    'pgmvol': 5483873608,
#    'fsc_listing': 116491607,
#    'fsc_sjrate': '26.15',
#    'fsc_0009': -11646667,
#    'gm_volume': 902343305,
#    'gm_value': 1550524},
#   {'date': '20230224',
#    'close': 61800,
#    'sign': '5',
#    'change': -700,
#    'diff': '-1.12',
#    'volume': 1339514,
#    'krx_0008': 10723752,
#    'krx_0018': 840841,
#    'krx_0009': -11551274,
#    'pgmvol': 5483863093,
#    'fsc_listing': 116377753,
#    'fsc_sjrate': '26.12',
#    'fsc_0009': -11760521,
#    'gm_volume': 902225884,
#    'gm_value': 1543231},
#   {'date': '20230223',
#    'close': 62500,
#    'sign': '2',
#    'change': 300,
#    'diff': '0.48',
#    'volume': 1217488,
#    'krx_0008': 10530755,
#    'krx_0018': 823459,
#    'krx_0009': -11336833,
#    'pgmvol': 5484068294,
#    'fsc_listing': 116580194,
#    'fsc_sjrate': '26.17',
#    'fsc_0009': -11558080,
#    'gm_volume': 902126207,
#    'gm_value': 1536985},
#   {'date': '20230222',
#    'close': 62200,
#    'sign': '5',
#    'change': -900,
#    'diff': '-1.43',
#    'volume': 1904538,
#    'krx_0008': 10551767,
#    'krx_0018': 702785,
#    'krx_0009': -11222547,
#    'pgmvol': 5484175776,
#    'fsc_listing': 116716480,
#    'fsc_sjrate': '26.20',
#    'fsc_0009': -11421794,
#    'gm_volume': 901801517,
#    'gm_value': 1516849},
#   {'date': '20230221',
#    'close': 63100,
#    'sign': '5',
#    'change': -1100,
#    'diff': '-1.71',
#    'volume': 1644407,
#    'krx_0008': 10248018,
#    'krx_0018': 1033416,
#    'krx_0009': -11371746,
#    'pgmvol': 5484089696,
#    'fsc_listing': 116667281,
#    'fsc_sjrate': '26.19',
#    'fsc_0009': -11470993,
#    'gm_volume': 901655459,
#    'gm_value': 1507591},
#   {'date': '20230220',
#    'close': 64200,
#    'sign': '2',
#    'change': 900,
#    'diff': '1.42',
#    'volume': 1424392,
#    'krx_0008': 9604213,
#    'krx_0018': 1369820,
#    'krx_0009': -11184240,
#    'pgmvol': 5484366075,
#    'fsc_listing': 116749713,
#    'fsc_sjrate': '26.21',
#    'fsc_0009': -11388561,
#    'gm_volume': 901549970,
#    'gm_value': 1500841},
#   {'date': '20230217',
#    'close': 63300,
#    'sign': '5',
#    'change': -900,
#    'diff': '-1.40',
#    'volume': 1584836,
#    'krx_0008': 9858014,
#    'krx_0018': 1243883,
#    'krx_0009': -11289703,
#    'pgmvol': 5484267078,
#    'fsc_listing': 116624270,
#    'fsc_sjrate': '26.18',
#    'fsc_0009': -11514004,
#    'gm_volume': 901309896,
#    'gm_value': 1485610},
#   {'date': '20230216',
#    'close': 64200,
#    'sign': '2',
#    'change': 600,
#    'diff': '0.94',
#    'volume': 2542941,
#    'krx_0008': 9682581,
#    'krx_0018': 1519223,
#    'krx_0009': -11367952,
#    'pgmvol': 5484216240,
#    'fsc_listing': 116545521,
#    'fsc_sjrate': '26.16',
#    'fsc_0009': -11592753,
#    'gm_volume': 900998603,
#    'gm_value': 1465605},
#   {'date': '20230215',
#    'close': 63600,
#    'sign': '5',
#    'change': -1400,
#    'diff': '-2.15',
#    'volume': 2984239,
#    'krx_0008': 9347259,
#    'krx_0018': 1290309,
#    'krx_0009': -10793632,
#    'pgmvol': 5484773813,
#    'fsc_listing': 117084851,
#    'fsc_sjrate': '26.28',
#    'fsc_0009': -11053423,
#    'gm_volume': 900531036,
#    'gm_value': 1436035},
#   {'date': '20230214',
#    'close': 65000,
#    'sign': '2',
#    'change': 700,
#    'diff': '1.09',
#    'volume': 2249182,
#    'krx_0008': 9010505,
#    'krx_0018': 1687593,
#    'krx_0009': -10892085,
#    'pgmvol': 5484694618,
#    'fsc_listing': 116984398,
#    'fsc_sjrate': '26.26',
#    'fsc_0009': -11153876,
#    'gm_volume': 900340517,
#    'gm_value': 1423581},
#   {'date': '20230213',
#    'close': 64300,
#    'sign': '5',
#    'change': -3300,
#    'diff': '-4.88',
#    'volume': 4298565,
#    'krx_0008': 8956637,
#    'krx_0018': 1689730,
#    'krx_0009': -10854138,
#    'pgmvol': 5484739480,
#    'fsc_listing': 116812345,
#    'fsc_sjrate': '26.22',
#    'fsc_0009': -11325929,
#    'gm_volume': 899890019,
#    'gm_value': 1394338},
#   {'date': '20230210',
#    'close': 67600,
#    'sign': '5',
#    'change': -3300,
#    'diff': '-4.65',
#    'volume': 5370780,
#    'krx_0008': 7323220,
#    'krx_0018': 2719918,
#    'krx_0009': -10345488,
#    'pgmvol': 5485260398,
#    'fsc_listing': 116974985,
#    'fsc_sjrate': '26.26',
#    'fsc_0009': -11163289,
#    'gm_volume': 899028118,
#    'gm_value': 1335694},
#   {'date': '20230209',
#    'close': 70900,
#    'sign': '2',
#    'change': 1800,
#    'diff': '2.60',
#    'volume': 3602387,
#    'krx_0008': 5276813,
#    'krx_0018': 3923038,
#    'krx_0009': -9441910,
#    'pgmvol': 5486271651,
#    'fsc_listing': 117834030,
#    'fsc_sjrate': '26.45',
#    'fsc_0009': -10304244,
#    'gm_volume': 898612691,
#    'gm_value': 1307174},
#   {'date': '20230208',
#    'close': 69100,
#    'sign': '2',
#    'change': 1100,
#    'diff': '1.62',
#    'volume': 3109216,
#    'krx_0008': 5464426,
#    'krx_0018': 3489238,
#    'krx_0009': -9301019,
#    'pgmvol': 5486439658,
#    'fsc_listing': 117974921,
#    'fsc_sjrate': '26.49',
#    'fsc_0009': -10163353,
#    'gm_volume': 898295842,
#    'gm_value': 1285277},
#   {'date': '20230207',
#    'close': 68000,
#    'sign': '2',
#    'change': 2800,
#    'diff': '4.29',
#    'volume': 3026310,
#    'krx_0008': 5314666,
#    'krx_0018': 3291898,
#    'krx_0009': -8948431,
#    'pgmvol': 5486877047,
#    'fsc_listing': 118127509,
#    'fsc_sjrate': '26.52',
#    'fsc_0009': -10010765,
#    'gm_volume': 898089353,
#    'gm_value': 1271483},
#   {'date': '20230206',
#    'close': 65200,
#    'sign': '5',
#    'change': -2000,
#    'diff': '-2.98',
#    'volume': 2276799,
#    'krx_0008': 5631310,
#    'krx_0018': 3011137,
#    'krx_0009': -8990590,
#    'pgmvol': 5486881059,
#    'fsc_listing': 118088506,
#    'fsc_sjrate': '26.51',
#    'fsc_0009': -10049768,
#    'gm_volume': 897886218,
#    'gm_value': 1258063},
#   {'date': '20230203',
#    'close': 67200,
#    'sign': '2',
#    'change': 2700,
#    'diff': '4.19',
#    'volume': 5019685,
#    'krx_0008': 5063483,
#    'krx_0018': 3431693,
#    'krx_0009': -8764743,
#    'pgmvol': 5487161757,
#    'fsc_listing': 118314353,
#    'fsc_sjrate': '26.56',
#    'fsc_0009': -9823921,
#    'gm_volume': 897728312,
#    'gm_value': 1247566},
#   {'date': '20230202',
#    'close': 64500,
#    'sign': '2',
#    'change': 2300,
#    'diff': '3.70',
#    'volume': 2933831,
#    'krx_0008': 5972919,
#    'krx_0018': 2760764,
#    'krx_0009': -8959207,
#    'pgmvol': 5486915058,
#    'fsc_listing': 118119889,
#    'fsc_sjrate': '26.52',
#    'fsc_0009': -10018385,
#    'gm_volume': 897645249,
#    'gm_value': 1242203},
#   {'date': '20230201',
#    'close': 62200,
#    'sign': '2',
#    'change': 800,
#    'diff': '1.30',
#    'volume': 1579766,
#    'krx_0008': 6857360,
#    'krx_0018': 2252217,
#    'krx_0009': -9332113,
#    'pgmvol': 5486451364,
#    'fsc_listing': 117728263,
#    'fsc_sjrate': '26.43',
#    'fsc_0009': -10410011,
#    'gm_volume': 897428082,
#    'gm_value': 1228760},
#   {'date': '20230131',
#    'close': 61400,
#    'sign': '5',
#    'change': -2100,
#    'diff': '-3.31',
#    'volume': 2390762,
#    'krx_0008': 6712957,
#    'krx_0018': 2662148,
#    'krx_0009': -9595676,
#    'pgmvol': 5486244564,
#    'fsc_listing': 117457212,
#    'fsc_sjrate': '26.37',
#    'fsc_0009': -10681062,
#    'gm_volume': 897121796,
#    'gm_value': 1209672},
#   {'date': '20230130',
#    'close': 63500,
#    'sign': '5',
#    'change': -1200,
#    'diff': '-1.85',
#    'volume': 1792146,
#    'krx_0008': 6068972,
#    'krx_0018': 2906772,
#    'krx_0009': -9200632,
#    'pgmvol': 5486384431,
#    'fsc_listing': 117990976,
#    'fsc_sjrate': '26.49',
#    'fsc_0009': -10147298,
#    'gm_volume': 896996229,
#    'gm_value': 1201661},
#   {'date': '20230127',
#    'close': 64700,
#    'sign': '2',
#    'change': 1000,
#    'diff': '1.57',
#    'volume': 2588030,
#    'krx_0008': 5804817,
#    'krx_0018': 3029235,
#    'krx_0009': -9061299,
#    'pgmvol': 5486500828,
#    'fsc_listing': 117990309,
#    'fsc_sjrate': '26.49',
#    'fsc_0009': -10147965,
#    'gm_volume': 896937097,
#    'gm_value': 1197847},
#   {'date': '20230126',
#    'close': 63700,
#    'sign': '2',
#    'change': 1100,
#    'diff': '1.76',
#    'volume': 1658008,
#    'krx_0008': 6101273,
#    'krx_0018': 2811848,
#    'krx_0009': -9144875,
#    'pgmvol': 5486412941,
#    'fsc_listing': 117916965,
#    'fsc_sjrate': '26.47',
#    'fsc_0009': -10221309,
#    'gm_volume': 896878945,
#    'gm_value': 1194185},
#   {'date': '20230125',
#    'close': 62600,
#    'sign': '2',
#    'change': 1400,
#    'diff': '2.29',
#    'volume': 2010088,
#    'krx_0008': 6296919,
#    'krx_0018': 2640497,
#    'krx_0009': -9157140,
#    'pgmvol': 5486398737,
#    'fsc_listing': 117893700,
#    'fsc_sjrate': '26.47',
#    'fsc_0009': -10244574,
#    'gm_volume': 896786529,
#    'gm_value': 1188376},
#   {'date': '20230120',
#    'close': 61200,
#    'sign': '2',
#    'change': 400,
#    'diff': '0.66',
#    'volume': 1376217,
#    'krx_0008': 6566755,
#    'krx_0018': 2376372,
#    'krx_0009': -9145088,
#    'pgmvol': 5486441530,
#    'fsc_listing': 117919752,
#    'fsc_sjrate': '26.47',
#    'fsc_0009': -10218522,
#    'gm_volume': 896658323,
#    'gm_value': 1180557},
#   {'date': '20230119',
#    'close': 60800,
#    'sign': '5',
#    'change': -800,
#    'diff': '-1.30',
#    'volume': 1687361,
#    'krx_0008': 6455035,
#    'krx_0018': 2286698,
#    'krx_0009': -8941780,
#    'pgmvol': 5486628386,
#    'fsc_listing': 118107060,
#    'fsc_sjrate': '26.52',
#    'fsc_0009': -10031214,
#    'gm_volume': 896540726,
#    'gm_value': 1173422},
#   {'date': '20230118',
#    'close': 61600,
#    'sign': '5',
#    'change': -200,
#    'diff': '-0.32',
#    'volume': 1650067,
#    'krx_0008': 6081521,
#    'krx_0018': 2671481,
#    'krx_0009': -8951103,
#    'pgmvol': 5486561995,
#    'fsc_listing': 118098468,
#    'fsc_sjrate': '26.51',
#    'fsc_0009': -10039806,
#    'gm_volume': 896457222,
#    'gm_value': 1168265},
#   {'date': '20230117',
#    'close': 61800,
#    'sign': '5',
#    'change': -2700,
#    'diff': '-4.19',
#    'volume': 3194397,
#    'krx_0008': 6030494,
#    'krx_0018': 2806302,
#    'krx_0009': -9034512,
#    'pgmvol': 5486552749,
#    'fsc_listing': 117812492,
#    'fsc_sjrate': '26.45',
#    'fsc_0009': -10325782,
#    'gm_volume': 896170677,
#    'gm_value': 1150398},
#   {'date': '20230116',
#    'close': 64500,
#    'sign': '2',
#    'change': 2500,
#    'diff': '4.03',
#    'volume': 2989321,
#    'krx_0008': 5217230,
#    'krx_0018': 3099529,
#    'krx_0009': -8471399,
#    'pgmvol': 5487101111,
#    'fsc_listing': 118375919,
#    'fsc_sjrate': '26.58',
#    'fsc_0009': -9762355,
#    'gm_volume': 896100275,
#    'gm_value': 1145877},
#   {'date': '20230113',
#    'close': 62000,
#    'sign': '2',
#    'change': 500,
#    'diff': '0.81',
#    'volume': 2248562,
#    'krx_0008': 5686713,
#    'krx_0018': 2698701,
#    'krx_0009': -8547580,
#    'pgmvol': 5487033936,
#    'fsc_listing': 118296342,
#    'fsc_sjrate': '26.56',
#    'fsc_0009': -9841932,
#    'gm_volume': 895809069,
#    'gm_value': 1127775},
#   {'date': '20230112',
#    'close': 61500,
#    'sign': '5',
#    'change': -400,
#    'diff': '-0.65',
#    'volume': 2197974,
#    'krx_0008': 5844457,
#    'krx_0018': 2490308,
#    'krx_0009': -8510947,
#    'pgmvol': 5487049684,
#    'fsc_listing': 118145353,
#    'fsc_sjrate': '26.52',
#    'fsc_0009': -9992921,
#    'gm_volume': 895693188,
#    'gm_value': 1120613},
#   {'date': '20230111',
#    'close': 61900,
#    'sign': '2',
#    'change': 1200,
#    'diff': '1.98',
#    'volume': 2544430,
#    'krx_0008': 5672530,
#    'krx_0018': 2824544,
#    'krx_0009': -8647321,
#    'pgmvol': 5487036508,
#    'fsc_listing': 118027979,
#    'fsc_sjrate': '26.50',
#    'fsc_0009': -10110295,
#    'gm_volume': 895506776,
#    'gm_value': 1109068},
#   {'date': '20230110',
#    'close': 60700,
#    'sign': '5',
#    'change': -400,
#    'diff': '-0.65',
#    'volume': 2178323,
#    'krx_0008': 6058891,
#    'krx_0018': 2243186,
#    'krx_0009': -8463829,
#    'pgmvol': 5487132780,
# ...
#    'gm_volume': 880676363,
#    'gm_value': 339820},
#   {'date': '20221004',
#    'close': 55900,
#    'sign': '5',
#    'change': -1200,
#    'diff': '-2.10',
#    'volume': 2220578,
#    'krx_0008': 3166418,
#    'krx_0018': 383064,
#    'krx_0009': -3773137,
#    'pgmvol': 5489253346,
#    'fsc_listing': 125286774,
#    'fsc_sjrate': '28.13',
#    'fsc_0009': -2851500,
#    'gm_volume': 880481743,
#    'gm_value': 328909},
#   {'date': '20220930',
#    'close': 57100,
#    'sign': '2',
#    'change': 1200,
#    'diff': '2.15',
#    'volume': 1882206,
#    'krx_0008': 2453520,
#    'krx_0018': 597042,
#    'krx_0009': -3265253,
#    'pgmvol': 5489503657,
#    'fsc_listing': 125668501,
#    'fsc_sjrate': '28.22',
#    'fsc_0009': -2469773,
#    'gm_volume': 880431060,
#    'gm_value': 326012},
#   {'date': '20220929',
#    'close': 55900,
#    'sign': '5',
#    'change': -1000,
#    'diff': '-1.76',
#    'volume': 2212133,
#    'krx_0008': 2976385,
#    'krx_0018': 438727,
#    'krx_0009': -3625355,
#    'pgmvol': 5489096863,
#    'fsc_listing': 125320793,
#    'fsc_sjrate': '28.14',
#    'fsc_0009': -2817481,
#    'gm_volume': 880368616,
#    'gm_value': 322440},
#   {'date': '20220928',
#    'close': 56900,
#    'sign': '5',
#    'change': -2400,
#    'diff': '-4.05',
#    'volume': 2387527,
#    'krx_0008': 3063049,
#    'krx_0018': 378114,
#    'krx_0009': -3653479,
#    'pgmvol': 5489134368,
#    'fsc_listing': 125271357,
#    'fsc_sjrate': '28.13',
#    'fsc_0009': -2866917,
#    'gm_volume': 880244198,
#    'gm_value': 315322},
#   {'date': '20220927',
#    'close': 59300,
#    'sign': '5',
#    'change': -400,
#    'diff': '-0.67',
#    'volume': 1807942,
#    'krx_0008': 2749134,
#    'krx_0018': 428376,
#    'krx_0009': -3488729,
#    'pgmvol': 5489108955,
#    'fsc_listing': 125378421,
#    'fsc_sjrate': '28.16',
#    'fsc_0009': -2759853,
#    'gm_volume': 880176326,
#    'gm_value': 311322},
#   {'date': '20220926',
#    'close': 59700,
#    'sign': '5',
#    'change': -1300,
#    'diff': '-2.13',
#    'volume': 1983320,
#    'krx_0008': 2620457,
#    'krx_0018': 366512,
#    'krx_0009': -3290860,
#    'pgmvol': 5489337084,
#    'fsc_listing': 125602602,
#    'fsc_sjrate': '28.21',
#    'fsc_0009': -2535672,
#    'gm_volume': 879962182,
#    'gm_value': 298530},
#   {'date': '20220923',
#    'close': 61000,
#    'sign': '5',
#    'change': -300,
#    'diff': '-0.49',
#    'volume': 1660303,
#    'krx_0008': 2865064,
#    'krx_0018': 259403,
#    'krx_0009': -3417308,
#    'pgmvol': 5489474845,
#    'fsc_listing': 125429105,
#    'fsc_sjrate': '28.17',
#    'fsc_0009': -2709169,
#    'gm_volume': 879840618,
#    'gm_value': 291084},
#   {'date': '20220922',
#    'close': 61300,
#    'sign': '5',
#    'change': -2700,
#    'diff': '-4.22',
#    'volume': 1743099,
#    'krx_0008': 2886463,
#    'krx_0018': 157864,
#    'krx_0009': -3338532,
#    'pgmvol': 5489681545,
#    'fsc_listing': 125501935,
#    'fsc_sjrate': '28.18',
#    'fsc_0009': -2636339,
#    'gm_volume': 879725679,
#    'gm_value': 284027},
#   {'date': '20220921',
#    'close': 64000,
#    'sign': '5',
#    'change': -1300,
#    'diff': '-1.99',
#    'volume': 1056852,
#    'krx_0008': 2433900,
#    'krx_0018': 482170,
#    'krx_0009': -3196904,
#    'pgmvol': 5489841399,
#    'fsc_listing': 125692916,
#    'fsc_sjrate': '28.23',
#    'fsc_0009': -2445358,
#    'gm_volume': 879662075,
#    'gm_value': 279955},
#   {'date': '20220920',
#    'close': 65300,
#    'sign': '5',
#    'change': -100,
#    'diff': '-0.15',
#    'volume': 854697,
#    'krx_0008': 2227064,
#    'krx_0018': 688801,
#    'krx_0009': -3163134,
#    'pgmvol': 5489865646,
#    'fsc_listing': 125740792,
#    'fsc_sjrate': '28.24',
#    'fsc_0009': -2397482,
#    'gm_volume': 879560759,
#    'gm_value': 273297},
#   {'date': '20220919',
#    'close': 65400,
#    'sign': '5',
#    'change': -1500,
#    'diff': '-2.24',
#    'volume': 1132357,
#    'krx_0008': 2211625,
#    'krx_0018': 667363,
#    'krx_0009': -3125458,
#    'pgmvol': 5489889225,
#    'fsc_listing': 125636796,
#    'fsc_sjrate': '28.21',
#    'fsc_0009': -2501478,
#    'gm_volume': 879427297,
#    'gm_value': 264541},
#   {'date': '20220916',
#    'close': 66900,
#    'sign': '5',
#    'change': -500,
#    'diff': '-0.74',
#    'volume': 922538,
#    'krx_0008': 1945590,
#    'krx_0018': 769826,
#    'krx_0009': -2960498,
#    'pgmvol': 5490016982,
#    'fsc_listing': 125793659,
#    'fsc_sjrate': '28.25',
#    'fsc_0009': -2344615,
#    'gm_volume': 879292457,
#    'gm_value': 255518},
#   {'date': '20220915',
#    'close': 67400,
#    'sign': '5',
#    'change': -700,
#    'diff': '-1.03',
#    'volume': 984996,
#    'krx_0008': 1872958,
#    'krx_0018': 867302,
#    'krx_0009': -2984932,
#    'pgmvol': 5490108348,
#    'fsc_listing': 125909472,
#    'fsc_sjrate': '28.27',
#    'fsc_0009': -2228802,
#    'gm_volume': 879241808,
#    'gm_value': 252072},
#   {'date': '20220914',
#    'close': 68100,
#    'sign': '5',
#    'change': -1900,
#    'diff': '-2.71',
#    'volume': 1827706,
#    'krx_0008': 1772657,
#    'krx_0018': 972438,
#    'krx_0009': -2986236,
#    'pgmvol': 5490200965,
#    'fsc_listing': 125988732,
#    'fsc_sjrate': '28.29',
#    'fsc_0009': -2149542,
#    'gm_volume': 879116337,
#    'gm_value': 243578},
#   {'date': '20220913',
#    'close': 70000,
#    'sign': '2',
#    'change': 2000,
#    'diff': '2.94',
#    'volume': 2103796,
#    'krx_0008': 1347858,
#    'krx_0018': 1224176,
#    'krx_0009': -2808274,
#    'pgmvol': 5490281849,
#    'fsc_listing': 126206066,
#    'fsc_sjrate': '28.34',
#    'fsc_0009': -1932208,
#    'gm_volume': 879058465,
#    'gm_value': 239540},
#   {'date': '20220908',
#    'close': 68000,
#    'sign': '2',
#    'change': 500,
#    'diff': '0.74',
#    'volume': 1169203,
#    'krx_0008': 1292942,
#    'krx_0018': 609960,
#    'krx_0009': -2138883,
#    'pgmvol': 5490020499,
#    'fsc_listing': 126875457,
#    'fsc_sjrate': '28.49',
#    'fsc_0009': -1262817,
#    'gm_volume': 879009664,
#    'gm_value': 236209},
#   {'date': '20220907',
#    'close': 67500,
#    'sign': '5',
#    'change': -2200,
#    'diff': '-3.16',
#    'volume': 1793068,
#    'krx_0008': 1357337,
#    'krx_0018': 433435,
#    'krx_0009': -2029920,
#    'pgmvol': 5490111981,
#    'fsc_listing': 126974420,
#    'fsc_sjrate': '28.52',
#    'fsc_0009': -1163854,
#    'gm_volume': 878780213,
#    'gm_value': 220674},
#   {'date': '20220906',
#    'close': 69700,
#    'sign': '5',
#    'change': -300,
#    'diff': '-0.43',
#    'volume': 744418,
#    'krx_0008': 624937,
#    'krx_0018': 651894,
#    'krx_0009': -1500577,
#    'pgmvol': 5490640996,
#    'fsc_listing': 127583763,
#    'fsc_sjrate': '28.66',
#    'fsc_0009': -554511,
#    'gm_volume': 878760955,
#    'gm_value': 219331},
#   {'date': '20220905',
#    'close': 70000,
#    'sign': '5',
#    'change': -200,
#    'diff': '-0.28',
#    'volume': 865940,
#    'krx_0008': 426879,
#    'krx_0018': 702601,
#    'krx_0009': -1353728,
#    'pgmvol': 5490774227,
#    'fsc_listing': 127719293,
#    'fsc_sjrate': '28.69',
#    'fsc_0009': -418981,
#    'gm_volume': 878723578,
#    'gm_value': 216716},
#   {'date': '20220902',
#    'close': 70200,
#    'sign': '5',
#    'change': -1200,
#    'diff': '-1.68',
#    'volume': 1201760,
#    'krx_0008': 414520,
#    'krx_0018': 694626,
#    'krx_0009': -1332496,
#    'pgmvol': 5490810555,
#    'fsc_listing': 127790525,
#    'fsc_sjrate': '28.71',
#    'fsc_0009': -347749,
#    'gm_volume': 878623895,
#    'gm_value': 209662},
#   {'date': '20220901',
#    'close': 71400,
#    'sign': '5',
#    'change': -2000,
#    'diff': '-2.72',
#    'volume': 1275977,
#    'krx_0008': 95525,
#    'krx_0018': 875045,
#    'krx_0009': -1190572,
#    'pgmvol': 5491023288,
#    'fsc_listing': 127724232,
#    'fsc_sjrate': '28.69',
#    'fsc_0009': -414042,
#    'gm_volume': 878542708,
#    'gm_value': 203841},
#   {'date': '20220831',
#    'close': 73400,
#    'sign': '2',
#    'change': 200,
#    'diff': '0.27',
#    'volume': 1348480,
#    'krx_0008': -319004,
#    'krx_0018': 1158855,
#    'krx_0009': -1048407,
#    'pgmvol': 5491337211,
#    'fsc_listing': 127889623,
#    'fsc_sjrate': '28.73',
#    'fsc_0009': -248651,
#    'gm_volume': 878481194,
#    'gm_value': 199371},
#   {'date': '20220830',
#    'close': 73200,
#    'sign': '2',
#    'change': 1000,
#    'diff': '1.39',
#    'volume': 802825,
#    'krx_0008': -419330,
#    'krx_0018': 1260864,
#    'krx_0009': -1055631,
#    'pgmvol': 5491309709,
#    'fsc_listing': 127907453,
#    'fsc_sjrate': '28.73',
#    'fsc_0009': -230821,
#    'gm_volume': 878424809,
#    'gm_value': 195253},
#   {'date': '20220829',
#    'close': 72200,
#    'sign': '5',
#    'change': -3800,
#    'diff': '-5.00',
#    'volume': 1632297,
#    'krx_0008': -441288,
#    'krx_0018': 1252382,
#    'krx_0009': -1024160,
#    'pgmvol': 5491332805,
#    'fsc_listing': 127958924,
#    'fsc_sjrate': '28.75',
#    'fsc_0009': -179350,
#    'gm_volume': 878263771,
#    'gm_value': 183584},
#   {'date': '20220826',
#    'close': 76000,
#    'sign': '5',
#    'change': -100,
#    'diff': '-0.13',
#    'volume': 993727,
#    'krx_0008': -978927,
#    'krx_0018': 1537092,
#    'krx_0009': -755921,
#    'pgmvol': 5491654389,
#    'fsc_listing': 128400550,
#    'fsc_sjrate': '28.84',
#    'fsc_0009': 262276,
#    'gm_volume': 878158115,
#    'gm_value': 175526},
#   {'date': '20220825',
#    'close': 76100,
#    'sign': '2',
#    'change': 1200,
#    'diff': '1.60',
#    'volume': 1252757,
#    'krx_0008': -939559,
#    'krx_0018': 1444634,
#    'krx_0009': -701615,
#    'pgmvol': 5491686414,
#    'fsc_listing': 128454331,
#    'fsc_sjrate': '28.86',
#    'fsc_0009': 316057,
#    'gm_volume': 878073169,
#    'gm_value': 169081},
#   {'date': '20220824',
#    'close': 74900,
#    'sign': '2',
#    'change': 100,
#    'diff': '0.13',
#    'volume': 936191,
#    'krx_0008': -904708,
#    'krx_0018': 1258469,
#    'krx_0009': -549899,
#    'pgmvol': 5491540174,
#    'fsc_listing': 128448489,
#    'fsc_sjrate': '28.86',
#    'fsc_0009': 310215,
#    'gm_volume': 877951003,
#    'gm_value': 159950},
#   {'date': '20220823',
#    'close': 74800,
#    'sign': '5',
#    'change': -200,
#    'diff': '-0.27',
#    'volume': 1327312,
#    'krx_0008': -949435,
#    'krx_0018': 1215428,
#    'krx_0009': -469263,
#    'pgmvol': 5491587808,
#    'fsc_listing': 128448991,
#    'fsc_sjrate': '28.86',
#    'fsc_0009': 310717,
#    'gm_volume': 877812424,
#    'gm_value': 149585},
#   {'date': '20220822',
#    'close': 75000,
#    'sign': '5',
#    'change': -1700,
#    'diff': '-2.22',
#    'volume': 1250643,
#    'krx_0008': -1053821,
#    'krx_0018': 1382777,
#    'krx_0009': -534786,
#    'pgmvol': 5491575575,
#    'fsc_listing': 128356086,
#    'fsc_sjrate': '28.83',
#    'fsc_0009': 217812,
#    'gm_volume': 877656755,
#    'gm_value': 137873},
#   {'date': '20220819',
#    'close': 76700,
#    'sign': '5',
#    'change': -2500,
#    'diff': '-3.16',
#    'volume': 1804047,
#    'krx_0008': -1066910,
#    'krx_0018': 1432894,
#    'krx_0009': -569089,
#    'pgmvol': 5491508159,
#    'fsc_listing': 128321783,
#    'fsc_sjrate': '28.83',
#    'fsc_0009': 183509,
#    'gm_volume': 877422687,
#    'gm_value': 119830},
#   {'date': '20220818',
#    'close': 79200,
#    'sign': '5',
#    'change': -900,
#    'diff': '-1.12',
#    'volume': 1640906,
#    'krx_0008': -1571526,
#    'krx_0018': 1637391,
#    'krx_0009': -253245,
#    'pgmvol': 5491920662,
#    'fsc_listing': 128436390,
#    'fsc_sjrate': '28.85',
#    'fsc_0009': 298116,
#    'gm_volume': 877282874,
#    'gm_value': 108858},
#   {'date': '20220817',
#    'close': 80100,
#    'sign': '5',
#    'change': -600,
#    'diff': '-0.74',
#    'volume': 1041971,
#    'krx_0008': -2011531,
#    'krx_0018': 2002312,
#    'krx_0009': -169596,
#    'pgmvol': 5492061643,
#    'fsc_listing': 128520039,
#    'fsc_sjrate': '28.87',
#    'fsc_0009': 381765,
#    'gm_volume': 877204257,
#    'gm_value': 102549},
#   {'date': '20220816',
#    'close': 80700,
#    'sign': '5',
#    'change': -1800,
#    'diff': '-2.18',
#    'volume': 1798225,
#    'krx_0008': -2197478,
#    'krx_0018': 2031423,
#    'krx_0009': -74702,
#    'pgmvol': 5492154823,
#    'fsc_listing': 128612330,
#    'fsc_sjrate': '28.89',
#    'fsc_0009': 474056,
#    'gm_volume': 877072244,
#    'gm_value': 91868},
#   {'date': '20220812',
#    'close': 82500,
#    'sign': '5',
#    'change': -1200,
#    'diff': '-1.43',
#    'volume': 1069578,
#    'krx_0008': -2778496,
#    'krx_0018': 2141704,
#    'krx_0009': 396842,
#    'pgmvol': 5492393008,
#    'fsc_listing': 129083874,
#    'fsc_sjrate': '29.00',
#    'fsc_0009': 945600,
#    'gm_volume': 876981232,
#    'gm_value': 84380},
#   {'date': '20220811',
#    'close': 83700,
#    'sign': '2',
#    'change': 3400,
#    'diff': '4.23',
#    'volume': 1918391,
#    'krx_0008': -2966053,
#    'krx_0018': 2204945,
#    'krx_0009': 520961,
#    'pgmvol': 5492510686,
#    'fsc_listing': 129507993,
#    'fsc_sjrate': '29.11',
#    'fsc_0009': 1369719,
#    'gm_volume': 876883172,
#    'gm_value': 76203},
#   {'date': '20220810',
#    'close': 80300,
#    'sign': '5',
#    'change': -2900,
#    'diff': '-3.49',
#    'volume': 1428961,
#    'krx_0008': -2325302,
#    'krx_0018': 1805855,
#    'krx_0009': 269646,
#    'pgmvol': 5492218482,
#    'fsc_listing': 129222280,
#    'fsc_sjrate': '29.04',
#    'fsc_0009': 1084006,
#    'gm_volume': 876830016,
#    'gm_value': 71899},
#   {'date': '20220809',
#    'close': 83200,
#    'sign': '2',
#    'change': 1200,
#    'diff': '1.46',
#    'volume': 1541966,
#    'krx_0008': -2578999,
#    'krx_0018': 1918093,
#    'krx_0009': 422027,
#    'pgmvol': 5492375265,
#    'fsc_listing': 129253678,
#    'fsc_sjrate': '29.05',
#    'fsc_0009': 1115404,
#    'gm_volume': 876758838,
#    'gm_value': 66024},
#   {'date': '20220808',
#    'close': 82000,
#    'sign': '2',
#    'change': 800,
#    'diff': '0.99',
#    'volume': 1674063,
#    'krx_0008': -2357507,
#    'krx_0018': 1543911,
#    'krx_0009': 573219,
#    'pgmvol': 5492509572,
#    'fsc_listing': 129388136,
#    'fsc_sjrate': '29.08',
#    'fsc_0009': 1249862,
#    'gm_volume': 876645964,
#    'gm_value': 56822},
#   {'date': '20220805',
#    'close': 81200,
#    'sign': '5',
#    'change': -500,
#    'diff': '-0.61',
#    'volume': 2511627,
#    'krx_0008': -2138774,
#    'krx_0018': 1546457,
#    'krx_0009': 348623,
#    'pgmvol': 5492715801,
#    'fsc_listing': 129163540,
#    'fsc_sjrate': '29.03',
#    'fsc_0009': 1025266,
#    'gm_volume': 876555190,
#    'gm_value': 49403},
#   {'date': '20220804',
#    'close': 81700,
#    'sign': '2',
#    'change': 5700,
#    'diff': '7.50',
#    'volume': 5803458,
#    'krx_0008': -1963477,
#    'krx_0018': 1283685,
#    'krx_0009': 423266,
#    'pgmvol': 5492956899,
#    'fsc_listing': 129288754,
#    'fsc_sjrate': '29.06',
#    'fsc_0009': 1150480,
#    'gm_volume': 876385944,
#    'gm_value': 35713},
#   {'date': '20220803',
#    'close': 76000,
#    'sign': '2',
#    'change': 4200,
#    'diff': '5.85',
#    'volume': 2893725,
#    'krx_0008': -537246,
#    'krx_0018': 705045,
#    'krx_0009': -473748,
#    'pgmvol': 5492241837,
#    'fsc_listing': 128460388,
#    'fsc_sjrate': '28.87',
#    'fsc_0009': 322114,
#    'gm_volume': 876305095,
#    'gm_value': 29638},
#   {'date': '20220802',
#    'close': 71800,
#    'sign': '5',
#    'change': -2200,
#    'diff': '-2.97',
#    'volume': 1786920,
#    'krx_0008': 629345,
#    'krx_0018': 251829,
#    'krx_0009': -1204058,
#    'pgmvol': 5491295410,
#    'fsc_listing': 127620078,
#    'fsc_sjrate': '28.68',
#    'fsc_0009': -518196,
#    'gm_volume': 876266164,
#    'gm_value': 26818},
#   {'date': '20220801',
#    'close': 74000,
#    'sign': '5',
#    'change': -800,
#    'diff': '-1.07',
#    'volume': 907903,
#    'krx_0008': -178965,
#    'krx_0018': 421749,
#    'krx_0009': -561649,
#    'pgmvol': 5491700248,
#    'fsc_listing': 128082487,
#    'fsc_sjrate': '28.79',
#    'fsc_0009': -55787,
#    'gm_volume': 876175064,
#    'gm_value': 20032},
#   {'date': '20220729',
#    'close': 74800,
#    'sign': '2',
#    'change': 2400,
#    'diff': '3.31',
#    'volume': 2164565,
#    'krx_0008': -391824,
#    'krx_0018': 487890,
#    'krx_0009': -425319,
#    'pgmvol': 5491860552,
#    'fsc_listing': 128208817,
#    'fsc_sjrate': '28.81',
#    'fsc_0009': 70543,
#    'gm_volume': 876051693,
#    'gm_value': 10834},
#   {'date': '20220728',
#    'close': 72400,
#    'sign': '2',
#    'change': 500,
#    'diff': '0.70',
#    'volume': 1226484,
#    'krx_0008': 155554,
#    'krx_0018': 157377,
#    'krx_0009': -646436,
#    'pgmvol': 5491684663,
#    'fsc_listing': 127987700,
#    'fsc_sjrate': '28.76',
#    'fsc_0009': -150574,
#    'gm_volume': 876016166,
#    'gm_value': 8254},
#   {'date': '20220727',
#    'close': 71900,
#    'sign': '5',
#    'change': -500,
#    'diff': '-0.69',
#    'volume': 924477,
#    'krx_0008': 264888,
#    'krx_0018': 183191,
#    'krx_0009': -750719,
#    'pgmvol': 5491561027,
#    'fsc_listing': 127863417,
#    'fsc_sjrate': '28.74',
#    'fsc_0009': -274857,
#    'gm_volume': 875900976,
#    'gm_value': 0}],
#  'rsp_cd': '00000',
#  'rsp_msg': '정상적으로 조회가 완료되었습니다.'}

# %%
a=[1]

# %%
a.push(0,'a')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 a.push(0,'a')
#
# AttributeError: 'list' object has no attribute 'push'

# %%
a.insert(0, 'a')

# %%
a.reverse()

# %%
a
# Out:
# [1, 'a']

# %%
with open('../currencyrates/EUR.csv', 'r') as f:
    s=list(csv.reader(f))[-24*60:]

# %%
os.path.dirname()
# Out:
# 'C:\\Users\\yosep\\Documents\\projects\\webapp\\webapp\\tools\\ebest'

# %%
from datetime import datetime

# %%
datetime.today() - timedelta(days=500)
# Out:
# datetime.datetime(2022, 3, 16, 18, 43, 16, 465895)

# %%
from datetime import timedelta

# %%
timedelta(days=1)
# Out:
# datetime.timedelta(days=1)

# %%
s['rate'].plot()
# Out:
# <Axes: xlabel='date'>

# %%
list(zip_longest([1,2,3],['a','b'], fillvalue={'hname':'', 'upcode':''}))
# Out:
# [(1, 'a'), (2, 'b'), (3, {'hname': '', 'upcode': ''})]

# %%
[ i for i in res.json()['t8424OutBlock'] if i['upcode'][0] == '0' or i['upcode'][0] == '3']
# Out:
# [{'hname': '종       합', 'upcode': '001'},
#  {'hname': '대   형  주', 'upcode': '002'},
#  {'hname': '중   형  주', 'upcode': '003'},
#  {'hname': '소   형  주', 'upcode': '004'},
#  {'hname': '음 식 료 업', 'upcode': '005'},
#  {'hname': '섬 유 의 복', 'upcode': '006'},
#  {'hname': '종 이 목 재', 'upcode': '007'},
#  {'hname': '화       학', 'upcode': '008'},
#  {'hname': '의   약  품', 'upcode': '009'},
#  {'hname': '비금속 광물', 'upcode': '010'},
#  {'hname': '철 강 금 속', 'upcode': '011'},
#  {'hname': '기       계', 'upcode': '012'},
#  {'hname': '전 기 전 자', 'upcode': '013'},
#  {'hname': '의 료 정 밀', 'upcode': '014'},
#  {'hname': '운 수 장 비', 'upcode': '015'},
#  {'hname': '유   통  업', 'upcode': '016'},
#  {'hname': '전 기 가 스', 'upcode': '017'},
#  {'hname': '건   설  업', 'upcode': '018'},
#  {'hname': '운 수 창 고', 'upcode': '019'},
#  {'hname': '통   신  업', 'upcode': '020'},
#  {'hname': '금   융  업', 'upcode': '021'},
#  {'hname': '증       권', 'upcode': '024'},
#  {'hname': '보   험  업', 'upcode': '025'},
#  {'hname': '서 비 스 업', 'upcode': '026'},
#  {'hname': '제   조  업', 'upcode': '027'},
#  {'hname': '코스닥 종합', 'upcode': '301'},
#  {'hname': '기타 서비스', 'upcode': '303'},
#  {'hname': 'IT   종  합', 'upcode': '304'},
#  {'hname': '제       조', 'upcode': '306'},
#  {'hname': '건       설', 'upcode': '307'},
#  {'hname': '유       통', 'upcode': '308'},
#  {'hname': '운       송', 'upcode': '310'},
#  {'hname': '금       융', 'upcode': '311'},
#  {'hname': '통 신/방 송', 'upcode': '312'},
#  {'hname': 'IT   S / W', 'upcode': '313'},
#  {'hname': 'IT   H / W', 'upcode': '314'},
#  {'hname': '음식료 담배', 'upcode': '315'},
#  {'hname': '섬 유/의 류', 'upcode': '316'},
#  {'hname': '종 이/목 재', 'upcode': '317'},
#  {'hname': '출 판 매 체', 'upcode': '318'},
#  {'hname': '화       학', 'upcode': '319'},
#  {'hname': '제       약', 'upcode': '320'},
#  {'hname': '비   금  속', 'upcode': '321'},
#  {'hname': '금       속', 'upcode': '322'},
#  {'hname': '기 계 장 비', 'upcode': '323'},
#  {'hname': '전 기/전 자', 'upcode': '324'},
#  {'hname': '의 료/정 밀', 'upcode': '325'},
#  {'hname': '운 송/부 품', 'upcode': '326'},
#  {'hname': '기 타 제 조', 'upcode': '327'},
#  {'hname': '통신 서비스', 'upcode': '328'},
#  {'hname': '방송 서비스', 'upcode': '329'},
#  {'hname': '인   터  넷', 'upcode': '330'},
#  {'hname': '디   지  털', 'upcode': '331'},
#  {'hname': '소프트 웨어', 'upcode': '332'},
#  {'hname': '컴퓨터서비스', 'upcode': '333'},
#  {'hname': '통 신 장 비', 'upcode': '334'},
#  {'hname': '정 보 기 기', 'upcode': '335'},
#  {'hname': '반   도  체', 'upcode': '336'},
#  {'hname': 'IT   부  품', 'upcode': '337'},
#  {'hname': '오락/문화', 'upcode': '338'},
#  {'hname': 'KOSDAQ100', 'upcode': '339'},
#  {'hname': 'KOSDAQ MID 300', 'upcode': '340'},
#  {'hname': 'KOSDAQ SMALL', 'upcode': '341'},
#  {'hname': '우 량 기 업', 'upcode': '342'},
#  {'hname': '벤 처 기 업', 'upcode': '343'},
#  {'hname': '중 견 기 업', 'upcode': '344'},
#  {'hname': '기술성장 기업', 'upcode': '345'}]

# %%
res.json()
# Out:
# {'t8424OutBlock': [{'hname': '종       합', 'upcode': '001'},
#   {'hname': '대   형  주', 'upcode': '002'},
#   {'hname': '중   형  주', 'upcode': '003'},
#   {'hname': '소   형  주', 'upcode': '004'},
#   {'hname': '음 식 료 업', 'upcode': '005'},
#   {'hname': '섬 유 의 복', 'upcode': '006'},
#   {'hname': '종 이 목 재', 'upcode': '007'},
#   {'hname': '화       학', 'upcode': '008'},
#   {'hname': '의   약  품', 'upcode': '009'},
#   {'hname': '비금속 광물', 'upcode': '010'},
#   {'hname': '철 강 금 속', 'upcode': '011'},
#   {'hname': '기       계', 'upcode': '012'},
#   {'hname': '전 기 전 자', 'upcode': '013'},
#   {'hname': '의 료 정 밀', 'upcode': '014'},
#   {'hname': '운 수 장 비', 'upcode': '015'},
#   {'hname': '유   통  업', 'upcode': '016'},
#   {'hname': '전 기 가 스', 'upcode': '017'},
#   {'hname': '건   설  업', 'upcode': '018'},
#   {'hname': '운 수 창 고', 'upcode': '019'},
#   {'hname': '통   신  업', 'upcode': '020'},
#   {'hname': '금   융  업', 'upcode': '021'},
#   {'hname': '증       권', 'upcode': '024'},
#   {'hname': '보   험  업', 'upcode': '025'},
#   {'hname': '서 비 스 업', 'upcode': '026'},
#   {'hname': '제   조  업', 'upcode': '027'},
#   {'hname': 'KOSPI200', 'upcode': '101'},
#   {'hname': 'KP200 건설', 'upcode': '111'},
#   {'hname': 'KP200 중공업', 'upcode': '112'},
#   {'hname': 'KP200 철강소재', 'upcode': '113'},
#   {'hname': 'KP200 에너지화학', 'upcode': '114'},
#   {'hname': 'KP200 정보기술', 'upcode': '115'},
#   {'hname': 'KP200 금융', 'upcode': '116'},
#   {'hname': 'KP200 생활소비재', 'upcode': '117'},
#   {'hname': 'KP200 경기소비재', 'upcode': '118'},
#   {'hname': 'KP200 산업재', 'upcode': '119'},
#   {'hname': 'KP200 건강관리', 'upcode': '120'},
#   {'hname': 'KP200 커뮤니케이션서', 'upcode': '121'},
#   {'hname': 'KP200 초대형주제외지', 'upcode': '122'},
#   {'hname': 'KOSPI100', 'upcode': '201'},
#   {'hname': 'KOSPI50', 'upcode': '202'},
#   {'hname': 'F-KOSPI200인버스', 'upcode': '204'},
#   {'hname': 'VKOSPI', 'upcode': '205'},
#   {'hname': 'F-KOSPI200', 'upcode': '206'},
#   {'hname': 'KP200 동일가중', 'upcode': '207'},
#   {'hname': 'KP100 동일가중', 'upcode': '208'},
#   {'hname': 'KP 50 동일가중', 'upcode': '209'},
#   {'hname': 'KRX100동일가중', 'upcode': '210'},
#   {'hname': 'KP200 고배당지수', 'upcode': '211'},
#   {'hname': 'KOSPI 고배당 50', 'upcode': '213'},
#   {'hname': 'KOSPI 배당성장 50', 'upcode': '214'},
#   {'hname': 'KOSPI 우선주', 'upcode': '215'},
#   {'hname': 'KP200 중소형주지수', 'upcode': '216'},
#   {'hname': 'KP200 필수소비재', 'upcode': '217'},
#   {'hname': 'KP200 예측 고배당 50', 'upcode': '222'},
#   {'hname': 'KP200 예측 배당성장', 'upcode': '223'},
#   {'hname': 'KP200 예측 TR', 'upcode': '224'},
#   {'hname': 'KP200 예측 NTR', 'upcode': '225'},
#   {'hname': '코스닥 종합', 'upcode': '301'},
#   {'hname': '기타 서비스', 'upcode': '303'},
#   {'hname': 'IT   종  합', 'upcode': '304'},
#   {'hname': '제       조', 'upcode': '306'},
#   {'hname': '건       설', 'upcode': '307'},
#   {'hname': '유       통', 'upcode': '308'},
#   {'hname': '운       송', 'upcode': '310'},
#   {'hname': '금       융', 'upcode': '311'},
#   {'hname': '통 신/방 송', 'upcode': '312'},
#   {'hname': 'IT   S / W', 'upcode': '313'},
#   {'hname': 'IT   H / W', 'upcode': '314'},
#   {'hname': '음식료 담배', 'upcode': '315'},
#   {'hname': '섬 유/의 류', 'upcode': '316'},
#   {'hname': '종 이/목 재', 'upcode': '317'},
#   {'hname': '출 판 매 체', 'upcode': '318'},
#   {'hname': '화       학', 'upcode': '319'},
#   {'hname': '제       약', 'upcode': '320'},
#   {'hname': '비   금  속', 'upcode': '321'},
#   {'hname': '금       속', 'upcode': '322'},
#   {'hname': '기 계 장 비', 'upcode': '323'},
#   {'hname': '전 기/전 자', 'upcode': '324'},
#   {'hname': '의 료/정 밀', 'upcode': '325'},
#   {'hname': '운 송/부 품', 'upcode': '326'},
#   {'hname': '기 타 제 조', 'upcode': '327'},
#   {'hname': '통신 서비스', 'upcode': '328'},
#   {'hname': '방송 서비스', 'upcode': '329'},
#   {'hname': '인   터  넷', 'upcode': '330'},
#   {'hname': '디   지  털', 'upcode': '331'},
#   {'hname': '소프트 웨어', 'upcode': '332'},
#   {'hname': '컴퓨터서비스', 'upcode': '333'},
#   {'hname': '통 신 장 비', 'upcode': '334'},
#   {'hname': '정 보 기 기', 'upcode': '335'},
#   {'hname': '반   도  체', 'upcode': '336'},
#   {'hname': 'IT   부  품', 'upcode': '337'},
#   {'hname': '오락/문화', 'upcode': '338'},
#   {'hname': 'KOSDAQ100', 'upcode': '339'},
#   {'hname': 'KOSDAQ MID 300', 'upcode': '340'},
#   {'hname': 'KOSDAQ SMALL', 'upcode': '341'},
#   {'hname': '우 량 기 업', 'upcode': '342'},
#   {'hname': '벤 처 기 업', 'upcode': '343'},
#   {'hname': '중 견 기 업', 'upcode': '344'},
#   {'hname': '기술성장 기업', 'upcode': '345'},
#   {'hname': '코스닥 150', 'upcode': '405'},
#   {'hname': 'K R X 1 0 0', 'upcode': '501'},
#   {'hname': 'KRX자 동 차', 'upcode': '502'},
#   {'hname': 'KRX반 도 체', 'upcode': '503'},
#   {'hname': 'KRX바 이 오', 'upcode': '504'},
#   {'hname': 'KRX금    융', 'upcode': '505'},
#   {'hname': 'KRX에너지화학', 'upcode': '507'},
#   {'hname': 'KRX철    강', 'upcode': '508'},
#   {'hname': 'KRX방송통신', 'upcode': '510'},
#   {'hname': 'KRX건    설', 'upcode': '511'},
#   {'hname': 'KRX증    권', 'upcode': '513'},
#   {'hname': 'KRX기계장비', 'upcode': '514'},
#   {'hname': 'KRX보    험', 'upcode': '516'},
#   {'hname': 'KRX운    송', 'upcode': '517'},
#   {'hname': 'KRX ESG Leaders 150', 'upcode': '523'},
#   {'hname': 'KRX Governance Leade', 'upcode': '524'},
#   {'hname': 'KRX Eco Leaders 100', 'upcode': '525'},
#   {'hname': 'KRX 최소변동성지수', 'upcode': '526'},
#   {'hname': 'KRX 경기소비재', 'upcode': '531'},
#   {'hname': 'KRX 생활소비재', 'upcode': '532'},
#   {'hname': 'KRX 미디어&엔터테인�', 'upcode': '533'},
#   {'hname': 'KRX 정보기술', 'upcode': '534'},
#   {'hname': 'KRX 유틸리티', 'upcode': '535'},
#   {'hname': 'KRX 금현물', 'upcode': '536'},
#   {'hname': 'KRX 금현물 USD', 'upcode': '537'},
#   {'hname': 'KRX 300', 'upcode': '538'},
#   {'hname': 'KRX 300 정보기술', 'upcode': '540'},
#   {'hname': 'KRX 300 금융', 'upcode': '541'},
#   {'hname': 'KRX 300 자유소비재', 'upcode': '542'},
#   {'hname': 'KRX 300 산업재', 'upcode': '543'},
#   {'hname': 'KRX 300 헬스케어', 'upcode': '544'},
#   {'hname': 'KRX 300 커뮤니케이션', 'upcode': '545'},
#   {'hname': 'KRX 300 소재', 'upcode': '546'},
#   {'hname': 'KRX 300 필수소비재', 'upcode': '547'},
#   {'hname': 'KRX BBIG K-뉴딜', 'upcode': '548'},
#   {'hname': 'KRX 2차전지 K-뉴딜', 'upcode': '549'},
#   {'hname': 'KRX 바이오 K-뉴딜', 'upcode': '550'},
#   {'hname': 'KRX 인터넷 K-뉴딜', 'upcode': '551'},
#   {'hname': 'KRX 게임 K-뉴딜', 'upcode': '552'},
#   {'hname': 'KOSPI200 기후변화', 'upcode': '553'},
#   {'hname': 'KRX 300 기후변화', 'upcode': '554'},
#   {'hname': 'KRX 기후변화 솔루션', 'upcode': '555'},
#   {'hname': 'F-USDKRW', 'upcode': '601'},
#   {'hname': 'F-USDKRW 인버스', 'upcode': '602'},
#   {'hname': 'KOSPI200레버리지', 'upcode': '603'},
#   {'hname': 'KP200 커버드콜 5OTM', 'upcode': '604'},
#   {'hname': 'KP200 프로텍티브풋 5', 'upcode': '605'},
#   {'hname': '국채선물지수', 'upcode': '606'},
#   {'hname': '국채선물인버스', 'upcode': '607'},
#   {'hname': 'F-LKTB', 'upcode': '608'},
#   {'hname': 'F-LKTB 인버스', 'upcode': '609'},
#   {'hname': '주식미국채DAE지수', 'upcode': '615'},
#   {'hname': 'COBIX', 'upcode': '616'},
#   {'hname': 'MOBIX', 'upcode': '617'},
#   {'hname': 'F-USDKRW 레버리지', 'upcode': '618'},
#   {'hname': 'F-USDKRW 인버스 -2x', 'upcode': '619'},
#   {'hname': 'F-USDKRW 인버스 -3x', 'upcode': '620'},
#   {'hname': 'K200 USD 선물 바이셀', 'upcode': '622'},
#   {'hname': 'USD K200 선물 바이셀', 'upcode': '623'},
#   {'hname': 'K200선물매수 콜매도', 'upcode': '624'},
#   {'hname': 'K200선물매도 풋매도', 'upcode': '625'},
#   {'hname': 'K200 가치저변동성지�', 'upcode': '630'},
#   {'hname': 'F-KP200 인버스 -2x', 'upcode': '638'},
#   {'hname': 'F-KP200 인버스 -3x', 'upcode': '639'},
#   {'hname': 'KTOP 30', 'upcode': '640'},
#   {'hname': 'KTOP 30 레버리지', 'upcode': '641'},
#   {'hname': '필수소비재채권혼합지', 'upcode': '642'},
#   {'hname': '배당성장채권혼합지수', 'upcode': '643'},
#   {'hname': 'KP200 에너지화학 레�', 'upcode': '644'},
#   {'hname': 'KP200 정보기술 레버�', 'upcode': '645'},
#   {'hname': 'KP200 금융 레버리지', 'upcode': '646'},
#   {'hname': 'KP200 경기소비재 레�', 'upcode': '647'},
#   {'hname': 'F-KP200 레버리지', 'upcode': '648'},
#   {'hname': 'F-KQ150', 'upcode': '649'},
#   {'hname': 'F-KQ150 인버스', 'upcode': '650'},
#   {'hname': 'F-KQ150 인버스 -2x', 'upcode': '651'},
#   {'hname': 'F-KQ150 인버스 -3x', 'upcode': '652'},
#   {'hname': 'KQ150 레버리지', 'upcode': '653'},
#   {'hname': 'KQ150 레버리지 0.5', 'upcode': '654'},
#   {'hname': 'WISE-KAP 스마트베타Q', 'upcode': '655'},
#   {'hname': 'MF-KP200', 'upcode': '656'},
#   {'hname': 'MF-KP200 레버리지', 'upcode': '657'},
#   {'hname': 'MF-KP200 인버스', 'upcode': '658'},
#   {'hname': 'MF-KP200 인버스 -2x', 'upcode': '659'},
#   {'hname': 'F-KQ150 레버리지', 'upcode': '660'},
#   {'hname': 'KP200 커버드콜 ATM', 'upcode': '661'},
#   {'hname': 'KP200 현선물레버리지', 'upcode': '662'},
#   {'hname': '한국대만IT프리미어', 'upcode': '663'},
#   {'hname': 'F-KRX300', 'upcode': '664'},
#   {'hname': 'F-KRX300 레버리지', 'upcode': '665'},
#   {'hname': 'F-KRX300 인버스', 'upcode': '666'},
#   {'hname': 'F-KRX300 인버스 -2X', 'upcode': '667'},
#   {'hname': 'KRX300 레버리지', 'upcode': '668'},
#   {'hname': 'F-KRX300 USD 혼합', 'upcode': '669'},
#   {'hname': 'SF-KP200 목표변동성', 'upcode': '670'},
#   {'hname': 'SF-KQ150 USD 혼합', 'upcode': '671'},
#   {'hname': 'F-K200 에너지/화학', 'upcode': '751'},
#   {'hname': 'F-K200 정보기술', 'upcode': '752'},
#   {'hname': 'F-K200 금융', 'upcode': '753'},
#   {'hname': 'F-K200 경기소비재', 'upcode': '754'},
#   {'hname': 'F-K200 건설', 'upcode': '755'},
#   {'hname': 'F-K200 중공업', 'upcode': '756'},
#   {'hname': 'F-K200 헬스케어', 'upcode': '757'},
#   {'hname': 'F-K200 생활소비재', 'upcode': '758'},
#   {'hname': 'F-K200 철강/소재', 'upcode': '759'},
#   {'hname': 'F-K200 산업재', 'upcode': '760'},
#   {'hname': 'F-K200 에너지/화학 �', 'upcode': '761'},
#   {'hname': 'F-K200 정보기술 레버', 'upcode': '762'},
#   {'hname': 'F-K200 금융 레버리지', 'upcode': '763'},
#   {'hname': 'F-K200 경기소비재 레', 'upcode': '764'},
#   {'hname': 'F-K200 건설 레버리지', 'upcode': '765'},
#   {'hname': 'F-K200 중공업 레버리', 'upcode': '766'},
#   {'hname': 'F-K200 헬스케어 레버', 'upcode': '767'},
#   {'hname': 'F-K200 생활소비재 레', 'upcode': '768'},
#   {'hname': 'F-K200 철강/소재 레�', 'upcode': '769'},
#   {'hname': 'F-K200 산업재 레버리', 'upcode': '770'},
#   {'hname': 'F-K200 에너지/화학 �', 'upcode': '771'},
#   {'hname': 'F-K200 정보기술 인버', 'upcode': '772'},
#   {'hname': 'F-K200 금융 인버스', 'upcode': '773'},
#   {'hname': 'F-K200 경기소비재 인', 'upcode': '774'},
#   {'hname': 'F-K200 건설 인버스', 'upcode': '775'},
#   {'hname': 'F-K200 중공업 인버스', 'upcode': '776'},
#   {'hname': 'F-K200 헬스케어 인버', 'upcode': '777'},
#   {'hname': 'F-K200 생활소비재 인', 'upcode': '778'},
#   {'hname': 'F-K200 철강/소재 인�', 'upcode': '779'},
#   {'hname': 'F-K200 산업재 인버스', 'upcode': '780'},
#   {'hname': 'F-K200 에너지/화학 �', 'upcode': '781'},
#   {'hname': 'F-K200 정보기술 인버', 'upcode': '782'},
#   {'hname': 'F-K200 금융 인버스-2', 'upcode': '783'},
#   {'hname': 'F-K200 경기소비재 인', 'upcode': '784'},
#   {'hname': 'F-K200 건설 인버스-2', 'upcode': '785'},
#   {'hname': 'F-K200 중공업 인버스', 'upcode': '786'},
#   {'hname': 'F-K200 헬스케어 인버', 'upcode': '787'},
#   {'hname': 'F-K200 생활소비재 인', 'upcode': '788'},
#   {'hname': 'F-K200 철강/소재 인�', 'upcode': '789'},
#   {'hname': 'F-K200 산업재 인버스', 'upcode': '790'},
#   {'hname': 'KOSPI 총수익', 'upcode': '791'},
#   {'hname': 'KOSDAQ 총수익', 'upcode': '792'},
#   {'hname': 'KOSDAQ150 총수익', 'upcode': '793'},
#   {'hname': 'KRX 300 총수익', 'upcode': '794'},
#   {'hname': 'KOSPI 고배당50 총수�', 'upcode': '796'},
#   {'hname': 'KSP배당성장50총수익', 'upcode': '797'},
#   {'hname': 'KOSPI200 ESG', 'upcode': '798'},
#   {'hname': 'F-KTB 3-10스티프닝', 'upcode': '810'},
#   {'hname': 'F-KTB 3-10플래트닝', 'upcode': '811'},
#   {'hname': 'F-KTB 3-10스티프닝2X', 'upcode': '812'},
#   {'hname': 'F-KTB 3-10플래트닝2X', 'upcode': '813'},
#   {'hname': 'KP200-KQ150 비중5:5', 'upcode': '814'},
#   {'hname': 'KP200-KQ150 비중7:3', 'upcode': '815'},
#   {'hname': 'KP200-KQ150 비중3:7', 'upcode': '816'},
#   {'hname': 'KP200 L KQ150 S', 'upcode': '817'},
#   {'hname': 'KQ150 L KP200 S', 'upcode': '818'},
#   {'hname': 'KP200 L KQ150 0.5 S', 'upcode': '819'},
#   {'hname': 'KQ150 L KP200 0.5 S', 'upcode': '820'}],
#  'rsp_cd': '00000',
#  'rsp_msg': '정상적으로 조회가 완료되었습니다.'}

# %%
getattr(a, 'test')()
# Out:
# haha

# %%
int('001')
# Out:
# 1
